# %% [markdown]
# ## Tokenize and POS tag the text

# %%
import nltk
# from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer

# %%
# https://www.battlefields.org/learn/articles/brief-overview-american-civil-war 
text = open("data.txt").read()
print(text)
print(len(text))
# Out:
# The Civil War is the central event in America's historical consciousness. While the Revolution of 1776-1783 created the United States, the Civil War of 1861-1865 determined what kind of nation it would be. The war resolved two fundamental questions left unresolved by the revolution: whether the United States was to be a dissolvable confederation of sovereign states or an indivisible nation with a sovereign national government; and whether this nation, born of a declaration that all men were created with an equal right to liberty, would continue to exist as the largest slaveholding country in the world.
#
# Northern victory in the war preserved the United States as one nation and ended the institution of slavery that had divided the country from its beginning. But these achievements came at the cost of 625,000 lives--nearly as many American soldiers as died in all the other wars in which this country has fought combined. The American Civil War was the largest and most destructive conflict in the Western world between the end of the Napoleonic Wars in 1815 and the onset of World War I in 1914.
#
# The Civil War started because of uncompromising differences between the free and slave states over the power of the national government to prohibit slavery in the territories that had not yet become states. When Abraham Lincoln won election in 1860 as the first Republican president on a platform pledging to keep slavery out of the territories, seven slave states in the deep South seceded and formed a new nation, the Confederate States of America. The incoming Lincoln administration and most of the Northern people refused to recognize the legitimacy of secession. They feared that it would discredit democracy and create a fatal precedent that would eventually fragment the no-longer United States into several small, squabbling countries.
#
# The event that triggered war came at Fort Sumter in Charleston Bay on April 12, 1861. Claiming this United States fort as their own, the Confederate army on that day opened fire on the federal garrison and forced it to lower the American flag in surrender. Lincoln called out the militia to suppress this "insurrection." Four more slave states seceded and joined the Confederacy. By the end of 1861 nearly a million armed men confronted each other along a line stretching 1200 miles from Virginia to Missouri. Several battles had already taken place--near Manassas Junction in Virginia, in the mountains of western Virginia where Union victories paved the way for creation of the new state of West Virginia, at Wilson's Creek in Missouri, at Cape Hatteras in North Carolina, and at Port Royal in South Carolina where the Union navy established a base for a blockade to shut off the Confederacy's access to the outside world.
#
# But the real fighting began in 1862. Huge battles like Shiloh in Tennessee, Gaines' Mill, Second Manassas, and Fredericksburg in Virginia, and Antietam in Maryland foreshadowed even bigger campaigns and battles in subsequent years, from Gettysburg in Pennsylvania to Vicksburg on the Mississippi to Chickamauga and Atlanta in Georgia. By 1864 the original Northern goal of a limited war to restore the Union had given way to a new strategy of "total war" to destroy the Old South and its basic institution of slavery and to give the restored Union a "new birth of freedom," as President Lincoln put it in his address at Gettysburg to dedicate a cemetery for Union soldiers killed in the battle there.
#
# For three long years, from 1862 to 1865, Robert E. Lee's Army of Northern Virginia staved off invasions and attacks by the Union Army of the Potomac commanded by a series of ineffective generals until Ulysses S. Grant came to Virginia from the Western theater to become general in chief of all Union armies in 1864. After bloody battles at places with names like The Wilderness, Spotsylvania, Cold Harbor, and Petersburg, Grant finally brought Lee to bay at Appomattox in April 1865. In the meantime Union armies and river fleets in the theater of war comprising the slave states west of the Appalachian Mountain chain won a long series of victories over Confederate armies commanded by hapless or unlucky Confederate generals. In 1864-1865 General William Tecumseh Sherman led his army deep into the Confederate heartland of Georgia and South Carolina, destroying their economic infrastructure while General George Thomas virtually destroyed the Confederacy's Army of Tennessee at the battle of Nashville.
#
# By the spring of 1865 all the principal Confederate armies surrendered, and when Union cavalry captured the fleeing Confederate President Jefferson Davis in Georgia on May 10, 1865, resistance collapsed and the war ended. The long, painful process of rebuilding a united nation free of slavery began.
# 4789

# %%
# convert to list of words
text_tokens = nltk.word_tokenize(text)
print(text_tokens)
print()
print(len(text_tokens))
# Out:
# ['The', 'Civil', 'War', 'is', 'the', 'central', 'event', 'in', 'America', "'s", 'historical', 'consciousness', '.', 'While', 'the', 'Revolution', 'of', '1776-1783', 'created', 'the', 'United', 'States', ',', 'the', 'Civil', 'War', 'of', '1861-1865', 'determined', 'what', 'kind', 'of', 'nation', 'it', 'would', 'be', '.', 'The', 'war', 'resolved', 'two', 'fundamental', 'questions', 'left', 'unresolved', 'by', 'the', 'revolution', ':', 'whether', 'the', 'United', 'States', 'was', 'to', 'be', 'a', 'dissolvable', 'confederation', 'of', 'sovereign', 'states', 'or', 'an', 'indivisible', 'nation', 'with', 'a', 'sovereign', 'national', 'government', ';', 'and', 'whether', 'this', 'nation', ',', 'born', 'of', 'a', 'declaration', 'that', 'all', 'men', 'were', 'created', 'with', 'an', 'equal', 'right', 'to', 'liberty', ',', 'would', 'continue', 'to', 'exist', 'as', 'the', 'largest', 'slaveholding', 'country', 'in', 'the', 'world', '.', 'Northern', 'victory', 'in', 'the', 'war', 'preserved', 'the', 'United', 'States', 'as', 'one', 'nation', 'and', 'ended', 'the', 'institution', 'of', 'slavery', 'that', 'had', 'divided', 'the', 'country', 'from', 'its', 'beginning', '.', 'But', 'these', 'achievements', 'came', 'at', 'the', 'cost', 'of', '625,000', 'lives', '--', 'nearly', 'as', 'many', 'American', 'soldiers', 'as', 'died', 'in', 'all', 'the', 'other', 'wars', 'in', 'which', 'this', 'country', 'has', 'fought', 'combined', '.', 'The', 'American', 'Civil', 'War', 'was', 'the', 'largest', 'and', 'most', 'destructive', 'conflict', 'in', 'the', 'Western', 'world', 'between', 'the', 'end', 'of', 'the', 'Napoleonic', 'Wars', 'in', '1815', 'and', 'the', 'onset', 'of', 'World', 'War', 'I', 'in', '1914', '.', 'The', 'Civil', 'War', 'started', 'because', 'of', 'uncompromising', 'differences', 'between', 'the', 'free', 'and', 'slave', 'states', 'over', 'the', 'power', 'of', 'the', 'national', 'government', 'to', 'prohibit', 'slavery', 'in', 'the', 'territories', 'that', 'had', 'not', 'yet', 'become', 'states', '.', 'When', 'Abraham', 'Lincoln', 'won', 'election', 'in', '1860', 'as', 'the', 'first', 'Republican', 'president', 'on', 'a', 'platform', 'pledging', 'to', 'keep', 'slavery', 'out', 'of', 'the', 'territories', ',', 'seven', 'slave', 'states', 'in', 'the', 'deep', 'South', 'seceded', 'and', 'formed', 'a', 'new', 'nation', ',', 'the', 'Confederate', 'States', 'of', 'America', '.', 'The', 'incoming', 'Lincoln', 'administration', 'and', 'most', 'of', 'the', 'Northern', 'people', 'refused', 'to', 'recognize', 'the', 'legitimacy', 'of', 'secession', '.', 'They', 'feared', 'that', 'it', 'would', 'discredit', 'democracy', 'and', 'create', 'a', 'fatal', 'precedent', 'that', 'would', 'eventually', 'fragment', 'the', 'no-longer', 'United', 'States', 'into', 'several', 'small', ',', 'squabbling', 'countries', '.', 'The', 'event', 'that', 'triggered', 'war', 'came', 'at', 'Fort', 'Sumter', 'in', 'Charleston', 'Bay', 'on', 'April', '12', ',', '1861', '.', 'Claiming', 'this', 'United', 'States', 'fort', 'as', 'their', 'own', ',', 'the', 'Confederate', 'army', 'on', 'that', 'day', 'opened', 'fire', 'on', 'the', 'federal', 'garrison', 'and', 'forced', 'it', 'to', 'lower', 'the', 'American', 'flag', 'in', 'surrender', '.', 'Lincoln', 'called', 'out', 'the', 'militia', 'to', 'suppress', 'this', '``', 'insurrection', '.', "''", 'Four', 'more', 'slave', 'states', 'seceded', 'and', 'joined', 'the', 'Confederacy', '.', 'By', 'the', 'end', 'of', '1861', 'nearly', 'a', 'million', 'armed', 'men', 'confronted', 'each', 'other', 'along', 'a', 'line', 'stretching', '1200', 'miles', 'from', 'Virginia', 'to', 'Missouri', '.', 'Several', 'battles', 'had', 'already', 'taken', 'place', '--', 'near', 'Manassas', 'Junction', 'in', 'Virginia', ',', 'in', 'the', 'mountains', 'of', 'western', 'Virginia', 'where', 'Union', 'victories', 'paved', 'the', 'way', 'for', 'creation', 'of', 'the', 'new', 'state', 'of', 'West', 'Virginia', ',', 'at', 'Wilson', "'s", 'Creek', 'in', 'Missouri',  ...
#
# 852

# %%
# POS tag on filtered text
text_tag = nltk.pos_tag(text_tokens)
print(text_tag)
# Out:
# [('The', 'DT'), ('Civil', 'NNP'), ('War', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('central', 'JJ'), ('event', 'NN'), ('in', 'IN'), ('America', 'NNP'), ("'s", 'POS'), ('historical', 'JJ'), ('consciousness', 'NN'), ('.', '.'), ('While', 'IN'), ('the', 'DT'), ('Revolution', 'NNP'), ('of', 'IN'), ('1776-1783', 'JJ'), ('created', 'VBD'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), (',', ','), ('the', 'DT'), ('Civil', 'NNP'), ('War', 'NNP'), ('of', 'IN'), ('1861-1865', 'JJ'), ('determined', 'VBD'), ('what', 'WP'), ('kind', 'NN'), ('of', 'IN'), ('nation', 'NN'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('.', '.'), ('The', 'DT'), ('war', 'NN'), ('resolved', 'VBD'), ('two', 'CD'), ('fundamental', 'JJ'), ('questions', 'NNS'), ('left', 'VBD'), ('unresolved', 'JJ'), ('by', 'IN'), ('the', 'DT'), ('revolution', 'NN'), (':', ':'), ('whether', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('was', 'VBD'), ('to', 'TO'), ('be', 'VB'), ('a', 'DT'), ('dissolvable', 'JJ'), ('confederation', 'NN'), ('of', 'IN'), ('sovereign', 'JJ'), ('states', 'NNS'), ('or', 'CC'), ('an', 'DT'), ('indivisible', 'JJ'), ('nation', 'NN'), ('with', 'IN'), ('a', 'DT'), ('sovereign', 'JJ'), ('national', 'JJ'), ('government', 'NN'), (';', ':'), ('and', 'CC'), ('whether', 'IN'), ('this', 'DT'), ('nation', 'NN'), (',', ','), ('born', 'VBN'), ('of', 'IN'), ('a', 'DT'), ('declaration', 'NN'), ('that', 'IN'), ('all', 'DT'), ('men', 'NNS'), ('were', 'VBD'), ('created', 'VBN'), ('with', 'IN'), ('an', 'DT'), ('equal', 'JJ'), ('right', 'NN'), ('to', 'TO'), ('liberty', 'VB'), (',', ','), ('would', 'MD'), ('continue', 'VB'), ('to', 'TO'), ('exist', 'VB'), ('as', 'IN'), ('the', 'DT'), ('largest', 'JJS'), ('slaveholding', 'VBG'), ('country', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ('Northern', 'NNP'), ('victory', 'NN'), ('in', 'IN'), ('the', 'DT'), ('war', 'NN'), ('preserved', 'VBD'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('as', 'IN'), ('one', 'CD'), ('nation', 'NN'), ('and', 'CC'), ('ended', 'VBD'), ('the', 'DT'), ('institution', 'NN'), ('of', 'IN'), ('slavery', 'NN'), ('that', 'WDT'), ('had', 'VBD'), ('divided', 'VBN'), ('the', 'DT'), ('country', 'NN'), ('from', 'IN'), ('its', 'PRP$'), ('beginning', 'NN'), ('.', '.'), ('But', 'CC'), ('these', 'DT'), ('achievements', 'NNS'), ('came', 'VBD'), ('at', 'IN'), ('the', 'DT'), ('cost', 'NN'), ('of', 'IN'), ('625,000', 'CD'), ('lives', 'NNS'), ('--', ':'), ('nearly', 'RB'), ('as', 'RB'), ('many', 'JJ'), ('American', 'JJ'), ('soldiers', 'NNS'), ('as', 'IN'), ('died', 'VBN'), ('in', 'IN'), ('all', 'PDT'), ('the', 'DT'), ('other', 'JJ'), ('wars', 'NNS'), ('in', 'IN'), ('which', 'WDT'), ('this', 'DT'), ('country', 'NN'), ('has', 'VBZ'), ('fought', 'VBN'), ('combined', 'VBN'), ('.', '.'), ('The', 'DT'), ('American', 'JJ'), ('Civil', 'NNP'), ('War', 'NNP'), ('was', 'VBD'), ('the', 'DT'), ('largest', 'JJS'), ('and', 'CC'), ('most', 'RBS'), ('destructive', 'JJ'), ('conflict', 'NN'), ('in', 'IN'), ('the', 'DT'), ('Western', 'JJ'), ('world', 'NN'), ('between', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Napoleonic', 'NNP'), ('Wars', 'NNP'), ('in', 'IN'), ('1815', 'CD'), ('and', 'CC'), ('the', 'DT'), ('onset', 'NN'), ('of', 'IN'), ('World', 'NNP'), ('War', 'NNP'), ('I', 'PRP'), ('in', 'IN'), ('1914', 'CD'), ('.', '.'), ('The', 'DT'), ('Civil', 'NNP'), ('War', 'NNP'), ('started', 'VBD'), ('because', 'IN'), ('of', 'IN'), ('uncompromising', 'VBG'), ('differences', 'NNS'), ('between', 'IN'), ('the', 'DT'), ('free', 'JJ'), ('and', 'CC'), ('slave', 'JJ'), ('states', 'NNS'), ('over', 'IN'), ('the', 'DT'), ('power', 'NN'), ('of', 'IN'), ('the', 'DT'), ('national', 'JJ'), ('government', 'NN'), ('to', 'TO'), ('prohibit', 'VB'), ('slavery', 'NN'), ('in', 'IN'), ('the', 'DT'), ('territories', 'NNS'), ('that', 'WDT'), ('had', 'VBD'), ('not', 'RB'), ('yet', 'RB'), ('become', 'VBN'), ('states', 'NNS'), ('.', '.'), ('When', 'WRB'), ('Abraham', 'NNP'), ('Lincoln', 'NNP'), ('won ...

# %% [markdown]
# ## Remove non-Alpha

# %%
# remove non-alpha entries
# print num of removed entries
print(f"Before removing non alpha characters, length is {len(text_tag)}")
# alpha words
text_alpha = [word for word in text_tokens if word.isalpha()]
# alpha entries with tag
text_tag_alpha = [entries for entries in text_tag if entries[0].isalpha()]
print(f"After removing non alpha characters, length is {len(text_tag_alpha)}\n")
print(text_tag_alpha)
# Out:
# Before removing non alpha characters, length is 852
# After removing non alpha characters, length is 759
#
# [('The', 'DT'), ('Civil', 'NNP'), ('War', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('central', 'JJ'), ('event', 'NN'), ('in', 'IN'), ('America', 'NNP'), ('historical', 'JJ'), ('consciousness', 'NN'), ('While', 'IN'), ('the', 'DT'), ('Revolution', 'NNP'), ('of', 'IN'), ('created', 'VBD'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('the', 'DT'), ('Civil', 'NNP'), ('War', 'NNP'), ('of', 'IN'), ('determined', 'VBD'), ('what', 'WP'), ('kind', 'NN'), ('of', 'IN'), ('nation', 'NN'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('The', 'DT'), ('war', 'NN'), ('resolved', 'VBD'), ('two', 'CD'), ('fundamental', 'JJ'), ('questions', 'NNS'), ('left', 'VBD'), ('unresolved', 'JJ'), ('by', 'IN'), ('the', 'DT'), ('revolution', 'NN'), ('whether', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('was', 'VBD'), ('to', 'TO'), ('be', 'VB'), ('a', 'DT'), ('dissolvable', 'JJ'), ('confederation', 'NN'), ('of', 'IN'), ('sovereign', 'JJ'), ('states', 'NNS'), ('or', 'CC'), ('an', 'DT'), ('indivisible', 'JJ'), ('nation', 'NN'), ('with', 'IN'), ('a', 'DT'), ('sovereign', 'JJ'), ('national', 'JJ'), ('government', 'NN'), ('and', 'CC'), ('whether', 'IN'), ('this', 'DT'), ('nation', 'NN'), ('born', 'VBN'), ('of', 'IN'), ('a', 'DT'), ('declaration', 'NN'), ('that', 'IN'), ('all', 'DT'), ('men', 'NNS'), ('were', 'VBD'), ('created', 'VBN'), ('with', 'IN'), ('an', 'DT'), ('equal', 'JJ'), ('right', 'NN'), ('to', 'TO'), ('liberty', 'VB'), ('would', 'MD'), ('continue', 'VB'), ('to', 'TO'), ('exist', 'VB'), ('as', 'IN'), ('the', 'DT'), ('largest', 'JJS'), ('slaveholding', 'VBG'), ('country', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('Northern', 'NNP'), ('victory', 'NN'), ('in', 'IN'), ('the', 'DT'), ('war', 'NN'), ('preserved', 'VBD'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('as', 'IN'), ('one', 'CD'), ('nation', 'NN'), ('and', 'CC'), ('ended', 'VBD'), ('the', 'DT'), ('institution', 'NN'), ('of', 'IN'), ('slavery', 'NN'), ('that', 'WDT'), ('had', 'VBD'), ('divided', 'VBN'), ('the', 'DT'), ('country', 'NN'), ('from', 'IN'), ('its', 'PRP$'), ('beginning', 'NN'), ('But', 'CC'), ('these', 'DT'), ('achievements', 'NNS'), ('came', 'VBD'), ('at', 'IN'), ('the', 'DT'), ('cost', 'NN'), ('of', 'IN'), ('lives', 'NNS'), ('nearly', 'RB'), ('as', 'RB'), ('many', 'JJ'), ('American', 'JJ'), ('soldiers', 'NNS'), ('as', 'IN'), ('died', 'VBN'), ('in', 'IN'), ('all', 'PDT'), ('the', 'DT'), ('other', 'JJ'), ('wars', 'NNS'), ('in', 'IN'), ('which', 'WDT'), ('this', 'DT'), ('country', 'NN'), ('has', 'VBZ'), ('fought', 'VBN'), ('combined', 'VBN'), ('The', 'DT'), ('American', 'JJ'), ('Civil', 'NNP'), ('War', 'NNP'), ('was', 'VBD'), ('the', 'DT'), ('largest', 'JJS'), ('and', 'CC'), ('most', 'RBS'), ('destructive', 'JJ'), ('conflict', 'NN'), ('in', 'IN'), ('the', 'DT'), ('Western', 'JJ'), ('world', 'NN'), ('between', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Napoleonic', 'NNP'), ('Wars', 'NNP'), ('in', 'IN'), ('and', 'CC'), ('the', 'DT'), ('onset', 'NN'), ('of', 'IN'), ('World', 'NNP'), ('War', 'NNP'), ('I', 'PRP'), ('in', 'IN'), ('The', 'DT'), ('Civil', 'NNP'), ('War', 'NNP'), ('started', 'VBD'), ('because', 'IN'), ('of', 'IN'), ('uncompromising', 'VBG'), ('differences', 'NNS'), ('between', 'IN'), ('the', 'DT'), ('free', 'JJ'), ('and', 'CC'), ('slave', 'JJ'), ('states', 'NNS'), ('over', 'IN'), ('the', 'DT'), ('power', 'NN'), ('of', 'IN'), ('the', 'DT'), ('national', 'JJ'), ('government', 'NN'), ('to', 'TO'), ('prohibit', 'VB'), ('slavery', 'NN'), ('in', 'IN'), ('the', 'DT'), ('territories', 'NNS'), ('that', 'WDT'), ('had', 'VBD'), ('not', 'RB'), ('yet', 'RB'), ('become', 'VBN'), ('states', 'NNS'), ('When', 'WRB'), ('Abraham', 'NNP'), ('Lincoln', 'NNP'), ('won', 'VBD'), ('election', 'NN'), ('in', 'IN'), ('as', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('Republican', 'NNP'), ('president', 'NN'), ('on', 'IN'), ('a', 'DT'), ('platform', 'NN'), ('pledging', 'NN'), ('to', 'TO'), ('keep', 'VB'), ('slavery', 'NN'), ('out', 'IN'), ...

# %% [markdown]
# ## Store normalized token and remove duplicates

# %%
# use Porter2 Stemmer
s_stemmer = SnowballStemmer(language='english')

# %%
# normalize and remove duplicates
normalized_text_alpha = [s_stemmer.stem(word) for word in text_alpha]
normalized_text_alpha_noDup = list(set(normalized_text_alpha))
# display difference
print(f"{len(normalized_text_alpha) - len(normalized_text_alpha_noDup)} duplicates removed\n")
print(len(normalized_text_alpha))
print()
print(normalized_text_alpha_noDup)
# Out:
# 439 duplicates removed
#
# 759
#
# ['becaus', 'cold', 'recogn', 'an', 'chief', 'ineffect', 'cape', 'be', 'liberti', 'had', 'free', 'april', 'call', 'atlanta', 'discredit', 'onset', 'they', 'bloodi', 'invas', 'meantim', 'has', 'militia', 'nation', 'campaign', 'restor', 'arm', 'infrastructur', 'antietam', 'while', 'trigger', 'manassa', 'ulyss', 'central', 'was', 'keep', 'econom', 'presid', 'yet', 'thoma', 'junction', 'gettysburg', 'begin', 'mani', 'that', 'pain', 'mile', 'resist', 'surrend', 'war', 'join', 'i', 'institut', 'at', 'govern', 'may', 'won', 'base', 'two', 'pledg', 'along', 'cost', 'foreshadow', 'line', 'sumter', 'would', 'determin', 'unit', 'give', 'georgia', 'insurrect', 'territori', 'secess', 'largest', 'dissolv', 'fredericksburg', 'all', 'appalachian', 'democraci', 'lee', 'american', 'confeder', 'fear', 'davi', 'new', 'fatal', 'left', 'the', 'own', 'huge', 'sever', 'western', 'name', 'administr', 'slavehold', 'refus', 'establish', 'seced', 'subsequ', 'there', 'start', 'brought', 'unresolv', 'west', 'his', 'real', 'royal', 'by', 'histor', 'divid', 'mountain', 'these', 'forc', 'until', 'form', 'feder', 'out', 'civil', 'birth', 'georg', 'bigger', 'general', 'die', 'attack', 'hattera', 'right', 'seven', 'republican', 'alreadi', 'for', 'into', 'tecumseh', 'command', 'origin', 'came', 'spotsylvania', 'cavalri', 'vicksburg', 'south', 'off', 'a', 'slave', 'robert', 'world', 'between', 'strategi', 'way', 'goal', 'dedic', 'conflict', 'fort', 'indivis', 'event', 'soldier', 'stretch', 'squabbl', 'wilder', 'conscious', 'captur', 'whether', 'were', 'one', 'basic', 'when', 'from', 'countri', 'each', 'gain', 'total', 'preserv', 'fleet', 'america', 'other', 'place', 'compris', 'theater', 'slaveri', 'which', 'abraham', 'stave', 'nashvill', 'appomattox', 'suppress', 'to', 'limit', 'prohibit', 'incom', 'achiev', 'carolina', 'what', 'given', 'tennesse', 'final', 'live', 'like', 'confederaci', 'potomac', 'this', 'river', 'navi', 'flag', 'declar', 'platform', 'their', 'destruct', 'second', 'northern', 'end', 'more', 'virginia', 'elect', 'fundament', 'with', 'shut', 'creation', 'garrison', 'over', 'kill', 'on', 'it', 'creat', 'fire', 'year', 'fight', 'sherman', 'taken', 'port', 'process', 'lincoln', 'charleston', 'born', 'open', 'freedom', 'mississippi', 'after', 'destroy', 'access', 'outsid', 'revolut', 'kind', 'rebuild', 'question', 'continu', 'william', 'combin', 'union', 'armi', 'day', 'napoleon', 'peopl', 'mill', 'or', 'lower', 'uncompromis', 'hapless', 'eventu', 'began', 'harbor', 'legitimaci', 'put', 'of', 'claim', 'pennsylvania', 'north', 'heartland', 'small', 'battl', 'victori', 'fought', 'creek', 'spring', 'cemeteri', 'collaps', 'jefferson', 'even', 'flee', 'pave', 'men', 'but', 'million', 'long', 'and', 'in', 'differ', 'bay', 'three', 'virtual', 'equal', 'near', 'chain', 'led', 'sovereign', 'resolv', 'confront', 'deep', 'wilson', 'seri', 'unlucki', 'as', 'old', 'fragment', 'where', 'not', 'blockad', 'petersburg', 'preced', 'address', 'is', 'four', 'state', 'grant', 'becom', 'first', 'power', 'chickamauga', 'princip', 'exist', 'shiloh', 'most', 'missouri', 'maryland']

# %% [markdown]
# ## Chunking using customized Grammar

# %%
# reference
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %%
"""
Grammar:
    1. his/her(PRP$)/the(DT)/a(LS) adj(JJ) noun(NN_)     {[<PRP$><DT><LS>]?<JJ>?<NN>+}
    2. cannot(MD) verb(VB)
    3. all(PDT) noun(NN_)
    4. be(VB_) doing(VBG)
    5. has(VB_) adv(RB) done(VBD)
    6. adv(RB) verb(VB|VBZ) {<RB>?[<VB><VBZ>]}
    7. was(VB_) taken(VBN)
    

"""
#seq = """
#    Chunk:
#    {<NNP>+}
#    {<NN>+}"""
seq = """
    Chunk:
    {<MD>?<VB>}
    {<PDT>?<JJ>?<NN>+}
    {(<VB>|<VBZ>)<VBG>}
    {(<VB>|<VBZ>)<RB>?<VBD>}
    {<VBD><VBN>}"""
chunker = nltk.RegexpParser(seq)

# %%
# print result
chunk_result = chunker.parse(text_tag_alpha)
for item in chunk_result:
    print(item, type(item))
# Out:
# ('The', 'DT') <class 'tuple'>
# ('Civil', 'NNP') <class 'tuple'>
# ('War', 'NNP') <class 'tuple'>
# ('is', 'VBZ') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk central/JJ event/NN) <class 'nltk.tree.Tree'>
# ('in', 'IN') <class 'tuple'>
# ('America', 'NNP') <class 'tuple'>
# (Chunk historical/JJ consciousness/NN) <class 'nltk.tree.Tree'>
# ('While', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Revolution', 'NNP') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('created', 'VBD') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('United', 'NNP') <class 'tuple'>
# ('States', 'NNPS') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Civil', 'NNP') <class 'tuple'>
# ('War', 'NNP') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('determined', 'VBD') <class 'tuple'>
# ('what', 'WP') <class 'tuple'>
# (Chunk kind/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# (Chunk nation/NN) <class 'nltk.tree.Tree'>
# ('it', 'PRP') <class 'tuple'>
# (Chunk would/MD be/VB) <class 'nltk.tree.Tree'>
# ('The', 'DT') <class 'tuple'>
# (Chunk war/NN) <class 'nltk.tree.Tree'>
# ('resolved', 'VBD') <class 'tuple'>
# ('two', 'CD') <class 'tuple'>
# ('fundamental', 'JJ') <class 'tuple'>
# ('questions', 'NNS') <class 'tuple'>
# ('left', 'VBD') <class 'tuple'>
# ('unresolved', 'JJ') <class 'tuple'>
# ('by', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk revolution/NN) <class 'nltk.tree.Tree'>
# ('whether', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('United', 'NNP') <class 'tuple'>
# ('States', 'NNPS') <class 'tuple'>
# ('was', 'VBD') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# (Chunk be/VB) <class 'nltk.tree.Tree'>
# ('a', 'DT') <class 'tuple'>
# (Chunk dissolvable/JJ confederation/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('sovereign', 'JJ') <class 'tuple'>
# ('states', 'NNS') <class 'tuple'>
# ('or', 'CC') <class 'tuple'>
# ('an', 'DT') <class 'tuple'>
# (Chunk indivisible/JJ nation/NN) <class 'nltk.tree.Tree'>
# ('with', 'IN') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# ('sovereign', 'JJ') <class 'tuple'>
# (Chunk national/JJ government/NN) <class 'nltk.tree.Tree'>
# ('and', 'CC') <class 'tuple'>
# ('whether', 'IN') <class 'tuple'>
# ('this', 'DT') <class 'tuple'>
# (Chunk nation/NN) <class 'nltk.tree.Tree'>
# ('born', 'VBN') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk declaration/NN) <class 'nltk.tree.Tree'>
# ('that', 'IN') <class 'tuple'>
# ('all', 'DT') <class 'tuple'>
# ('men', 'NNS') <class 'tuple'>
# (Chunk were/VBD created/VBN) <class 'nltk.tree.Tree'>
# ('with', 'IN') <class 'tuple'>
# ('an', 'DT') <class 'tuple'>
# (Chunk equal/JJ right/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk liberty/VB) <class 'nltk.tree.Tree'>
# (Chunk would/MD continue/VB) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk exist/VB) <class 'nltk.tree.Tree'>
# ('as', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('largest', 'JJS') <class 'tuple'>
# ('slaveholding', 'VBG') <class 'tuple'>
# (Chunk country/NN) <class 'nltk.tree.Tree'>
# ('in', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk world/NN) <class 'nltk.tree.Tree'>
# ('Northern', 'NNP') <class 'tuple'>
# (Chunk victory/NN) <class 'nltk.tree.Tree'>
# ('in', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk war/NN) <class 'nltk.tree.Tree'>
# ('preserved', 'VBD') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('United', 'NNP') <class 'tuple'>
# ('States', 'NNPS') <class 'tuple'>
# ('as', 'IN') <class 'tuple'>
# ('one', 'CD') <class 'tuple'>
# (Chunk nation/NN) <class 'nltk.tree.Tree'>
# ('and', 'CC') <class 'tuple'>
# ('ended', 'VBD') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk institution/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# (Chunk slavery/NN) <class 'nltk.tree.Tree'>
# ('that', 'WDT') <class 'tuple'>
# (Chunk had/VBD divided/VBN) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# (Chunk country/NN) <class 'nltk.tree.Tree'>
# ('from', 'IN') <class 'tuple'>
# ('its', 'PRP$') <class 'tuple'>
# (Chunk beginning/NN) <class 'nltk.tree.Tree'>
# ('But', 'CC') <class 'tuple'>
# ('these', 'DT') <class 'tuple'>
# ('achievements', 'NNS') <class 'tuple'>
# ('came', 'VBD') <class 'tuple'>
# ('at', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk cost/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('lives', 'NNS') <class 'tuple'>
# ('nearly', 'RB') <class 'tuple'>
# ('as', 'RB') <class 'tuple'>
# ('many', 'JJ') <class 'tuple'>
# ('American', 'JJ') <class 'tuple'>
# ('soldiers', 'NNS') <class 'tuple'>
# ('as', 'IN') <class 'tuple'>
# ('died', 'VBN') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('all', 'PDT') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('other', 'JJ') <class 'tuple'>
# ('wars', 'NNS') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('which', 'WDT') <class 'tuple'>
# ('this', 'DT') <class 'tuple'>
# (Chunk country/NN) <class 'nltk.tree.Tree'>
# ('has', 'VBZ') <class 'tuple'>
# ('fought', 'VBN') <class 'tuple'>
# ('combined', 'VBN') <class 'tuple'>
# ('The', 'DT') <class 'tuple'>
# ('American', 'JJ') <class 'tuple'>
# ('Civil', 'NNP') <class 'tuple'>
# ('War', 'NNP') <class 'tuple'>
# ('was', 'VBD') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('largest', 'JJS') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('most', 'RBS') <class 'tuple'>
# (Chunk destructive/JJ conflict/NN) <class 'nltk.tree.Tree'>
# ('in', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk Western/JJ world/NN) <class 'nltk.tree.Tree'>
# ('between', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk end/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Napoleonic', 'NNP') <class 'tuple'>
# ('Wars', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk onset/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('World', 'NNP') <class 'tuple'>
# ('War', 'NNP') <class 'tuple'>
# ('I', 'PRP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('The', 'DT') <class 'tuple'>
# ('Civil', 'NNP') <class 'tuple'>
# ('War', 'NNP') <class 'tuple'>
# ('started', 'VBD') <class 'tuple'>
# ('because', 'IN') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('uncompromising', 'VBG') <class 'tuple'>
# ('differences', 'NNS') <class 'tuple'>
# ('between', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('free', 'JJ') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('slave', 'JJ') <class 'tuple'>
# ('states', 'NNS') <class 'tuple'>
# ('over', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk power/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk national/JJ government/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk prohibit/VB) <class 'nltk.tree.Tree'>
# (Chunk slavery/NN) <class 'nltk.tree.Tree'>
# ('in', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('territories', 'NNS') <class 'tuple'>
# ('that', 'WDT') <class 'tuple'>
# ('had', 'VBD') <class 'tuple'>
# ('not', 'RB') <class 'tuple'>
# ('yet', 'RB') <class 'tuple'>
# ('become', 'VBN') <class 'tuple'>
# ('states', 'NNS') <class 'tuple'>
# ('When', 'WRB') <class 'tuple'>
# ('Abraham', 'NNP') <class 'tuple'>
# ('Lincoln', 'NNP') <class 'tuple'>
# ('won', 'VBD') <class 'tuple'>
# (Chunk election/NN) <class 'nltk.tree.Tree'>
# ('in', 'IN') <class 'tuple'>
# ('as', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('first', 'JJ') <class 'tuple'>
# ('Republican', 'NNP') <class 'tuple'>
# (Chunk president/NN) <class 'nltk.tree.Tree'>
# ('on', 'IN') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk platform/NN pledging/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk keep/VB) <class 'nltk.tree.Tree'>
# (Chunk slavery/NN) <class 'nltk.tree.Tree'>
# ('out', 'IN') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('territories', 'NNS') <class 'tuple'>
# ('seven', 'CD') <class 'tuple'>
# ('slave', 'VBP') <class 'tuple'>
# ('states', 'NNS') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('deep', 'JJ') <class 'tuple'>
# ('South', 'NNP') <class 'tuple'>
# ('seceded', 'VBD') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('formed', 'VBD') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk new/JJ nation/NN) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# ('Confederate', 'NNP') <class 'tuple'>
# ('States', 'NNPS') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('America', 'NNP') <class 'tuple'>
# ('The', 'DT') <class 'tuple'>
# ('incoming', 'VBG') <class 'tuple'>
# ('Lincoln', 'NNP') <class 'tuple'>
# (Chunk administration/NN) <class 'nltk.tree.Tree'>
# ('and', 'CC') <class 'tuple'>
# ('most', 'JJS') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Northern', 'NNP') <class 'tuple'>
# ('people', 'NNS') <class 'tuple'>
# ('refused', 'VBD') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# (Chunk recognize/VB) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# (Chunk legitimacy/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# (Chunk secession/NN) <class 'nltk.tree.Tree'>
# ('They', 'PRP') <class 'tuple'>
# ('feared', 'VBD') <class 'tuple'>
# ('that', 'IN') <class 'tuple'>
# ('it', 'PRP') <class 'tuple'>
# (Chunk would/MD discredit/VB) <class 'nltk.tree.Tree'>
# (Chunk democracy/NN) <class 'nltk.tree.Tree'>
# ('and', 'CC') <class 'tuple'>
# (Chunk create/VB) <class 'nltk.tree.Tree'>
# ('a', 'DT') <class 'tuple'>
# (Chunk fatal/JJ precedent/NN) <class 'nltk.tree.Tree'>
# ('that', 'WDT') <class 'tuple'>
# ('would', 'MD') <class 'tuple'>
# ('eventually', 'RB') <class 'tuple'>
# (Chunk fragment/VB) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# ('United', 'NNP') <class 'tuple'>
# ('States', 'NNPS') <class 'tuple'>
# ('into', 'IN') <class 'tuple'>
# ('several', 'JJ') <class 'tuple'>
# ('small', 'JJ') <class 'tuple'>
# ('squabbling', 'JJ') <class 'tuple'>
# ('countries', 'NNS') <class 'tuple'>
# ('The', 'DT') <class 'tuple'>
# (Chunk event/NN) <class 'nltk.tree.Tree'>
# ('that', 'WDT') <class 'tuple'>
# ('triggered', 'VBD') <class 'tuple'>
# (Chunk war/NN) <class 'nltk.tree.Tree'>
# ('came', 'VBD') <class 'tuple'>
# ('at', 'IN') <class 'tuple'>
# ('Fort', 'NNP') <class 'tuple'>
# ('Sumter', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Charleston', 'NNP') <class 'tuple'>
# ('Bay', 'NNP') <class 'tuple'>
# ('on', 'IN') <class 'tuple'>
# ('April', 'NNP') <class 'tuple'>
# ('Claiming', 'VBG') <class 'tuple'>
# ('this', 'DT') <class 'tuple'>
# ('United', 'NNP') <class 'tuple'>
# ('States', 'NNPS') <class 'tuple'>
# ('fort', 'RB') <class 'tuple'>
# ('as', 'IN') <class 'tuple'>
# ('their', 'PRP$') <class 'tuple'>
# ('own', 'JJ') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Confederate', 'NNP') <class 'tuple'>
# (Chunk army/NN) <class 'nltk.tree.Tree'>
# ('on', 'IN') <class 'tuple'>
# ('that', 'DT') <class 'tuple'>
# (Chunk day/NN) <class 'nltk.tree.Tree'>
# ('opened', 'VBD') <class 'tuple'>
# (Chunk fire/NN) <class 'nltk.tree.Tree'>
# ('on', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk federal/JJ garrison/NN) <class 'nltk.tree.Tree'>
# ('and', 'CC') <class 'tuple'>
# ('forced', 'VBD') <class 'tuple'>
# ('it', 'PRP') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# (Chunk lower/VB) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# (Chunk American/JJ flag/NN) <class 'nltk.tree.Tree'>
# ('in', 'IN') <class 'tuple'>
# (Chunk surrender/NN) <class 'nltk.tree.Tree'>
# ('Lincoln', 'NNP') <class 'tuple'>
# ('called', 'VBD') <class 'tuple'>
# ('out', 'RP') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk militia/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk suppress/VB) <class 'nltk.tree.Tree'>
# ('this', 'DT') <class 'tuple'>
# (Chunk insurrection/NN) <class 'nltk.tree.Tree'>
# ('Four', 'CD') <class 'tuple'>
# ('more', 'JJR') <class 'tuple'>
# (Chunk slave/NN) <class 'nltk.tree.Tree'>
# ('states', 'NNS') <class 'tuple'>
# ('seceded', 'VBD') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('joined', 'VBD') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Confederacy', 'NNP') <class 'tuple'>
# ('By', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk end/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('nearly', 'RB') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# ('million', 'CD') <class 'tuple'>
# ('armed', 'VBN') <class 'tuple'>
# ('men', 'NNS') <class 'tuple'>
# ('confronted', 'VBN') <class 'tuple'>
# ('each', 'DT') <class 'tuple'>
# ('other', 'JJ') <class 'tuple'>
# ('along', 'IN') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk line/NN) <class 'nltk.tree.Tree'>
# ('stretching', 'VBG') <class 'tuple'>
# ('miles', 'NNS') <class 'tuple'>
# ('from', 'IN') <class 'tuple'>
# ('Virginia', 'NNP') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# ('Missouri', 'NNP') <class 'tuple'>
# ('Several', 'JJ') <class 'tuple'>
# ('battles', 'NNS') <class 'tuple'>
# ('had', 'VBD') <class 'tuple'>
# ('already', 'RB') <class 'tuple'>
# ('taken', 'VBN') <class 'tuple'>
# (Chunk place/NN) <class 'nltk.tree.Tree'>
# ('near', 'IN') <class 'tuple'>
# ('Manassas', 'NNP') <class 'tuple'>
# ('Junction', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Virginia', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('mountains', 'NNS') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('western', 'JJ') <class 'tuple'>
# ('Virginia', 'NNP') <class 'tuple'>
# ('where', 'WRB') <class 'tuple'>
# ('Union', 'NNP') <class 'tuple'>
# (Chunk victories/VBZ paved/VBD) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# (Chunk way/NN) <class 'nltk.tree.Tree'>
# ('for', 'IN') <class 'tuple'>
# (Chunk creation/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk new/JJ state/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('West', 'NNP') <class 'tuple'>
# ('Virginia', 'NNP') <class 'tuple'>
# ('at', 'IN') <class 'tuple'>
# ('Wilson', 'NNP') <class 'tuple'>
# ('Creek', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Missouri', 'NNP') <class 'tuple'>
# ('at', 'IN') <class 'tuple'>
# ('Cape', 'NNP') <class 'tuple'>
# ('Hatteras', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('North', 'NNP') <class 'tuple'>
# ('Carolina', 'NNP') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('at', 'IN') <class 'tuple'>
# ('Port', 'NNP') <class 'tuple'>
# ('Royal', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('South', 'NNP') <class 'tuple'>
# ('Carolina', 'NNP') <class 'tuple'>
# ('where', 'WRB') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Union', 'NNP') <class 'tuple'>
# ('navy', 'NNP') <class 'tuple'>
# ('established', 'VBD') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk base/NN) <class 'nltk.tree.Tree'>
# ('for', 'IN') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk blockade/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk shut/VB) <class 'nltk.tree.Tree'>
# ('off', 'RP') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Confederacy', 'NNP') <class 'tuple'>
# (Chunk access/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk outside/JJ world/NN) <class 'nltk.tree.Tree'>
# ('But', 'CC') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk real/JJ fighting/NN) <class 'nltk.tree.Tree'>
# ('began', 'VBD') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Huge', 'JJ') <class 'tuple'>
# ('battles', 'NNS') <class 'tuple'>
# ('like', 'IN') <class 'tuple'>
# ('Shiloh', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Tennessee', 'NNP') <class 'tuple'>
# ('Gaines', 'NNP') <class 'tuple'>
# ('Mill', 'NNP') <class 'tuple'>
# ('Second', 'NNP') <class 'tuple'>
# ('Manassas', 'NNP') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('Fredericksburg', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Virginia', 'NNP') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('Antietam', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Maryland', 'NNP') <class 'tuple'>
# ('foreshadowed', 'VBD') <class 'tuple'>
# ('even', 'RB') <class 'tuple'>
# ('bigger', 'JJR') <class 'tuple'>
# ('campaigns', 'NNS') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('battles', 'NNS') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('subsequent', 'JJ') <class 'tuple'>
# ('years', 'NNS') <class 'tuple'>
# ('from', 'IN') <class 'tuple'>
# ('Gettysburg', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Pennsylvania', 'NNP') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# (Chunk Vicksburg/VB) <class 'nltk.tree.Tree'>
# ('on', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Mississippi', 'NNP') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# ('Chickamauga', 'NNP') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('Atlanta', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Georgia', 'NNP') <class 'tuple'>
# ('By', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('original', 'JJ') <class 'tuple'>
# ('Northern', 'NNP') <class 'tuple'>
# (Chunk goal/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk limited/JJ war/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk restore/VB) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# ('Union', 'NNP') <class 'tuple'>
# (Chunk had/VBD given/VBN) <class 'nltk.tree.Tree'>
# (Chunk way/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk new/JJ strategy/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# (Chunk total/JJ war/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk destroy/VB) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# ('Old', 'NNP') <class 'tuple'>
# ('South', 'NNP') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('its', 'PRP$') <class 'tuple'>
# (Chunk basic/JJ institution/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# (Chunk slavery/NN) <class 'nltk.tree.Tree'>
# ('and', 'CC') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# (Chunk give/VB) <class 'nltk.tree.Tree'>
# ('the', 'DT') <class 'tuple'>
# ('restored', 'VBN') <class 'tuple'>
# ('Union', 'NNP') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk new/JJ birth/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# (Chunk freedom/NN) <class 'nltk.tree.Tree'>
# ('as', 'IN') <class 'tuple'>
# ('President', 'NNP') <class 'tuple'>
# ('Lincoln', 'NNP') <class 'tuple'>
# ('put', 'VBD') <class 'tuple'>
# ('it', 'PRP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('his', 'PRP$') <class 'tuple'>
# (Chunk address/NN) <class 'nltk.tree.Tree'>
# ('at', 'IN') <class 'tuple'>
# ('Gettysburg', 'NNP') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# (Chunk dedicate/VB) <class 'nltk.tree.Tree'>
# ('a', 'DT') <class 'tuple'>
# (Chunk cemetery/NN) <class 'nltk.tree.Tree'>
# ('for', 'IN') <class 'tuple'>
# ('Union', 'NNP') <class 'tuple'>
# ('soldiers', 'NNS') <class 'tuple'>
# ('killed', 'VBD') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk battle/NN) <class 'nltk.tree.Tree'>
# ('there', 'RB') <class 'tuple'>
# ('For', 'IN') <class 'tuple'>
# ('three', 'CD') <class 'tuple'>
# ('long', 'JJ') <class 'tuple'>
# ('years', 'NNS') <class 'tuple'>
# ('from', 'IN') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# ('Robert', 'NNP') <class 'tuple'>
# ('Lee', 'NNP') <class 'tuple'>
# ('Army', 'NNP') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('Northern', 'NNP') <class 'tuple'>
# ('Virginia', 'NNP') <class 'tuple'>
# ('staved', 'VBD') <class 'tuple'>
# ('off', 'RP') <class 'tuple'>
# ('invasions', 'NNS') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('attacks', 'NNS') <class 'tuple'>
# ('by', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Union', 'NNP') <class 'tuple'>
# ('Army', 'NNP') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Potomac', 'NNP') <class 'tuple'>
# ('commanded', 'VBN') <class 'tuple'>
# ('by', 'IN') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk series/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('ineffective', 'JJ') <class 'tuple'>
# ('generals', 'NNS') <class 'tuple'>
# ('until', 'IN') <class 'tuple'>
# ('Ulysses', 'NNP') <class 'tuple'>
# ('Grant', 'NNP') <class 'tuple'>
# ('came', 'VBD') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# ('Virginia', 'NNP') <class 'tuple'>
# ('from', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk Western/JJ theater/NN) <class 'nltk.tree.Tree'>
# ('to', 'TO') <class 'tuple'>
# (Chunk become/VB) <class 'nltk.tree.Tree'>
# ('general', 'JJ') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# (Chunk chief/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('all', 'DT') <class 'tuple'>
# ('Union', 'NNP') <class 'tuple'>
# ('armies', 'NNS') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('After', 'IN') <class 'tuple'>
# ('bloody', 'JJ') <class 'tuple'>
# ('battles', 'NNS') <class 'tuple'>
# ('at', 'IN') <class 'tuple'>
# ('places', 'NNS') <class 'tuple'>
# ('with', 'IN') <class 'tuple'>
# ('names', 'NNS') <class 'tuple'>
# ('like', 'IN') <class 'tuple'>
# ('The', 'DT') <class 'tuple'>
# ('Wilderness', 'NNP') <class 'tuple'>
# ('Spotsylvania', 'NNP') <class 'tuple'>
# ('Cold', 'NNP') <class 'tuple'>
# ('Harbor', 'NNP') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('Petersburg', 'NNP') <class 'tuple'>
# ('Grant', 'NNP') <class 'tuple'>
# ('finally', 'RB') <class 'tuple'>
# ('brought', 'VBD') <class 'tuple'>
# ('Lee', 'NNP') <class 'tuple'>
# ('to', 'TO') <class 'tuple'>
# (Chunk bay/VB) <class 'nltk.tree.Tree'>
# ('at', 'IN') <class 'tuple'>
# ('Appomattox', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('April', 'NNP') <class 'tuple'>
# ('In', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk meantime/NN) <class 'nltk.tree.Tree'>
# ('Union', 'NNP') <class 'tuple'>
# ('armies', 'NNS') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# (Chunk river/NN) <class 'nltk.tree.Tree'>
# ('fleets', 'NNS') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk theater/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# (Chunk war/NN) <class 'nltk.tree.Tree'>
# ('comprising', 'VBG') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk slave/NN) <class 'nltk.tree.Tree'>
# ('states', 'VBZ') <class 'tuple'>
# ('west', 'JJS') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Appalachian', 'NNP') <class 'tuple'>
# ('Mountain', 'NNP') <class 'tuple'>
# (Chunk chain/NN) <class 'nltk.tree.Tree'>
# ('won', 'VBD') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk long/JJ series/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('victories', 'NNS') <class 'tuple'>
# ('over', 'IN') <class 'tuple'>
# ('Confederate', 'NNP') <class 'tuple'>
# ('armies', 'NNS') <class 'tuple'>
# ('commanded', 'VBN') <class 'tuple'>
# ('by', 'IN') <class 'tuple'>
# (Chunk hapless/NN) <class 'nltk.tree.Tree'>
# ('or', 'CC') <class 'tuple'>
# ('unlucky', 'JJ') <class 'tuple'>
# ('Confederate', 'NNP') <class 'tuple'>
# ('generals', 'NNS') <class 'tuple'>
# ('In', 'IN') <class 'tuple'>
# ('General', 'NNP') <class 'tuple'>
# ('William', 'NNP') <class 'tuple'>
# ('Tecumseh', 'NNP') <class 'tuple'>
# ('Sherman', 'NNP') <class 'tuple'>
# ('led', 'VBD') <class 'tuple'>
# ('his', 'PRP$') <class 'tuple'>
# (Chunk army/NN) <class 'nltk.tree.Tree'>
# ('deep', 'RB') <class 'tuple'>
# ('into', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Confederate', 'NNP') <class 'tuple'>
# (Chunk heartland/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('Georgia', 'NNP') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('South', 'NNP') <class 'tuple'>
# ('Carolina', 'NNP') <class 'tuple'>
# ('destroying', 'VBG') <class 'tuple'>
# ('their', 'PRP$') <class 'tuple'>
# (Chunk economic/JJ infrastructure/NN) <class 'nltk.tree.Tree'>
# ('while', 'IN') <class 'tuple'>
# ('General', 'NNP') <class 'tuple'>
# ('George', 'NNP') <class 'tuple'>
# ('Thomas', 'NNP') <class 'tuple'>
# ('virtually', 'RB') <class 'tuple'>
# ('destroyed', 'VBD') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('Confederacy', 'NNP') <class 'tuple'>
# ('Army', 'NNP') <class 'tuple'>
# ('of', 'IN') <class 'tuple'>
# ('Tennessee', 'NNP') <class 'tuple'>
# ('at', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk battle/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('Nashville', 'NNP') <class 'tuple'>
# ('By', 'IN') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk spring/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('all', 'PDT') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('principal', 'JJ') <class 'tuple'>
# ('Confederate', 'NNP') <class 'tuple'>
# ('armies', 'NNS') <class 'tuple'>
# ('surrendered', 'VBD') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('when', 'WRB') <class 'tuple'>
# ('Union', 'NNP') <class 'tuple'>
# (Chunk cavalry/NN) <class 'nltk.tree.Tree'>
# ('captured', 'VBD') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# ('fleeing', 'JJ') <class 'tuple'>
# ('Confederate', 'NNP') <class 'tuple'>
# ('President', 'NNP') <class 'tuple'>
# ('Jefferson', 'NNP') <class 'tuple'>
# ('Davis', 'NNP') <class 'tuple'>
# ('in', 'IN') <class 'tuple'>
# ('Georgia', 'NNP') <class 'tuple'>
# ('on', 'IN') <class 'tuple'>
# ('May', 'NNP') <class 'tuple'>
# (Chunk resistance/NN) <class 'nltk.tree.Tree'>
# ('collapsed', 'VBD') <class 'tuple'>
# ('and', 'CC') <class 'tuple'>
# ('the', 'DT') <class 'tuple'>
# (Chunk war/NN) <class 'nltk.tree.Tree'>
# ('ended', 'VBD') <class 'tuple'>
# ('The', 'DT') <class 'tuple'>
# ('long', 'JJ') <class 'tuple'>
# (Chunk painful/JJ process/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# ('rebuilding', 'VBG') <class 'tuple'>
# ('a', 'DT') <class 'tuple'>
# (Chunk united/JJ nation/NN free/NN) <class 'nltk.tree.Tree'>
# ('of', 'IN') <class 'tuple'>
# (Chunk slavery/NN) <class 'nltk.tree.Tree'>
# ('began', 'VBD') <class 'tuple'>

# %% [markdown]
# # Spacy

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)

# %%
for chunk in doc.noun_chunks:
    print(f'{chunk.text:{25}} {chunk.root.text:{6}} {chunk.root.dep_:<{22}} {chunk.root.head.text}')
# Out:
# The Civil War             War    nsubj                  is
# the central event         event  attr                   is
# America's historical consciousness consciousness pobj                   in
# the Revolution            Revolution nsubj                  created
# the United States         States dobj                   created
# the Civil War             War    appos                  States
# what kind                 kind   attr                   be
# nation                    nation pobj                   of
# it                        it     nsubj                  be
# The war                   war    nsubj                  resolved
# two fundamental questions questions dobj                   resolved
# the revolution            revolution pobj                   by
# the United States         States nsubj                  was
# a dissolvable confederation confederation attr                   be
# sovereign states          states pobj                   of
# an indivisible nation     nation conj                   states
# a sovereign national government government pobj                   with
# this nation               nation nsubj                  continue
# a declaration             declaration pobj                   of
# all men                   men    nsubjpass              created
# an equal right            right  pobj                   with
# liberty                   liberty pobj                   to
# the largest slaveholding country country pobj                   as
# the world                 world  pobj                   in
# Northern victory          victory nsubj                  preserved
# the war                   war    pobj                   in
# the United States         States dobj                   preserved
# one nation                nation pobj                   as
# the institution           institution dobj                   ended
# slavery                   slavery pobj                   of
# the country               country dobj                   divided
# its beginning             beginning pobj                   from
# these achievements        achievements nsubj                  came
# the cost                  cost   pobj                   at
# 625,000 lives             lives  pobj                   of
# nearly as many American soldiers soldiers nsubj                  died
# all the other wars        wars   pobj                   in
# this country              country nsubj                  fought
# The American Civil War    War    nsubj                  was
# the largest and most destructive conflict conflict attr                   was
# the Western world         world  pobj                   in
# the end                   end    pobj                   between
# the Napoleonic Wars       Wars   pobj                   of
# the onset                 onset  conj                   conflict
# World War I               I      pobj                   of
# The Civil War             War    nsubj                  started
# differences               differences dobj                   uncompromising
# the free and slave states states pobj                   between
# the power                 power  pobj                   over
# the national government   government pobj                   of
# slavery                   slavery dobj                   prohibit
# the territories           territories pobj                   in
# states                    states attr                   become
# Abraham Lincoln           Lincoln nsubj                  won
# election                  election dobj                   won
# the first Republican president president pobj                   as
# a platform                platform pobj                   on
# slavery                   slavery dobj                   keep
# the territories           territories pobj                   of
# seven slave states        states nsubj                  seceded
# the deep South            South  pobj                   in
# a new nation              nation dobj                   formed
# the Confederate States    States dobj                   formed
# America                   America pobj                   of
# The incoming Lincoln administration administration nsubj                  refused
# the Northern people       people pobj                   of
# the legitimacy            legitimacy dobj                   recognize
# secession                 secession pobj                   of
# They                      They   nsubj                  feared
# it                        it     nsubj                  discredit
# democracy                 democracy dobj                   discredit
# a fatal precedent         precedent dobj                   create
# the no-longer United States States dobj                   fragment
# several small, squabbling countries countries pobj                   into
# The event                 event  nsubj                  came
# war                       war    dobj                   triggered
# Fort Sumter               Sumter pobj                   at
# Charleston Bay            Bay    pobj                   in
# April                     April  pobj                   on
# this United States fort   fort   dobj                   Claiming
# the Confederate army      army   nsubj                  opened
# that day                  day    pobj                   on
# fire                      fire   dobj                   opened
# the federal garrison      garrison pobj                   on
# it                        it     dobj                   forced
# the American flag         flag   dobj                   lower
# surrender                 surrender pobj                   in
# Lincoln                   Lincoln nsubj                  called
# the militia               militia dobj                   called
# this "insurrection        insurrection dobj                   suppress
# Four more slave states    states nsubj                  seceded
# the Confederacy           Confederacy dobj                   joined
# the end                   end    pobj                   By
# nearly a million armed men men    pobj                   of
# a line                    line   pobj                   along
# Virginia                  Virginia pobj                   from
# Missouri                  Missouri pobj                   to
# Several battles           battles nsubj                  taken
# place                     place  dobj                   taken
# Manassas Junction         Junction pobj                   near
# Virginia                  Virginia pobj                   in
# the mountains             mountains pobj                   in
# western Virginia          Virginia pobj                   of
# Union victories           victories nsubj                  paved
# the way                   way    dobj                   paved
# creation                  creation pobj                   for
# the new state             state  pobj                   of
# West Virginia             Virginia pobj                   of
# Wilson's Creek            Creek  pobj                   at
# Missouri                  Missouri pobj                   in
# Cape Hatteras             Hatteras pobj                   at
# North Carolina            Carolina pobj                   in
# Port Royal                Royal  pobj                   at
# South Carolina            Carolina pobj                   in
# the Union navy            navy   nsubj                  established
# a base                    base   dobj                   established
# a blockade                blockade pobj                   for
# the Confederacy's access  access dobj                   shut
# the outside world         world  pobj                   to
# the real fighting         fighting nsubj                  began
# Huge battles              battles nsubj                  foreshadowed
# Shiloh                    Shiloh pobj                   like
# Tennessee                 Tennessee pobj                   in
# Gaines' Mill, Second Manassas Manassas conj                   battles
# Fredericksburg            Fredericksburg conj                   Manassas
# Virginia                  Virginia pobj                   in
# Antietam                  Antietam conj                   Manassas
# Maryland                  Maryland pobj                   in
# even bigger campaigns     campaigns dobj                   foreshadowed
# battles                   battles conj                   campaigns
# subsequent years          years  pobj                   in
# Gettysburg                Gettysburg pobj                   from
# Pennsylvania              Pennsylvania pobj                   in
# Vicksburg                 Vicksburg pobj                   to
# the Mississippi           Mississippi pobj                   on
# Chickamauga               Chickamauga pobj                   to
# Atlanta                   Atlanta conj                   Chickamauga
# Georgia                   Georgia pobj                   in
# the original Northern goal goal   nsubj                  given
# a limited war             war    pobj                   of
# the Union                 Union  dobj                   restore
# way                       way    dobj                   given
# a new strategy            strategy pobj                   to
# "total war                war    pobj                   of
# the Old South             South  dobj                   destroy
# its basic institution     institution conj                   South
# slavery                   slavery pobj                   of
# the restored Union        Union  dative                 give
# a "new birth              birth  dobj                   give
# freedom                   freedom pobj                   of
# President Lincoln         Lincoln nsubj                  put
# it                        it     dobj                   put
# his address               address pobj                   in
# Gettysburg                Gettysburg pobj                   at
# a cemetery                cemetery dobj                   dedicate
# Union soldiers            soldiers pobj                   for
# the battle                battle pobj                   in
# three long years          years  pobj                   For
# Robert E. Lee's Army      Army   nsubj                  staved
# Northern Virginia         Virginia pobj                   of
# invasions                 invasions dobj                   staved
# attacks                   attacks conj                   invasions
# the Union Army            Army   pobj                   by
# the Potomac               Potomac pobj                   of
# a series                  series pobj                   by
# ineffective generals      generals pobj                   of
# Ulysses S. Grant          Grant  nsubj                  came
# Virginia                  Virginia pobj                   to
# the Western theater       theater pobj                   from
# chief                     chief  pobj                   in
# all Union armies          armies pobj                   of
# bloody battles            battles pobj                   After
# places                    places pobj                   at
# names                     names  pobj                   with
# The Wilderness            Wilderness pobj                   like
# Spotsylvania              Spotsylvania conj                   Wilderness
# Cold Harbor               Harbor conj                   Spotsylvania
# Petersburg                Petersburg conj                   Harbor
# Grant                     Grant  nsubj                  brought
# Lee                       Lee    dobj                   brought
# Appomattox                Appomattox pobj                   at
# April                     April  pobj                   in
# the meantime Union armies armies pobj                   In
# river fleets              fleets conj                   armies
# the theater               theater pobj                   in
# war                       war    pobj                   of
# the slave states          states dobj                   comprising
# the Appalachian Mountain chain chain  pobj                   of
# a long series             series dobj                   won
# victories                 victories pobj                   of
# Confederate armies        armies pobj                   over
# hapless or unlucky Confederate generals generals pobj                   by
# 1864-1865 General William Tecumseh Sherman Sherman nsubj                  led
# his army                  army   dobj                   led
# the Confederate heartland heartland pobj                   into
# Georgia                   Georgia pobj                   of
# South Carolina            Carolina conj                   Georgia
# their economic infrastructure infrastructure dobj                   destroying
# General George Thomas     Thomas nsubj                  destroyed
# the Confederacy's Army    Army   dobj                   destroyed
# Tennessee                 Tennessee pobj                   of
# the battle                battle pobj                   at
# Nashville                 Nashville pobj                   of
# the spring                spring pobj                   By
# all the principal Confederate armies armies nsubj                  surrendered
# Union cavalry             cavalry nsubj                  captured
# the fleeing Confederate President Jefferson Davis Davis  dobj                   captured
# Georgia                   Georgia pobj                   in
# May                       May    pobj                   on
# resistance                resistance nsubj                  collapsed
# the war                   war    nsubj                  ended
# The long, painful process process nsubj                  began
# a united nation           nation dobj                   rebuilding
# slavery                   slavery pobj                   of

# %%
#When doc is created, the parsing process is done and a parse tree is generated
displacy.render(doc, style = 'dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="83f8c62679844ce0a43b563d2b1ac9bb-0" class="displacy" width="139525" height="2324.5" direction="ltr" style="max-width: none; height: 2324.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Civil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">War</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">central</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">event</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">America</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">historical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">consciousness.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">While</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Revolution</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">1776-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">1783</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">created</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">States,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Civil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">War</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">1861-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">1865</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">determined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">kind</tspan>
#     <tspan class=

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  is the central event in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's historical consciousness. While
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Revolution of 1776-1783
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  created
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  of 1861-1865 determined what kind of nation it would be. The war resolved
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  fundamental questions left unresolved by the revolution: whether
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was to be a dissolvable confederation of sovereign states or an indivisible nation with a sovereign national government; and whether this nation, born of a declaration that all men were created with an equal right to liberty, would continue to exist as the largest slaveholding country in the world.</br></br>Northern victory in the war preserved
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  nation and ended the institution of slavery that had divided the country from its beginning. But these achievements came at the cost of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     625,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lives--nearly as many
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  soldiers as died in all the other wars in which this country has fought combined.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The American Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was the largest and most destructive conflict in the Western world between the end of
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Napoleonic Wars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1815
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and the onset of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War I
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  started because of uncompromising differences between the free and slave states over the power of the national government to prohibit slavery in the territories that had not yet become states. When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abraham Lincoln
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  won election in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1860
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Republican
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  president on a platform pledging to keep slavery out of the territories,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0

# %%
# higher accuracy
# !python -m spacy download en_core_web_trf
nlp = spacy.load('en_core_web_trf')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-trf==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.0.0/en_core_web_trf-3.0.0-py3-none-any.whl (459.7 MB)
# Requirement already satisfied: spacy-transformers<1.1.0,>=1.0.0rc4 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from en-core-web-trf==3.0.0) (1.0.3)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from en-core-web-trf==3.0.0) (3.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (8.0.7)
# Requirement already satisfied: setuptools in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (57.0.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.0.5)
# Requirement already satisfied: numpy>=1.15.0 in d:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.20.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.0.5)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.11.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.0.6)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.6.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (20.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (4.59.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.4.1)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.7.4)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\anaconda\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (5.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2020.12.5)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.8.3)
# Requirement already satisfied: transformers<4.7.0,>=3.4.0 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (4.6.1)
# Requirement already satisfied: torch>=1.5.0 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.9.0)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (3.7.4.3)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from transformers<4.7.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (3.0.12)
# Requirement already satisfied: huggingface-hub==0.0.8 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from transformers<4.7.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.0.8)
# Requirement already satisfied: sacremoses in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from transformers<4.7.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.0.45)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\zdszy\appdata\roaming\python\python38\site-packages (from transformers<4.7.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in d:\anaconda\lib\site-packages (from transformers<4.7.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (2021.4.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in d:\anaconda\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.1.1)
# Requirement already satisfied: joblib in d:\anaconda\lib\site-packages (from sacremoses->transformers<4.7.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.0.1)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from sacremoses->transformers<4.7.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.15.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
doc = nlp(text)
for chunk in doc.noun_chunks:
    print(f'{chunk.text:{25}} {chunk.root.text:{6}} {chunk.root.dep_:<{22}} {chunk.root.head.text}')
# Out:
# The Civil War             War    nsubj                  is
# the central event         event  attr                   is
# America's historical consciousness consciousness pobj                   in
# the Revolution            Revolution nsubj                  created
# the United States         States dobj                   created
# the Civil War             War    nsubj                  determined
# what kind                 kind   attr                   be
# nation                    nation pobj                   of
# it                        it     nsubj                  be
# The war                   war    nsubj                  resolved
# two fundamental questions questions dobj                   resolved
# the revolution            revolution pobj                   by
# the United States         States nsubj                  was
# a dissolvable confederation confederation attr                   be
# sovereign states          states pobj                   of
# an indivisible nation     nation conj                   confederation
# a sovereign national government government pobj                   with
# this nation               nation nsubj                  continue
# a declaration             declaration pobj                   of
# all men                   men    nsubjpass              created
# an equal right            right  pobj                   with
# liberty                   liberty pobj                   to
# the largest slaveholding country country pobj                   as
# the world                 world  pobj                   in
# Northern victory          victory nsubj                  preserved
# the war                   war    pobj                   in
# the United States         States dobj                   preserved
# one nation                nation pobj                   as
# the institution           institution dobj                   ended
# slavery                   slavery pobj                   of
# the country               country dobj                   divided
# its beginning             beginning pobj                   from
# these achievements        achievements nsubj                  came
# the cost                  cost   pobj                   at
# 625,000 lives             lives  pobj                   of
# nearly as many American soldiers soldiers appos                  lives
# all the other wars        wars   pobj                   in
# this country              country nsubj                  fought
# The American Civil War    War    nsubj                  was
# the largest and most destructive conflict conflict attr                   was
# the Western world         world  pobj                   in
# the end                   end    pobj                   between
# the Napoleonic Wars       Wars   pobj                   of
# the onset                 onset  conj                   end
# The Civil War             War    nsubj                  started
# uncompromising differences differences pobj                   because
# the free and slave states states pobj                   between
# the power                 power  pobj                   over
# the national government   government pobj                   of
# slavery                   slavery dobj                   prohibit
# the territories           territories pobj                   in
# states                    states attr                   become
# Abraham Lincoln           Lincoln nsubj                  won
# election                  election dobj                   won
# the first Republican president president pobj                   as
# a platform                platform pobj                   on
# slavery                   slavery dobj                   keep
# the territories           territories pobj                   of
# seven slave states        states nsubj                  seceded
# the deep South            South  pobj                   in
# a new nation              nation dobj                   formed
# the Confederate States    States appos                  nation
# America                   America pobj                   of
# The incoming Lincoln administration administration nsubj                  refused
# the Northern people       people pobj                   of
# the legitimacy            legitimacy dobj                   recognize
# secession                 secession pobj                   of
# They                      They   nsubj                  feared
# it                        it     nsubj                  discredit
# democracy                 democracy dobj                   discredit
# a fatal precedent         precedent dobj                   create
# the no-longer United States States dobj                   fragment
# several small, squabbling countries countries pobj                   into
# The event                 event  nsubj                  came
# war                       war    dobj                   triggered
# Fort Sumter               Sumter pobj                   at
# Charleston Bay            Bay    pobj                   in
# April                     April  pobj                   on
# this United States fort   fort   dobj                   Claiming
# the Confederate army      army   nsubj                  opened
# that day                  day    pobj                   on
# fire                      fire   dobj                   opened
# the federal garrison      garrison pobj                   on
# it                        it     dobj                   forced
# the American flag         flag   dobj                   lower
# surrender                 surrender pobj                   in
# Lincoln                   Lincoln nsubj                  called
# the militia               militia dobj                   called
# this "insurrection        insurrection dobj                   suppress
# Four more slave states    states nsubj                  seceded
# the Confederacy           Confederacy dobj                   joined
# the end                   end    pobj                   By
# nearly a million armed men men    nsubj                  confronted
# a line                    line   pobj                   along
# Virginia                  Virginia pobj                   from
# Missouri                  Missouri pobj                   to
# Several battles           battles nsubj                  taken
# place                     place  dobj                   taken
# Manassas Junction         Junction pobj                   near
# Virginia                  Virginia pobj                   in
# the mountains             mountains pobj                   in
# western Virginia          Virginia pobj                   of
# Union victories           victories nsubj                  paved
# the way                   way    dobj                   paved
# creation                  creation pobj                   for
# the new state             state  pobj                   of
# West Virginia             Virginia pobj                   of
# Wilson's Creek            Creek  pobj                   at
# Missouri                  Missouri pobj                   in
# Cape Hatteras             Hatteras pobj                   at
# North Carolina            Carolina pobj                   in
# Port Royal                Royal  pobj                   at
# South Carolina            Carolina pobj                   in
# the Union navy            navy   nsubj                  established
# a base                    base   dobj                   established
# a blockade                blockade pobj                   for
# the Confederacy's access  access dobj                   shut
# the outside world         world  pobj                   to
# the real fighting         fighting nsubj                  began
# Huge battles              battles nsubj                  foreshadowed
# Shiloh                    Shiloh pobj                   like
# Tennessee                 Tennessee pobj                   in
# Gaines' Mill              Mill   conj                   Shiloh
# Second Manassas           Manassas conj                   Mill
# Fredericksburg            Fredericksburg conj                   Manassas
# Virginia                  Virginia pobj                   in
# Antietam                  Antietam conj                   Fredericksburg
# Maryland                  Maryland pobj                   in
# even bigger campaigns     campaigns dobj                   foreshadowed
# battles                   battles conj                   campaigns
# subsequent years          years  pobj                   in
# Gettysburg                Gettysburg pobj                   from
# Pennsylvania              Pennsylvania pobj                   in
# Vicksburg                 Vicksburg pobj                   to
# the Mississippi           Mississippi pobj                   on
# Chickamauga               Chickamauga pobj                   to
# Atlanta                   Atlanta conj                   Chickamauga
# Georgia                   Georgia pobj                   in
# the original Northern goal goal   nsubj                  given
# a limited war             war    pobj                   of
# the Union                 Union  dobj                   restore
# way                       way    dobj                   given
# a new strategy            strategy pobj                   to
# total war                 war    pobj                   of
# the Old South             South  dobj                   destroy
# its basic institution     institution conj                   South
# slavery                   slavery pobj                   of
# the restored Union        Union  dative                 give
# a "new birth              birth  dobj                   give
# freedom                   freedom pobj                   of
# President Lincoln         Lincoln nsubj                  put
# it                        it     dobj                   put
# his address               address pobj                   in
# Gettysburg                Gettysburg pobj                   at
# a cemetery                cemetery dobj                   dedicate
# Union soldiers            soldiers pobj                   for
# the battle                battle pobj                   in
# three long years          years  pobj                   For
# Robert E. Lee's Army      Army   nsubj                  staved
# Northern Virginia         Virginia pobj                   of
# invasions                 invasions dobj                   staved
# attacks                   attacks conj                   invasions
# the Union Army            Army   pobj                   by
# the Potomac               Potomac pobj                   of
# a series                  series pobj                   by
# ineffective generals      generals pobj                   of
# Ulysses S. Grant          Grant  nsubj                  came
# Virginia                  Virginia pobj                   to
# the Western theater       theater pobj                   from
# chief                     chief  pobj                   in
# all Union armies          armies pobj                   of
# bloody battles            battles pobj                   After
# places                    places pobj                   at
# names                     names  pobj                   with
# The Wilderness            Wilderness pobj                   like
# Spotsylvania              Spotsylvania conj                   Wilderness
# Cold Harbor               Harbor conj                   Spotsylvania
# Petersburg                Petersburg conj                   Harbor
# Grant                     Grant  nsubj                  brought
# Lee                       Lee    dobj                   brought
# bay                       bay    pobj                   to
# Appomattox                Appomattox pobj                   at
# April                     April  pobj                   in
# the meantime              meantime pobj                   In
# Union armies              armies nsubj                  won
# river fleets              fleets conj                   armies
# the theater               theater pobj                   in
# war                       war    pobj                   of
# the slave states          states dobj                   comprising
# the Appalachian Mountain chain chain  pobj                   of
# a long series             series dobj                   won
# victories                 victories pobj                   of
# Confederate armies        armies pobj                   over
# hapless or unlucky Confederate generals generals pobj                   by
# General William Tecumseh Sherman Sherman nsubj                  led
# his army                  army   dobj                   led
# the Confederate heartland heartland pobj                   into
# Georgia                   Georgia pobj                   of
# South Carolina            Carolina conj                   Georgia
# their economic infrastructure infrastructure dobj                   destroying
# General George Thomas     Thomas nsubj                  destroyed
# the Confederacy's Army    Army   dobj                   destroyed
# Tennessee                 Tennessee pobj                   of
# the battle                battle pobj                   at
# Nashville                 Nashville pobj                   of
# all the principal Confederate armies armies nsubj                  surrendered
# Union cavalry             cavalry nsubj                  captured
# the fleeing Confederate President Jefferson Davis Davis  dobj                   captured
# Georgia                   Georgia pobj                   in
# May                       May    pobj                   on
# resistance                resistance nsubj                  collapsed
# the war                   war    nsubj                  ended
# The long, painful process process nsubj                  began
# a united nation           nation dobj                   rebuilding
# slavery                   slavery pobj                   of

# %%
#When doc is created, the parsing process is done and a parse tree is generated
displacy.render(doc, style = 'dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="83de5d5d34194d3a90a28ee5f77d38dd-0" class="displacy" width="139525" height="2324.5" direction="ltr" style="max-width: none; height: 2324.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Civil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">War</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">central</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">event</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">America</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">historical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">consciousness.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">While</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Revolution</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">1776-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">1783</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">created</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">States,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Civil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">War</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">1861-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">1865</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">determined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">kind</tspan>
#     <tspan class

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  is the central event in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's historical consciousness. While
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Revolution of 1776
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# -1783 created
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1861-1865
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  determined what kind of nation it would be. The war resolved
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  fundamental questions left unresolved by the revolution: whether
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was to be a dissolvable confederation of sovereign states or an indivisible nation with a sovereign national government; and whether this nation, born of a declaration that all men were created with an equal right to liberty, would continue to exist as the largest slaveholding country in the world.</br></br>Northern victory in the war preserved
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  nation and ended the institution of slavery that had divided the country from its beginning. But these achievements came at the cost of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     625,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lives--nearly as many
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  soldiers as died in all the other wars in which this country has fought combined.
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The American Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  was the largest and most destructive conflict in the Western world between the end of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Napoleonic Wars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1815
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and the onset of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War I
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  started because of uncompromising differences between the free and slave states over the power of the national government to prohibit slavery in the territories that had not yet become states. When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abraham Lincoln
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  won election in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1860
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Republican
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  pr
