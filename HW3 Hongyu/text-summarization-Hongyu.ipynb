# %% [markdown]
# # Text Summarization - In Class Coding Example

# %%
import urllib.request  
import bs4 as BeautifulSoup
import nltk
nltk.download('stopwords')
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zdszy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Web Scrapying on the Article Source for Text Summarization

# %% [markdown]
# Look at the HTML code of [this](https://en.wikipedia.org/wiki/Machine_learning) webpage. What did you notice? What types of tags tend to hold important text information?

# %%
# Raw HTML from Wikipedia using Urllib
text = urllib.request.urlopen('https://en.wikipedia.org/wiki/Machine_learning')
text
print(type(text))
# Out:
# <class 'http.client.HTTPResponse'>

# %%
# Processed HTML
article = text.read()
article
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Machine learning - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"2444c583-9249-48d2-ab56-63821da0d508","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Machine_learning","wgTitle":"Machine learning","wgCurRevisionId":1035217173,"wgRevisionId":1035217173,"wgArticleId":233488,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 errors: missing periodical","Harv and Sfn no-target errors","CS1 maint: uses authors parameter","Articles with short description","Short description is different from Wikidata","Commons category link from Wikidata","Wikipedia articles with GND identifiers",\n"Wikipedia articles with LCCN identifiers","Wikipedia articles with NDL identifiers","Wikipedia articles with MA identifiers","Machine learning","Cybernetics","Learning"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Machine_learning","wgRelevantArticleId":233488,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":-1}}},"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":!0,\n"wgGENewcomerTasksGuidanceEnabled":!0,"wgGEAskQuestionEnabled":!1,"wgGELinkRecommendationsFrontendEnabled":!1,"wgWikibaseItemId":"Q2539"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","skins.vector.styles.legacy":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.math.scripts","ext.scribunto.logs","site","mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart",\n"ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.growthExperiments.SuggestedEditSession"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.math.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modul ...

# %%
# Parsing the URL content 
article_parsed = BeautifulSoup.BeautifulSoup(article,'html.parser')
print(type(article_parsed))
paragraphs = article_parsed.find_all('p')
print(type(paragraphs))
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.element.ResultSet'>

# %%
# Extracted text from <p> tags
paragraphs
# Out:
# [<p><b>Machine learning</b> (<b>ML</b>) is the study of computer <a href="/wiki/Algorithm" title="Algorithm">algorithms</a> that improve automatically through experience and by the use of data.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup> It is seen as a part of <a href="/wiki/Artificial_intelligence" title="Artificial intelligence">artificial intelligence</a>. Machine learning algorithms build a model based on sample data, known as "<a class="mw-redirect" href="/wiki/Training_data" title="Training data">training data</a>", in order to make predictions or decisions without being explicitly programmed to do so.<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> Machine learning algorithms are used in a wide variety of applications, such as in medicine, <a href="/wiki/Email_filtering" title="Email filtering">email filtering</a>, <a href="/wiki/Speech_recognition" title="Speech recognition">speech recognition</a>, and <a href="/wiki/Computer_vision" title="Computer vision">computer vision</a>, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.<sup class="reference" id="cite_ref-tvt_3-0"><a href="#cite_note-tvt-3">[3]</a></sup>
#  </p>,
#  <p>A subset of machine learning is closely related to <a href="/wiki/Computational_statistics" title="Computational statistics">computational statistics</a>, which focuses on making predictions using computers; but not all machine learning is statistical learning. The study of <a href="/wiki/Mathematical_optimization" title="Mathematical optimization">mathematical optimization</a> delivers methods, theory and application domains to the field of machine learning. <a href="/wiki/Data_mining" title="Data mining">Data mining</a> is a related field of study, focusing on <a href="/wiki/Exploratory_data_analysis" title="Exploratory data analysis">exploratory data analysis</a> through <a href="/wiki/Unsupervised_learning" title="Unsupervised learning">unsupervised learning</a>.<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup><sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup> In its application across business problems, machine learning is also referred to as <a href="/wiki/Predictive_analytics" title="Predictive analytics">predictive analytics</a>.
#  </p>,
#  <p>Machine learning involves computers discovering how they can perform tasks without being explicitly programmed to do so. It involves computers learning from data provided so that they carry out certain tasks. For simple tasks assigned to computers, it is possible to program algorithms telling the machine how to execute all steps required to solve the problem at hand; on the computer's part, no learning is needed. For more advanced tasks, it can be challenging for a human to manually create the needed algorithms. In practice, it can turn out to be more effective to help the machine develop its own algorithm, rather than having human programmers specify every needed step.<sup class="reference" id="cite_ref-Alpaydin2020_7-0"><a href="#cite_note-Alpaydin2020-7">[7]</a></sup>
#  </p>,
#  <p>The discipline of machine learning employs various approaches to teach computers to accomplish tasks where no fully satisfactory algorithm is available. In cases where vast numbers of potential answers exist, one approach is to label some of the correct answers as valid. This can then be used as training data for the computer to improve the algorithm(s) it uses to determine correct answers. For example, to train a system for the task of digital character recognition, the <a href="/wiki/MNIST_database" title="MNIST database">MNIST</a> dataset of handwritten digits has often been used.<sup class="reference" id="cite_ref-Alpaydin2020_7-1"><a href="#cite_note-Alpaydin2020-7">[7]</a></sup>
#  </p>,
#  <p>The term <i>machine learning</i> was coined in 1959 by <a href="/wiki/Arthur_Samuel" title="Arthur Samuel">Arthur Samuel</a>, an American <a class="mw-redirect" href="/wiki/IBMer" title="IBMer">IBMer</a> and pioneer in the field of <a class="mw-redirect" href="/wiki/Computer_gaming" title="Computer gaming">computer gaming</a> and <a href="/wiki/Artificial_intelligence" title="Artificial intelligence">artificial intelligence</a>.<sup class="reference" id="cite_ref-Samuel_8-0"><a href="#cite_note-Samuel-8">[8]</a></sup><sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup> A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup> Interest related to pattern recognition continued into the 1970s, as described by Duda and Hart in 1973.<sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup> In 1981 a report was given on using teaching strategies so that a <a href="/wiki/Neural_network" title="Neural network">neural network</a> learns to recognize 40 characters (26 letters, 10 digits, and 4 special symbols) from a computer terminal.<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
#  </p>,
#  <p><a href="/wiki/Tom_M._Mitchell" title="Tom M. Mitchell">Tom M. Mitchell</a> provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience <i>E</i> with respect to some class of tasks <i>T</i> and performance measure <i>P</i> if its performance at tasks in <i>T</i>, as measured by <i>P</i>,  improves with experience <i>E</i>."<sup class="reference" id="cite_ref-Mitchell-1997_13-0"><a href="#cite_note-Mitchell-1997-13">[13]</a></sup> This definition of the tasks in which machine learning is concerned offers a fundamentally <a href="/wiki/Operational_definition" title="Operational definition">operational definition</a> rather than defining the field in cognitive terms. This follows <a href="/wiki/Alan_Turing" title="Alan Turing">Alan Turing</a>'s proposal in his paper "<a href="/wiki/Computing_Machinery_and_Intelligence" title="Computing Machinery and Intelligence">Computing Machinery and Intelligence</a>", in which the question "Can machines think?" is replaced with the question "Can machines do what we (as thinking entities) can do?".<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup>
#  </p>,
#  <p>Modern day machine learning has two objectives, one is to classify data based on models which have been developed, the other purpose is to make predictions for future outcomes based on these models. A hypothetical algorithm specific to classifying data may use computer vision of moles coupled with supervised learning in order to train it to classify the cancerous moles. Where as, a machine learning algorithm for stock trading may inform the trader of future potential predictions.<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup>
#  </p>,
#  <p>As a scientific endeavor, machine learning grew out of the quest for artificial intelligence. In the early days of AI as an <a class="mw-redirect" href="/wiki/Discipline_(academia)" title="Discipline (academia)">academic discipline</a>, some researchers were interested in having machines learn from data. They attempted to approach the problem with various symbolic methods, as well as what was then termed "<a href="/wiki/Neural_network" title="Neural network">neural networks</a>"; these were mostly <a href="/wiki/Perceptron" title="Perceptron">perceptrons</a> and <a href="/wiki/ADALINE" title="ADALINE">other models</a> that were later found to be reinventions of the <a href="/wiki/Generalized_linear_model" title="Generalized linear model">generalized linear models</a> of statistics.<sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[18]</a></sup> <a href="/wiki/Probability_theory" title="Probability theory">Probabilistic</a> reasoning was also employed, especially in automated <a href="/wiki/Medical_diagnosis" title="Medical diagnosis">medical diagnosis</a>.<sup class="reference" id="cite_ref-aima_19-0"><a href="#cite_note-aima-19">[19]</a></sup><sup class="reference" style="white-space:nowrap;">:<span>488</span></sup>
#  </p>,
#  <p>However, an increasing emphasis on the <a class="mw-redirect" href="/wiki/GOFAI" title="GOFAI">logical, knowledge-based approach</a> caused a rift between AI and machine learning. Probabilistic systems were plagued by theoretical and practical problems of data acquisition and representation.<sup class="reference" id="cite_ref-aima_19-1"><a href="#cite_note-aima-19">[19]</a></sup><sup class="reference" style="white-space:nowrap;">:<span>488</span></sup> By 1980, <a href="/wiki/Expert_system" title="Expert system">expert systems</a> had come to dominate AI, and statistics was out of favor.<sup class="reference" id="cite_ref-changing_20-0"><a href="#cite_note-changing-20">[20]</a></sup> Work on symbolic/knowledge-based learning did continue within AI, leading to <a href="/wiki/Inductive_logic_programming" title="Inductive logic programming">inductive logic programming</a>, but the more statistical line of research was now outside the field of AI proper, in <a href="/wiki/Pattern_recognition" title="Pattern recognition">pattern recognition</a> and <a href="/wiki/Information_retrieval" title="Information retrieval">information retrieval</a>.<sup class="reference" id="cite_ref-aima_19-2"><a href="#cite_note-aima-19">[19]</a></sup><sup class="reference" style="white-space:nowrap;">:<span>708–710; 755</span></sup> Neural networks research had been abandoned by AI and <a href="/wiki/Computer_science" title="Computer science">computer science</a> around the same time. This line, too, was continued outside the AI/CS field, as "<a href="/wiki/Connectionism" title="Connectionism">connectionism</a>", by researchers from other disciplines including <a href="/wiki/John_Hopfield" title="John Hopfield">Hopfield</a>, <a href="/wiki/David_Rumelhart" title="David Rumelhart">Rumelhart</a> and <a class="mw-redirect" href="/wiki/Geoff_Hinton" title="Geoff Hinton">Hinton</a>. Their main success came in the mid-1980s with the reinvention of <a href="/wiki/Backpropagation" title="Backpropagation">backpropagation</a>.<sup class="reference" id="cite_ref-aima_19-3"><a href="#cite_note-aima-19">[19]</a></sup><sup class="reference" style="white-space:nowrap;">:<span>25</span></sup>
#  </p>,
#  <p>Machine learning (ML), reorganized as a separate field, started to flourish in the 1990s. The field changed its goal from achieving artificial intelligence to tackling solvable problems of a practical nature. It shifted focus away from the <a href="/wiki/Symbolic_artificial_intelligence" title="Symbolic artificial intelligence">symbolic approaches</a> it had inherited from AI, and toward methods and models borrowed from statistics and <a href="/wiki/Probability_theory" title="Probability theory">probability theory</a>.<sup class="reference" id="cite_ref-changing_20-1"><a href="#cite_note-changing-20">[20]</a></sup>
#  </p>,
#  <p>As of 2020, many sources continue to assert that machine learning remains a subfield of AI.<sup class="reference" id="cite_ref-21"><a href="#cite_note-21">[21]</a></sup><sup class="reference" id="cite_ref-22"><a href="#cite_note-22">[22]</a></sup><sup class="reference" id="cite_ref-journalimcms.org_16-1"><a href="#cite_note-journalimcms.org-16">[16]</a></sup> The main disagreement is whether all of ML is part of AI, as this would mean that anyone using ML could claim they are using AI. Others have the view that not all of ML is part of AI<sup class="reference" id="cite_ref-23"><a href="#cite_note-23">[23]</a></sup><sup class="reference" id="cite_ref-24"><a href="#cite_note-24">[24]</a></sup><sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[25]</a></sup> where only an 'intelligent' subset of ML is part of AI.<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[26]</a></sup>
#  </p>,
#  <p>The question to what is the difference between ML and AI is answered by <a href="/wiki/Judea_Pearl" title="Judea Pearl">Judea Pearl</a> in <i>The Book of Why</i>.<sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[27]</a></sup> Accordingly ML learns and predicts based on passive observations, whereas AI implies an agent  interacting with the environment to learn and take actions that maximize its chance of successfully achieving its goals.<sup class="reference" id="cite_ref-Definition_of_AI_30-0"><a href="#cite_note-Definition_of_AI-30">[30]</a></sup>
#  </p>,
#  <p>Machine learning and <a href="/wiki/Data_mining" title="Data mining">data mining</a> often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on <i>known</i> properties learned from the training data, <a href="/wiki/Data_mining" title="Data mining">data mining</a> focuses on the <a href="/wiki/Discovery_(observation)" title="Discovery (observation)">discovery</a> of (previously) <i>unknown</i> properties in the data (this is the analysis step of <a class="mw-redirect" href="/wiki/Knowledge_discovery" title="Knowledge discovery">knowledge discovery</a> in databases). Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy. Much of the confusion between these two research communities (which do often have separate conferences and separate journals, <a href="/wiki/ECML_PKDD" title="ECML PKDD">ECML PKDD</a> being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to <i>reproduce known</i> knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously <i>unknown</i> knowledge. Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.
#  </p>,
#  <p>Machine learning also has intimate ties to <a href="/wiki/Mathematical_optimization" title="Mathematical optimization">optimization</a>: many learning problems are formulated as minimization of some <a href="/wiki/Loss_function" title="Loss function">loss function</a> on a training set of examples. Loss functions express the discrepancy between the predictions of the model being trained and the actual problem instances (for example, in classification, one wants to assign a label to instances, and models are trained to correctly predict the pre-assigned labels of a set of examples).<sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[31]</a></sup>
#  </p>,
#  <p>The difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples. Characterizing the generalization of various learning algorithms is an active topic of current research, especially for <a href="/wiki/Deep_learning" title="Deep learning">deep learning</a> algorithms.
#  </p>,
#  <p>Machine learning and <a href="/wiki/Statistics" title="Statistics">statistics</a> are closely related fields in terms of methods, but distinct in their principal goal: statistics draws population <a href="/wiki/Statistical_inference" title="Statistical inference">inferences</a> from a <a href="/wiki/Sample_(statistics)" title="Sample (statistics)">sample</a>, while machine learning finds generalizable predictive patterns.<sup class="reference" id="cite_ref-32"><a href="#cite_note-32">[32]</a></sup> According to <a href="/wiki/Michael_I._Jordan" title="Michael I. Jordan">Michael I. Jordan</a>, the ideas of machine learning, from methodological principles to theoretical tools, have had a long pre-history in statistics.<sup class="reference" id="cite_ref-mi_jordan_ama_33-0"><a href="#cite_note-mi_jordan_ama-33">[33]</a></sup> He also suggested the term <a href="/wiki/Data_science" title="Data science">data science</a> as a placeholder to call the overall field.<sup class="reference" id="cite_ref-mi_jordan_ama_33-1"><a href="#cite_note-mi_jordan_ama-33">[33]</a></sup>
#  </p>,
#  <p><a href="/wiki/Leo_Breiman" title="Leo Breiman">Leo Breiman</a> distinguished two statistical modeling paradigms: data model and algorithmic model,<sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[34]</a></sup> wherein "algorithmic model" means more or less the machine learning algorithms like <a href="/wiki/Random_forest" title="Random forest">Random forest</a>.
#  </p>,
#  <p>Some statisticians have adopted methods from machine learning, leading to a combined field that they call <i>statistical learning</i>.<sup class="reference" id="cite_ref-islr_35-0"><a href="#cite_note-islr-35">[35]</a></sup>
#  </p>,
#  <p><br/>
#  </p>,
#  <p>A core objective of a learner is to generalize from its experience.<sup class="reference" id="cite_ref-bishop2006_4-1"><a href="#cite_note-bishop2006-4">[4]</a></sup><sup class="reference" id="cite_ref-36"><a href="#cite_note-36">[36]</a></sup> Generalization in this context is the ability of a learning machine to perform accurately on new, unseen examples/tasks after having experienced a learning data set. The training examples come from some generally unknown probability distribution (considered representative of the space of occurrences) and the learner has to build a general model about this space that enables it to produce sufficiently accurate predictions in new cases.
#  </p>,
#  <p>The computational analysis of machine learning algorithms and their performance is a branch of <a href="/wiki/Theoretical_computer_science" title="Theoretical computer science">theoretical computer science</a> known as <a href="/wiki/Computational_learning_theory" title="Computational learning theory">computational learning theory</a>. Because training sets are finite and the future is uncertain, learning theory usually does not yield guarantees of the performance of algorithms. Instead, probabilistic bounds on the performance are quite common. The <a class="mw-redirect" href="/wiki/Bias%E2%80%93variance_decomposition" title="Bias–variance decomposition">bias–variance decomposition</a> is one way to quantify generalization <a href="/wiki/Errors_and_residuals" title="Errors and residuals">error</a>.
#  </p>,
#  <p>For the best performance in the context of generalization, the complexity of the hypothesis should match the complexity of the function underlying the data. If the hypothesis is less complex than the function, then the model has under fitted the data. If the complexity of the model is increased in response, then the training error decreases. But if the hypothesis is too complex, then the model is subject to <a href="/wiki/Overfitting" title="Overfitting">overfitting</a> and generalization will be poorer.<sup class="reference" id="cite_ref-alpaydin_37-0"><a href="#cite_note-alpaydin-37">[37]</a></sup>
#  </p>,
#  <p>In addition to performance bounds, learning theorists study the time complexity and feasibility of learning. In computational learning theory, a computation is considered feasible if it can be done in <a href="/wiki/Time_complexity#Polynomial_time" title="Time complexity">polynomial time</a>. There are two kinds of <a href="/wiki/Time_complexity" title="Time complexity">time complexity</a> results. Positive results show that a certain class of functions can be learned in polynomial time. Negative results show that certain classes cannot be learned in polynomial time.
#  </p>,
#  <p><span class="anchor" id="Algorithm_types"></span>
#  Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:
#  </p>,
#  <p>Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.<sup class="reference" id="cite_ref-38"><a href="#cite_note-38">[38]</a></sup> The data is known as <a class="mw-redirect" href="/wiki/Training_data" title="Training data">training data</a>, and consists of a set of training examples. Each training example has one or more inputs and the desired output, also known as a supervisory signal.  In the mathematical model, each training example is represented by an <a href="/wiki/Array_data_structure" title="Array data structure">array</a> or vector, sometimes called a feature vector, and the training data is represented by a <a href="/wiki/Matrix_(mathematics)" title="Matrix (mathematics)">matrix</a>. Through <a href="/wiki/Mathematical_optimization#Computational_optimization_techniques" title="Mathematical optimization">iterative optimization</a> of an <a href="/wiki/Loss_function" title="Loss function">objective function</a>, supervised learning algorithms learn a function that can be used to predict the output associated with new inputs.<sup class="reference" id="cite_ref-39"><a href="#cite_note-39">[39]</a></sup> An optimal function will allow the algorithm to correctly determine the output for inputs that were not a part of the training data. An algorithm that improves the accuracy of its outputs or predictions over time is said to have learned to perform that task.<sup class="reference" id="cite_ref-Mitchell-1997_13-1"><a href="#cite_note-Mitchell-1997-13">[13]</a></sup>
#  </p>,
#  <p>Types of supervised learning algorithms include <a href="/wiki/Active_learning_(machine_learning)" title="Active learning (machine learning)">active learning</a>, <a href="/wiki/Statistical_classification" title="Statistical classification">classification</a> and <a href="/wiki/Regression_analysis" title="Regression analysis">regression</a>.<sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[40]</a></sup> Classification algorithms are used when the outputs are restricted to a limited set of values, and regression algorithms are used when the outputs may have any numerical value within a range. As an example, for a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email.
#  </p>,
#  <p><a href="/wiki/Similarity_learning" title="Similarity learning">Similarity learning</a> is an area of supervised machine learning closely related to regression and classification, but the goal is to learn from examples using a similarity function that measures how similar or related two objects are. It has applications in <a href="/wiki/Ranking" title="Ranking">ranking</a>, <a class="mw-redirect" href="/wiki/Recommendation_systems" title="Recommendation systems">recommendation systems</a>, visual identity tracking, face verification, and speaker verification.
#  </p>,
#  <p>Unsupervised learning algorithms take a set of data that contains only inputs, and find structure in the data, like grouping or clustering of data points. The algorithms, therefore, learn from test data that has not been labeled, classified or categorized. Instead of responding to feedback, unsupervised learning algorithms identify commonalities in the data and react based on the presence or absence of such commonalities in each new piece of data. A central application of unsupervised learning is in the field of <a href="/wiki/Density_estimation" title="Density estimation">density estimation</a> in <a href="/wiki/Statistics" title="Statistics">statistics</a>, such as finding the <a href="/wiki/Probability_density_function" title="Probability density function">probability density function</a>.<sup class="reference" id="cite_ref-JordanBishop2004_41-0"><a href="#cite_note-JordanBishop2004-41">[41]</a></sup> Though unsupervised learning encompasses other domains involving summarizing and explaining data features.
#  </p>,
#  <p>Cluster analysis is the assignment of a set of observations into subsets (called <i>clusters</i>) so that observations within the same cluster are similar according to one or more predesignated criteria, while observations drawn from different clusters are dissimilar. Different clustering techniques make different assumptions on the structure of the data, often defined by some <i>similarity metric</i> and evaluated, for example, by <i>internal compactness</i>, or the similarity between members of the same cluster, and <i>separation</i>, the difference between clusters. Other methods are based on <i>estimated density</i> and <i>graph connectivity</i>.
#  </p>,
#  <p>Semi-supervised learning falls between <a href="/wiki/Unsupervised_learning" title="Unsupervised learning">unsupervised learning</a> (without any labeled training data) and <a href="/wiki/Supervised_learning" title="Supervised learning">supervised learning</a> (with completely labeled training data). Some of the training examples are missing training labels,  yet many machine-learning researchers have found that unlabeled data, when used in conjunction with a small amount of labeled data, can produce a considerable improvement in learning accuracy.
#  </p>,
#  <p>In <a href="/wiki/Weak_supervision" title="Weak supervision">weakly supervised learning</a>, the training labels are noisy, limited, or imprecise; however, these labels are often cheaper to obtain, resulting in larger effective training sets.<sup class="reference" id="cite_ref-42"><a href="#cite_note-42">[42]</a></sup>
#  </p>,
#  <p>Reinforcement learning is an area of machine learning concerned with how <a href="/wiki/Software_agent" title="Software agent">software agents</a> ought to take <a href="/wiki/Action_selection" title="Action selection">actions</a> in an environment so as to maximize some notion of cumulative reward. Due to its generality, the field is studied in many other disciplines, such as <a href="/wiki/Game_theory" title="Game theory">game theory</a>, <a href="/wiki/Control_theory" title="Control theory">control theory</a>, <a href="/wiki/Operations_research" title="Operations research">operations research</a>, <a href="/wiki/Information_theory" title="Information theory">information theory</a>, <a href="/wiki/Simulation-based_optimization" title="Simulation-based optimization">simulation-based optimization</a>, <a href="/wiki/Multi-agent_system" title="Multi-agent system">multi-agent systems</a>, <a href="/wiki/Swarm_intelligence" title="Swarm intelligence">swarm intelligence</a>, <a href="/wiki/Statistics" title="Statistics">statistics</a> and <a href="/wiki/Genetic_algorithm" title="Genetic algorithm">genetic algorithms</a>. In machine learning, the environment is typically represented as a <a href="/wiki/Markov_decision_process" title="Markov decision process">Markov decision process</a> (MDP). Many reinforcement learning algorithms use <a href="/wiki/Dynamic_programming" title="Dynamic programming">dynamic programming</a> techniques.<sup class="reference" id="cite_ref-43"><a href="#cite_note-43">[43]</a></sup> Reinforcement learning algorithms do not assume knowledge of an exact mathematical model of the MDP, and are used when exact models are infeasible. Reinforcement learning algorithms are used in autonomous vehicles or in learning to play a game against a human opponent.
#  </p>,
#  <p>The Dimensionality reduction is a process of reducing the number of random variables under the consideration by obtaining a set of principal variables.<sup class="reference" id="cite_ref-44"><a href="#cite_note-44">[44]</a></sup> In other words, it is a process of reducing the dimension of your feature set also called no of features. Most of the dimensionality reduction techniques can be considered as either feature elimination or extraction.
#  One of the popular method of dimensionality reduction is called as principal component analysis.
#  </p>,
#  <p>The PCA involves changing higher dimensional data (eg. 3D) to a smaller space (eg. 2D). This results in a smaller dimension of data, (2D instead of 3D) while keeping all original variables in the model without changing the data.<sup class="reference" id="cite_ref-45"><a href="#cite_note-45">[45]</a></sup>
#  </p>,
#  <p>Other approaches have been developed which don't fit neatly into this three-fold categorisation, and sometimes more than one is used by the same machine learning system. For example <a class="mw-redirect" href="/wiki/Topic_modeling" title="Topic modeling">topic modeling</a>,  <a href="/wiki/Meta_learning_(computer_science)" title="Meta learning (computer science)">meta learning</a>.<sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[46]</a></sup>
#  </p>,
#  <p>As of 2020, <a href="/wiki/Deep_learning" title="Deep learning">deep learning</a> has become the dominant approach for much ongoing work in the field of machine learning.<sup class="reference" id="cite_ref-Alpaydin2020_7-2"><a href="#cite_note-Alpaydin2020-7">[7]</a></sup>
#  </p>,
#  <p>Self-learning as a machine learning paradigm was introduced in 1982 along with a neural network capable of self-learning named <i>crossbar adaptive array</i> (CAA).<sup class="reference" id="cite_ref-47"><a href="#cite_note-47">[47]</a></sup> It is a learning with no external rewards and no external teacher advice. The CAA self-learning algorithm computes, in a crossbar fashion, both decisions about actions and emotions (feelings) about consequence situations. The system is driven by the interaction between cognition and emotion.<sup class="reference" id="cite_ref-48"><a href="#cite_note-48">[48]</a></sup>
#  The self-learning algorithm updates a memory matrix W =||w(a,s)|| such that in each iteration executes the following machine learning routine:
#  </p>,
#  <p>It is a system with only one input, situation s, and only one output, action (or behavior) a. There is neither a separate reinforcement input nor an advice input from the environment. The backpropagated value (secondary reinforcement) is the emotion toward the consequence situation. The CAA exists in two environments, one is the behavioral environment where it behaves, and the other is the genetic environment, wherefrom it initially and only once receives initial emotions about situations to be encountered in the behavioral environment. After receiving the genome (species) vector from the genetic environment, the CAA learns a goal-seeking behavior, in an environment that contains both desirable and undesirable situations.<sup class="reference" id="cite_ref-49"><a href="#cite_note-49">[49]</a></sup>
#  </p>,
#  <p>Several learning algorithms aim at discovering better representations of the inputs provided during training.<sup class="reference" id="cite_ref-pami_50-0"><a href="#cite_note-pami-50">[50]</a></sup> Classic examples include <a class="mw-redirect" href="/wiki/Principal_components_analysis" title="Principal components analysis">principal components analysis</a> and cluster analysis. Feature learning algorithms, also called representation learning algorithms, often attempt to preserve the information in their input but also transform it in a way that makes it useful, often as a pre-processing step before performing classification or predictions. This technique allows reconstruction of the inputs coming from the unknown data-generating distribution, while not being necessarily faithful to configurations that are implausible under that distribution. This replaces manual <a href="/wiki/Feature_engineering" title="Feature engineering">feature engineering</a>, and allows a machine to both learn the features and use them to perform a specific task.
#  </p>,
#  <p>Feature learning can be either supervised or unsupervised. In supervised feature learning, features are learned using labeled input data. Examples include <a href="/wiki/Artificial_neural_network" title="Artificial neural network">artificial neural networks</a>, <a href="/wiki/Multilayer_perceptron" title="Multilayer perceptron">multilayer perceptrons</a>, and supervised <a class="mw-redirect" href="/wiki/Dictionary_learning" title="Dictionary learning">dictionary learning</a>. In unsupervised feature learning, features are learned with unlabeled input data.  Examples include dictionary learning, <a href="/wiki/Independent_component_analysis" title="Independent component analysis">independent component analysis</a>, <a href="/wiki/Autoencoder" title="Autoencoder">autoencoders</a>, <a href="/wiki/Matrix_decomposition" title="Matrix decomposition">matrix factorization</a><sup class="reference" id="cite_ref-51"><a href="#cite_note-51">[51]</a></sup> and various forms of <a href="/wiki/Cluster_analysis" title="Cluster analysis">clustering</a>.<sup class="reference" id="cite_ref-coates2011_52-0"><a href="#cite_note-coates2011-52">[52]</a></sup><sup class="reference" id="cite_ref-53"><a href="#cite_note-53">[53]</a></sup><sup class="reference" id="cite_ref-jurafsky_54-0"><a href="#cite_note-jurafsky-54">[54]</a></sup>
#  </p>,
#  <p><a class="mw-redirect" href="/wiki/Manifold_learning" title="Manifold learning">Manifold learning</a> algorithms attempt to do so under the constraint that the learned representation is low-dimensional. <a class="mw-redirect" href="/wiki/Sparse_coding" title="Sparse coding">Sparse coding</a> algorithms attempt to do so under the constraint that the learned representation is sparse, meaning that the mathematical model has many zeros. <a href="/wiki/Multilinear_subspace_learning" title="Multilinear subspace learning">Multilinear subspace learning</a> algorithms aim to learn low-dimensional representations directly from <a href="/wiki/Tensor" title="Tensor">tensor</a> representations for multidimensional data, without reshaping them into higher-dimensional vectors.<sup class="reference" id="cite_ref-55"><a href="#cite_note-55">[55]</a></sup> <a href="/wiki/Deep_learning" title="Deep learning">Deep learning</a> algorithms discover multiple levels of representation, or a hierarchy of features, with higher-level, more abstract features defined in terms of (or generating) lower-level features. It has been argued that an intelligent machine is one that learns a representation that disentangles the underlying factors of variation that explain the observed data.<sup class="reference" id="cite_ref-56"><a href="#cite_note-56">[56]</a></sup>
#  </p>,
#  <p>Feature learning is motivated by the fact that machine learning tasks such as classification often require input that is mathematically and computationally convenient to process. However, real-world data such as images, video, and sensory data has not yielded to attempts to algorithmically define specific features. An alternative is to discover such features or representations through examination, without relying on explicit algorithms.
#  </p>,
#  <p>Sparse dictionary learning is a feature learning method where a training example is represented as a linear combination of <a href="/wiki/Basis_function" title="Basis function">basis functions</a>, and is assumed to be a <a href="/wiki/Sparse_matrix" title="Sparse matrix">sparse matrix</a>. The method is <a class="mw-redirect" href="/wiki/Strongly_NP-hard" title="Strongly NP-hard">strongly NP-hard</a> and difficult to solve approximately.<sup class="reference" id="cite_ref-57"><a href="#cite_note-57">[57]</a></sup> A popular <a href="/wiki/Heuristic" title="Heuristic">heuristic</a> method for sparse dictionary learning is the <a href="/wiki/K-SVD" title="K-SVD">K-SVD</a> algorithm. Sparse dictionary learning has been applied in several contexts. In classification, the problem is to determine the class to which a previously unseen training example belongs. For a dictionary where each class has already been built, a new training example is associated with the class that is best sparsely represented by the corresponding dictionary. Sparse dictionary learning has also been applied in <a class="mw-redirect" href="/wiki/Image_de-noising" title="Image de-noising">image de-noising</a>. The key idea is that a clean image patch can be sparsely represented by an image dictionary, but the noise cannot.<sup class="reference" id="cite_ref-58"><a href="#cite_note-58">[58]</a></sup>
#  </p>,
#  <p>In <a href="/wiki/Data_mining" title="Data mining">data mining</a>, anomaly detection, also known as outlier detection, is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.<sup class="reference" id="cite_ref-:0_59-0"><a href="#cite_note-:0-59">[59]</a></sup> Typically, the anomalous items represent an issue such as <a href="/wiki/Bank_fraud" title="Bank fraud">bank fraud</a>, a structural defect, medical problems or errors in a text. Anomalies are referred to as <a href="/wiki/Outlier" title="Outlier">outliers</a>, novelties, noise, deviations and exceptions.<sup class="reference" id="cite_ref-60"><a href="#cite_note-60">[60]</a></sup>
#  </p>,
#  <p>In particular, in the context of abuse and network intrusion detection, the interesting objects are often not rare objects, but unexpected bursts of inactivity. This pattern does not adhere to the common statistical definition of an outlier as a rare object, and many outlier detection methods (in particular, unsupervised algorithms) will fail on such data unless it has been aggregated appropriately. Instead, a cluster analysis algorithm may be able to detect the micro-clusters formed by these patterns.<sup class="reference" id="cite_ref-61"><a href="#cite_note-61">[61]</a></sup>
#  </p>,
#  <p>Three broad categories of anomaly detection techniques exist.<sup class="reference" id="cite_ref-ChandolaSurvey_62-0"><a href="#cite_note-ChandolaSurvey-62">[62]</a></sup> Unsupervised anomaly detection techniques detect anomalies in an unlabeled test data set under the assumption that the majority of the instances in the data set are normal, by looking for instances that seem to fit least to the remainder of the data set. Supervised anomaly detection techniques require a data set that has been labeled as "normal" and "abnormal" and involves training a classifier (the key difference to many other statistical classification problems is the inherently unbalanced nature of outlier detection). Semi-supervised anomaly detection techniques construct a model representing normal behavior from a given normal training data set and then test the likelihood of a test instance to be generated by the model.
#  </p>,
#  <p>In <a href="/wiki/Developmental_robotics" title="Developmental robotics">developmental robotics</a>, <a href="/wiki/Robot_learning" title="Robot learning">robot learning</a> algorithms generate their own sequences of learning experiences, also known as a curriculum, to cumulatively acquire new skills through self-guided exploration and social interaction with humans. These robots use guidance mechanisms such as active learning, maturation, <a href="/wiki/Motor_coordination#Muscle_synergies" title="Motor coordination">motor synergies</a> and imitation.
#  </p>,
#  <p>Association rule learning is a <a href="/wiki/Rule-based_machine_learning" title="Rule-based machine learning">rule-based machine learning</a> method for discovering relationships between variables in large databases. It is intended to identify strong rules discovered in databases using some measure of "interestingness".<sup class="reference" id="cite_ref-piatetsky_63-0"><a href="#cite_note-piatetsky-63">[63]</a></sup>
#  </p>,
#  <p>Rule-based machine learning is a general term for any machine learning method that identifies, learns, or evolves "rules" to store, manipulate or apply knowledge. The defining characteristic of a rule-based machine learning algorithm is the identification and utilization of a set of relational rules that collectively represent the knowledge captured by the system. This is in contrast to other machine learning algorithms that commonly identify a singular model that can be universally applied to any instance in order to make a prediction.<sup class="reference" id="cite_ref-64"><a href="#cite_note-64">[64]</a></sup> Rule-based machine learning approaches include <a href="/wiki/Learning_classifier_system" title="Learning classifier system">learning classifier systems</a>, association rule learning, and <a href="/wiki/Artificial_immune_system" title="Artificial immune system">artificial immune systems</a>.
#  </p>,
#  <p>Based on the concept of strong rules, <a href="/wiki/Rakesh_Agrawal_(computer_scientist)" title="Rakesh Agrawal (computer scientist)">Rakesh Agrawal</a>, <a href="/wiki/Tomasz_Imieli%C5%84ski" title="Tomasz Imieliński">Tomasz Imieliński</a> and Arun Swami introduced association rules for discovering regularities between products in large-scale transaction data recorded by <a class="mw-redirect" href="/wiki/Point-of-sale" title="Point-of-sale">point-of-sale</a> (POS) systems in supermarkets.<sup class="reference" id="cite_ref-mining_65-0"><a href="#cite_note-mining-65">[65]</a></sup> For example, the rule <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle \{\mathrm {onions,potatoes} \}\Rightarrow \{\mathrm {burger} \}}" xmlns="http://www.w3.org/1998/Math/MathML">
#  <semantics>
#  <mrow class="MJX-TeXAtom-ORD">
#  <mstyle displaystyle="true" scriptlevel="0">
#  <mo fence="false" stretchy="false">{</mo>
#  <mrow class="MJX-TeXAtom-ORD">
#  <mi mathvariant="normal">o</mi>
#  <mi mathvariant="normal">n</mi>
#  <mi mathvariant="normal">i</mi>
#  <mi mathvariant="normal">o</mi>
#  <mi mathvariant="normal">n</mi>
#  <mi mathvariant="normal">s</mi>
#  <mo>,</mo>
#  <mi mathvariant="normal">p</mi>
#  <mi mathvariant="normal">o</mi>
#  <mi mathvariant="normal">t</mi>
#  <mi mathvariant="normal">a</mi>
#  <mi mathvariant="normal">t</mi>
#  <mi mathvariant="normal">o</mi>
#  <mi mathvariant="normal">e</mi>
#  <mi mathvariant="normal">s</mi>
#  </mrow>
#  <mo fence="false" stretchy="false">}</mo>
#  <mo stretchy="false">⇒<!-- ⇒ --></mo>
#  <mo fence="false" stretchy="false">{</mo>
#  <mrow class="MJX-TeXAtom-ORD">
#  <mi mathvariant="normal">b</mi>
#  <mi mathvariant="normal">u</mi>
#  <mi mathvariant="normal">r</mi>
#  <mi mathvariant="normal">g</mi>
#  <mi mathvariant="normal">e</mi>
#  <mi mathvariant="normal">r</mi>
#  </mrow>
#  <mo fence="false" stretchy="false">}</mo>
#  </mstyle>
#  </mrow>
#  <annotation encoding="application/x-tex">{\displaystyle \{\mathrm {onions,potatoes} \}\Rightarrow \{\mathrm {burger} \}}</annotation>
#  </semantics>
#  </math></span><img alt="\{{\mathrm  {onions,potatoes}}\}\Rightarrow \{{\mathrm  {burger}}\}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/2e6daa2c8e553e87e411d6e0ec66ae596c3c9381" style="vertical-align: -0.838ex; width:30.912ex; height:2.843ex;"/></span> found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat. Such information can be used as the basis for decisions about marketing activities such as promotional <a href="/wiki/Pricing" title="Pricing">pricing</a> or <a href="/wiki/Product_placement" title="Product placement">product placements</a>. In addition to <a class="mw-redirect" href="/wiki/Market_basket_analysis" title="Market basket analysis">market basket analysis</a>, association rules are employed today in application areas including <a class="mw-redirect" href="/wiki/Web_usage_mining" title="Web usage mining">Web usage mining</a>, <a class="mw-redirect" href="/wiki/Intrusion_detection" title="Intrusion detection">intrusion detection</a>, <a href="/wiki/Continuous_production" title="Continuous production">continuous production</a>, and <a href="/wiki/Bioinformatics" title="Bioinformatics">bioinformatics</a>. In contrast with <a class="mw-redirect" href="/wiki/Sequence_mining" title="Sequence mining">sequence mining</a>, association rule learning typically does not consider the order of items either within a transaction or across transactions.
#  </p>,
#  <p>Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a <a href="/wiki/Genetic_algorithm" title="Genetic algorithm">genetic algorithm</a>, with a learning component, performing either <a href="/wiki/Supervised_learning" title="Supervised learning">supervised learning</a>, <a href="/wiki/Reinforcement_learning" title="Reinforcement learning">reinforcement learning</a>, or <a href="/wiki/Unsupervised_learning" title="Unsupervised learning">unsupervised learning</a>. They seek to identify a set of context-dependent rules that collectively store and apply knowledge in a <a href="/wiki/Piecewise" title="Piecewise">piecewise</a> manner in order to make predictions.<sup class="reference" id="cite_ref-66"><a href="#cite_note-66">[66]</a></sup>
#  </p>,
#  <p>Inductive logic programming (ILP) is an approach to rule-learning using <a href="/wiki/Logic_programming" title="Logic programming">logic programming</a> as a uniform representation for input examples, background knowledge, and hypotheses. Given an encoding of the known background knowledge and a set of examples represented as a logical database of facts, an ILP system will derive a hypothesized logic program that <a class="mw-redirect" href="/wiki/Entailment" title="Entailment">entails</a> all positive and no negative examples. <a href="/wiki/Inductive_programming" title="Inductive programming">Inductive programming</a> is a related field that considers any kind of programming language for representing hypotheses (and not only logic programming), such as <a href="/wiki/Functional_programming" title="Functional programming">functional programs</a>.
#  </p>,
#  <p>Inductive logic programming is particularly useful in <a href="/wiki/Bioinformatics" title="Bioinformatics">bioinformatics</a> and <a href="/wiki/Natural_language_processing" title="Natural language processing">natural language processing</a>. <a href="/wiki/Gordon_Plotkin" title="Gordon Plotkin">Gordon Plotkin</a> and <a href="/wiki/Ehud_Shapiro" title="Ehud Shapiro">Ehud Shapiro</a> laid the initial theoretical foundation for inductive machine learning in a logical setting.<sup class="reference" id="cite_ref-67"><a href="#cite_note-67">[67]</a></sup><sup class="reference" id="cite_ref-68"><a href="#cite_note-68">[68]</a></sup><sup class="reference" id="cite_ref-69"><a href="#cite_note-69">[69]</a></sup> Shapiro built their first implementation (Model Inference System) in 1981: a Prolog program that inductively inferred logic programs from positive and negative examples.<sup class="reference" id="cite_ref-70"><a href="#cite_note-70">[70]</a></sup> The term <i>inductive</i> here refers to <a href="/wiki/Inductive_reasoning" title="Inductive reasoning">philosophical</a> induction, suggesting a theory to explain observed facts, rather than <a href="/wiki/Mathematical_induction" title="Mathematical induction">mathematical induction</a>, proving a property for all members of a well-ordered set.
#  </p>,
#  <p>Performing machine learning involves creating a <a href="/wiki/Statistical_model" title="Statistical model">model</a>, which is trained on some training data and then can process additional data to make predictions. Various types of models have been used and researched for machine learning systems.
#  </p>,
#  <p>Artificial neural networks (ANNs), or <a href="/wiki/Connectionism" title="Connectionism">connectionist</a> systems, are computing systems vaguely inspired by the <a class="mw-redirect" href="/wiki/Biological_neural_network" title="Biological neural network">biological neural networks</a> that constitute animal <a href="/wiki/Brain" title="Brain">brains</a>. Such systems "learn" to perform tasks by considering examples, generally without being programmed with any task-specific rules.
#  </p>,
# ...
#  </p>,
#  <p>Usually, machine learning models require a lot of data in order for them to perform well. Usually, when training a machine learning model, one needs to collect a large, representative sample of data from a training set. Data from the training set can be as varied as a corpus of text, a collection of images, and data collected from individual users of a service. <a href="/wiki/Overfitting" title="Overfitting">Overfitting</a> is something to watch out for when training a machine learning model. Trained models derived from biased data can result in skewed or undesired predictions. <a href="/wiki/Algorithmic_bias" title="Algorithmic bias">Algorithmic bias</a> is a potential result from data not fully prepared for training.
#  </p>,
#  <p>Federated learning is an adapted form of <a href="/wiki/Distributed_artificial_intelligence" title="Distributed artificial intelligence">distributed artificial intelligence</a> to training machine learning models that decentralizes the training process, allowing for users' privacy to be maintained by not needing to send their data to a centralized server. This also increases efficiency by decentralizing the training process to many devices. For example, <a href="/wiki/Gboard" title="Gboard">Gboard</a> uses federated machine learning to train search query prediction models on users' mobile phones without having to send individual searches back to <a href="/wiki/Google" title="Google">Google</a>.<sup class="reference" id="cite_ref-77"><a href="#cite_note-77">[77]</a></sup>
#  </p>,
#  <p>There are many applications for machine learning, including:
#  </p>,
#  <p>In 2006, the media-services provider <a href="/wiki/Netflix" title="Netflix">Netflix</a> held the first "<a href="/wiki/Netflix_Prize" title="Netflix Prize">Netflix Prize</a>" competition to find a program to better predict user preferences and improve the accuracy of its existing Cinematch movie recommendation algorithm by at least 10%.  A joint team made up of researchers from <a href="/wiki/AT%26T_Labs" title="AT&amp;T Labs">AT&amp;T Labs</a>-Research in collaboration with the teams Big Chaos and Pragmatic Theory built an <a class="mw-redirect" href="/wiki/Ensemble_Averaging" title="Ensemble Averaging">ensemble model</a> to win the Grand Prize in 2009 for $1 million.<sup class="reference" id="cite_ref-79"><a href="#cite_note-79">[79]</a></sup> Shortly after the prize was awarded, Netflix realized that viewers' ratings were not the best indicators of their viewing patterns ("everything is a recommendation") and they changed their recommendation engine accordingly.<sup class="reference" id="cite_ref-80"><a href="#cite_note-80">[80]</a></sup> In 2010 The Wall Street Journal wrote about the firm Rebellion Research and their use of machine learning to predict the financial crisis.<sup class="reference" id="cite_ref-81"><a href="#cite_note-81">[81]</a></sup> In 2012, co-founder of <a href="/wiki/Sun_Microsystems" title="Sun Microsystems">Sun Microsystems</a>, <a href="/wiki/Vinod_Khosla" title="Vinod Khosla">Vinod Khosla</a>, predicted that 80% of medical doctors' jobs would be lost in the next two decades to automated machine learning medical diagnostic software.<sup class="reference" id="cite_ref-82"><a href="#cite_note-82">[82]</a></sup> In 2014, it was reported that a machine learning algorithm had been applied in the field of art history to study fine art paintings and that it may have revealed previously unrecognized influences among artists.<sup class="reference" id="cite_ref-83"><a href="#cite_note-83">[83]</a></sup> In 2019 <a href="/wiki/Springer_Nature" title="Springer Nature">Springer Nature</a> published the first research book created using machine learning.<sup class="reference" id="cite_ref-84"><a href="#cite_note-84">[84]</a></sup> In 2020, machine learning technology was used to help make diagnoses and aid researchers in developing a cure for COVID-19.<sup class="reference" id="cite_ref-85"><a href="#cite_note-85">[85]</a></sup> Machine learning is recently applied to predict the green behavior of human-being.<sup class="reference" id="cite_ref-86"><a href="#cite_note-86">[86]</a></sup> Recently, machine learning technology is also applied to optimise smartphone's performance and thermal behaviour based on the user's interaction with the phone.<sup class="reference" id="cite_ref-87"><a href="#cite_note-87">[87]</a></sup><sup class="reference" id="cite_ref-88"><a href="#cite_note-88">[88]</a></sup>
#  </p>,
#  <p>Although machine learning has been transformative in some fields, machine-learning programs often fail to deliver expected results.<sup class="reference" id="cite_ref-89"><a href="#cite_note-89">[89]</a></sup><sup class="reference" id="cite_ref-90"><a href="#cite_note-90">[90]</a></sup><sup class="reference" id="cite_ref-91"><a href="#cite_note-91">[91]</a></sup> Reasons for this are numerous: lack of (suitable) data, lack of access to the data, data bias, privacy problems, badly chosen tasks and algorithms, wrong tools and people, lack of resources, and evaluation problems.<sup class="reference" id="cite_ref-92"><a href="#cite_note-92">[92]</a></sup>
#  </p>,
#  <p>In 2018, a self-driving car from <a href="/wiki/Uber" title="Uber">Uber</a> failed to detect a pedestrian, who was killed after a collision.<sup class="reference" id="cite_ref-93"><a href="#cite_note-93">[93]</a></sup> Attempts to use machine learning in healthcare with the <a href="/wiki/Watson_(computer)" title="Watson (computer)">IBM Watson</a> system failed to deliver even after years of time and billions of dollars invested.<sup class="reference" id="cite_ref-94"><a href="#cite_note-94">[94]</a></sup><sup class="reference" id="cite_ref-95"><a href="#cite_note-95">[95]</a></sup>
#  </p>,
#  <p>Machine learning has been used as a strategy to update the evidence related to systematic review and increased reviewer burden related to the growth of biomedical literature. While it has improved with training sets, it has not yet developed sufficiently to reduce the workload burden without limiting the necessary sensitivity for the findings research themselves.<sup class="reference" id="cite_ref-96"><a href="#cite_note-96">[96]</a></sup>
#  </p>,
#  <p>Machine learning approaches in particular can suffer from different data biases. A machine learning system trained specifically on current customers may not be able to predict the needs of new customer groups that are not represented in the training data. When trained on man-made data, machine learning is likely to pick up the constitutional and unconscious biases already present in society.<sup class="reference" id="cite_ref-:1_97-0"><a href="#cite_note-:1-97">[97]</a></sup> Language models learned from data have been shown to contain human-like biases.<sup class="reference" id="cite_ref-98"><a href="#cite_note-98">[98]</a></sup><sup class="reference" id="cite_ref-99"><a href="#cite_note-99">[99]</a></sup> Machine learning systems used for criminal risk assessment have been found to be biased against black people.<sup class="reference" id="cite_ref-100"><a href="#cite_note-100">[100]</a></sup><sup class="reference" id="cite_ref-101"><a href="#cite_note-101">[101]</a></sup> In 2015, Google photos would often tag black people as gorillas,<sup class="reference" id="cite_ref-:2_102-0"><a href="#cite_note-:2-102">[102]</a></sup> and in 2018 this still was not well resolved, but Google reportedly was still using the workaround to remove all gorillas from the training data, and thus was not able to recognize real gorillas at all.<sup class="reference" id="cite_ref-103"><a href="#cite_note-103">[103]</a></sup> Similar issues with recognizing non-white people have been found in many other systems.<sup class="reference" id="cite_ref-104"><a href="#cite_note-104">[104]</a></sup> In 2016, Microsoft tested a <a href="/wiki/Chatbot" title="Chatbot">chatbot</a> that learned from Twitter, and it quickly picked up racist and sexist language.<sup class="reference" id="cite_ref-105"><a href="#cite_note-105">[105]</a></sup> Because of such challenges, the effective use of machine learning may take longer to be adopted in other domains.<sup class="reference" id="cite_ref-106"><a href="#cite_note-106">[106]</a></sup> Concern for <a href="/wiki/Fairness_(machine_learning)" title="Fairness (machine learning)">fairness</a> in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including <a href="/wiki/Fei-Fei_Li" title="Fei-Fei Li">Fei-Fei Li</a>, who reminds engineers that "There’s nothing artificial about AI...It’s inspired by people, it’s created by people, and—most importantly—it impacts people. It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”<sup class="reference" id="cite_ref-107"><a href="#cite_note-107">[107]</a></sup>
#  </p>,
#  <p>Classification of machine learning models can be validated by accuracy estimation techniques like the <a class="mw-redirect" href="/wiki/Test_set" title="Test set">holdout</a> method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set. In comparison, the K-fold-<a href="/wiki/Cross-validation_(statistics)" title="Cross-validation (statistics)">cross-validation</a> method randomly partitions the data into K subsets and then K experiments are performed each respectively considering 1 subset for evaluation and the remaining K-1 subsets for training the model. In addition to the holdout and cross-validation methods, <a href="/wiki/Bootstrapping" title="Bootstrapping">bootstrap</a>, which samples n instances with replacement from the dataset, can be used to assess model accuracy.<sup class="reference" id="cite_ref-108"><a href="#cite_note-108">[108]</a></sup>
#  </p>,
#  <p>In addition to overall accuracy, investigators frequently report <a href="/wiki/Sensitivity_and_specificity" title="Sensitivity and specificity">sensitivity and specificity</a> meaning True Positive Rate (TPR) and True Negative Rate (TNR) respectively. Similarly, investigators sometimes report the <a href="/wiki/False_positive_rate" title="False positive rate">false positive rate</a> (FPR) as well as the <a class="mw-redirect" href="/wiki/False_negative_rate" title="False negative rate">false negative rate</a> (FNR). However, these rates are ratios that fail to reveal their numerators and denominators. The <a href="/wiki/Total_operating_characteristic" title="Total operating characteristic">total operating characteristic</a> (TOC) is an effective method to express a model's diagnostic ability. TOC shows the numerators and denominators of the previously mentioned rates, thus TOC provides more information than the commonly used <a href="/wiki/Receiver_operating_characteristic" title="Receiver operating characteristic">receiver operating characteristic</a> (ROC) and ROC's associated area under the curve (AUC).<sup class="reference" id="cite_ref-109"><a href="#cite_note-109">[109]</a></sup>
#  </p>,
#  <p>Machine learning poses a host of <a href="/wiki/Machine_ethics" title="Machine ethics">ethical questions</a>. Systems which are trained on datasets collected with biases may exhibit these biases upon use (<a href="/wiki/Algorithmic_bias" title="Algorithmic bias">algorithmic bias</a>), thus digitizing cultural prejudices.<sup class="reference" id="cite_ref-110"><a href="#cite_note-110">[110]</a></sup> For example, in 1988, the UK's Commission for Racial Equality found that St. George's Medical School had been using a computer program trained from data of previous admissions staff and this program had denied nearly 60 candidates who were found to be either women or had non-European sounding names.<sup class="reference" id="cite_ref-:1_97-1"><a href="#cite_note-:1-97">[97]</a></sup> Using job hiring data from a firm with racist hiring policies may lead to a machine learning system duplicating the bias by scoring job applicants by similarity to previous successful applicants.<sup class="reference" id="cite_ref-Edionwe_Outline_111-0"><a href="#cite_note-Edionwe_Outline-111">[111]</a></sup><sup class="reference" id="cite_ref-Jeffries_Outline_112-0"><a href="#cite_note-Jeffries_Outline-112">[112]</a></sup> Responsible <a href="/wiki/Data_collection" title="Data collection">collection of data</a> and documentation of algorithmic rules used by a system thus is a critical part of machine learning.
#  </p>,
#  <p>AI can be well-equipped to make decisions in technical fields, which rely heavily on data and historical information. These decisions rely on objectivity and logical reasoning.<sup class="reference" id="cite_ref-113"><a href="#cite_note-113">[113]</a></sup> Because human languages contain biases, machines trained on language <i><a href="/wiki/Text_corpus" title="Text corpus">corpora</a></i> will necessarily also learn these biases.<sup class="reference" id="cite_ref-114"><a href="#cite_note-114">[114]</a></sup><sup class="reference" id="cite_ref-115"><a href="#cite_note-115">[115]</a></sup>
#  </p>,
#  <p>Other forms of ethical challenges, not related to personal biases, are seen in health care. There are concerns among health care professionals that these systems might not be designed in the public's interest but as income-generating machines.<sup class="reference" id="cite_ref-116"><a href="#cite_note-116">[116]</a></sup> This is especially true in the United States where there is a long-standing ethical dilemma of improving health care, but also increasing profits. For example, the algorithms could be designed to provide patients with unnecessary tests or medication in which the algorithm's proprietary owners hold stakes. There is  potential for machine learning in health care to provide professionals an additional tool to diagnose, medicate, and plan recovery paths for patients, but this requires these biases to be mitigated.<sup class="reference" id="cite_ref-117"><a href="#cite_note-117">[117]</a></sup>
#  </p>,
#  <p>Since the 2010s, advances in both machine learning algorithms and computer hardware have led to more efficient methods for training deep neural networks (a particular narrow subdomain of machine learning) that contain many layers of non-linear hidden units.<sup class="reference" id="cite_ref-118"><a href="#cite_note-118">[118]</a></sup> By 2019, graphic processing units (<a class="mw-redirect" href="/wiki/GPU" title="GPU">GPUs</a>), often with AI-specific enhancements, had displaced CPUs as the dominant method of training large-scale commercial cloud AI.<sup class="reference" id="cite_ref-119"><a href="#cite_note-119">[119]</a></sup> <a href="/wiki/OpenAI" title="OpenAI">OpenAI</a> estimated the hardware compute used in the largest deep learning projects from AlexNet (2012) to AlphaZero (2017), and found a 300,000-fold increase in the amount of compute required, with a doubling-time trendline of 3.4 months.<sup class="reference" id="cite_ref-120"><a href="#cite_note-120">[120]</a></sup><sup class="reference" id="cite_ref-121"><a href="#cite_note-121">[121]</a></sup>
#  </p>,
#  <p><a href="/wiki/Software_suite" title="Software suite">Software suites</a> containing a variety of machine learning algorithms include the following:
#  </p>]

# %%
# To get the content within all poaragrphs loop through it
article_content = ""
for p in paragraphs:  
    article_content += p.text

# %%
print(article_content)
# Out:
# Machine learning (ML) is the study of computer algorithms that improve automatically through experience and by the use of data.[1] It is seen as a part of artificial intelligence. Machine learning algorithms build a model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.[2] Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.[3]
# A subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers; but not all machine learning is statistical learning. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning.[5][6] In its application across business problems, machine learning is also referred to as predictive analytics.
# Machine learning involves computers discovering how they can perform tasks without being explicitly programmed to do so. It involves computers learning from data provided so that they carry out certain tasks. For simple tasks assigned to computers, it is possible to program algorithms telling the machine how to execute all steps required to solve the problem at hand; on the computer's part, no learning is needed. For more advanced tasks, it can be challenging for a human to manually create the needed algorithms. In practice, it can turn out to be more effective to help the machine develop its own algorithm, rather than having human programmers specify every needed step.[7]
# The discipline of machine learning employs various approaches to teach computers to accomplish tasks where no fully satisfactory algorithm is available. In cases where vast numbers of potential answers exist, one approach is to label some of the correct answers as valid. This can then be used as training data for the computer to improve the algorithm(s) it uses to determine correct answers. For example, to train a system for the task of digital character recognition, the MNIST dataset of handwritten digits has often been used.[7]
# The term machine learning was coined in 1959 by Arthur Samuel, an American IBMer and pioneer in the field of computer gaming and artificial intelligence.[8][9] A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.[10] Interest related to pattern recognition continued into the 1970s, as described by Duda and Hart in 1973.[11] In 1981 a report was given on using teaching strategies so that a neural network learns to recognize 40 characters (26 letters, 10 digits, and 4 special symbols) from a computer terminal.[12]
# Tom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E."[13] This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms. This follows Alan Turing's proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?" is replaced with the question "Can machines do what we (as thinking entities) can do?".[14]
# Modern day machine learning has two objectives, one is to classify data based on models which have been developed, the other purpose is to make predictions for future outcomes based on these models. A hypothetical algorithm specific to classifying data may use computer vision of moles coupled with supervised learning in order to train it to classify the cancerous moles. Where as, a machine learning algorithm for stock trading may inform the trader of future potential predictions.[15]
# As a scientific endeavor, machine learning grew out of the quest for artificial intelligence. In the early days of AI as an academic discipline, some researchers were interested in having machines learn from data. They attempted to approach the problem with various symbolic methods, as well as what was then termed "neural networks"; these were mostly perceptrons and other models that were later found to be reinventions of the generalized linear models of statistics.[18] Probabilistic reasoning was also employed, especially in automated medical diagnosis.[19]:488
# However, an increasing emphasis on the logical, knowledge-based approach caused a rift between AI and machine learning. Probabilistic systems were plagued by theoretical and practical problems of data acquisition and representation.[19]:488 By 1980, expert systems had come to dominate AI, and statistics was out of favor.[20] Work on symbolic/knowledge-based learning did continue within AI, leading to inductive logic programming, but the more statistical line of research was now outside the field of AI proper, in pattern recognition and information retrieval.[19]:708–710; 755 Neural networks research had been abandoned by AI and computer science around the same time. This line, too, was continued outside the AI/CS field, as "connectionism", by researchers from other disciplines including Hopfield, Rumelhart and Hinton. Their main success came in the mid-1980s with the reinvention of backpropagation.[19]:25
# Machine learning (ML), reorganized as a separate field, started to flourish in the 1990s. The field changed its goal from achieving artificial intelligence to tackling solvable problems of a practical nature. It shifted focus away from the symbolic approaches it had inherited from AI, and toward methods and models borrowed from statistics and probability theory.[20]
# As of 2020, many sources continue to assert that machine learning remains a subfield of AI.[21][22][16] The main disagreement is whether all of ML is part of AI, as this would mean that anyone using ML could claim they are using AI. Others have the view that not all of ML is part of AI[23][24][25] where only an 'intelligent' subset of ML is part of AI.[26]
# The question to what is the difference between ML and AI is answered by Judea Pearl in The Book of Why.[27] Accordingly ML learns and predicts based on passive observations, whereas AI implies an agent  interacting with the environment to learn and take actions that maximize its chance of successfully achieving its goals.[30]
# Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases). Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy. Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge. Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.
# Machine learning also has intimate ties to optimization: many learning problems are formulated as minimization of some loss function on a training set of examples. Loss functions express the discrepancy between the predictions of the model being trained and the actual problem instances (for example, in classification, one wants to assign a label to instances, and models are trained to correctly predict the pre-assigned labels of a set of examples).[31]
# The difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples. Characterizing the generalization of various learning algorithms is an active topic of current research, especially for deep learning algorithms.
# Machine learning and statistics are closely related fields in terms of methods, but distinct in their principal goal: statistics draws population inferences from a sample, while machine learning finds generalizable predictive patterns.[32] According to Michael I. Jordan, the ideas of machine learning, from methodological principles to theoretical tools, have had a long pre-history in statistics.[33] He also suggested the term data science as a placeholder to call the overall field.[33]
# Leo Breiman distinguished two statistical modeling paradigms: data model and algorithmic model,[34] wherein "algorithmic model" means more or less the machine learning algorithms like Random forest.
# Some statisticians have adopted methods from machine learning, leading to a combined field that they call statistical learning.[35]
#
# A core objective of a learner is to generalize from its experience.[4][36] Generalization in this context is the ability of a learning machine to perform accurately on new, unseen examples/tasks after having experienced a learning data set. The training examples come from some generally unknown probability distribution (considered representative of the space of occurrences) and the learner has to build a general model about this space that enables it to produce sufficiently accurate predictions in new cases.
# The computational analysis of machine learning algorithms and their performance is a branch of theoretical computer science known as computational learning theory. Because training sets are finite and the future is uncertain, learning theory usually does not yield guarantees of the performance of algorithms. Instead, probabilistic bounds on the performance are quite common. The bias–variance decomposition is one way to quantify generalization error.
# For the best performance in the context of generalization, the complexity of the hypothesis should match the complexity of the function underlying the data. If the hypothesis is less complex than the function, then the model has under fitted the data. If the complexity of the model is increased in response, then the training error decreases. But if the hypothesis is too complex, then the model is subject to overfitting and generalization will be poorer.[37]
# In addition to performance bounds, learning theorists study the time complexity and feasibility of learning. In computational learning theory, a computation is considered feasible if it can be done in polynomial time. There are two kinds of time complexity results. Positive results show that a certain class of functions can be learned in polynomial time. Negative results show that certain classes cannot be learned in polynomial time.
#
# Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:
# Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.[38] The data is known as training data, and consists of a set of training examples. Each training example has one or more inputs and the desired output, also known as a supervisory signal.  In the mathematical model, each training example is represented by an array or vector, sometimes called a feature vector, and the training data is represented by a matrix. Through iterative optimization of an objective function, supervised learning algorithms learn a function that can be used to predict the output associated with new inputs.[39] An optimal function will allow the algorithm to correctly determine the output for inputs that were not a part of the training data. An algorithm that improves the accuracy of its outputs or predictions over time is said to have learned to perform that task.[13]
# Types of supervised learning algorithms include active learning, classification and regression.[40] Classification algorithms are used when the outputs are restricted to a limited set of values, and regression algorithms are used when the outputs may have any numerical value within a range. As an example, for a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email.
# Similarity learning is an area of supervised machine learning closely related to regression and classification, but the goal is to learn from examples using a similarity function that measures how similar or related two objects are. It has applications in ranking, recommendation systems, visual identity tracking, face verification, and speaker verification.
# Unsupervised learning algorithms take a set of data that contains only inputs, and find structure in the data, like grouping or clustering of data points. The algorithms, therefore, learn from test data that has not been labeled, classified or categorized. Instead of responding to feedback, unsupervised learning algorithms identify commonalities in the data and react based on the presence or absence of such commonalities in each new piece of data. A central application of unsupervised learning is in the field of density estimation in statistics, such as finding the probability density function.[41] Though unsupervised learning encompasses other domains involving summarizing and explaining data features.
# Cluster analysis is the assignment of a set of observations into subsets (called clusters) so that observations within the same cluster are similar according to one or more predesignated criteria, while observations drawn from different clusters are dissimilar. Different clustering techniques make different assumptions on the structure of the data, often defined by some similarity metric and evaluated, for example, by internal compactness, or the similarity between members of the same cluster, and separation, the difference between clusters. Other methods are based on estimated density and graph connectivity.
# Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data). Some of the training examples are missing training labels,  yet many machine-learning researchers have found that unlabeled data, when used in conjunction with a small amount of labeled data, can produce a considerable improvement in learning accuracy.
# In weakly supervised learning, the training labels are noisy, limited, or imprecise; however, these labels are often cheaper to obtain, resulting in larger effective training sets.[42]
# Reinforcement learning is an area of machine learning concerned with how software agents ought to take actions in an environment so as to maximize some notion of cumulative reward. Due to its generality, the field is studied in many other disciplines, such as game theory, control theory, operations research, information theory, simulation-based optimization, multi-agent systems, swarm intelligence, statistics and genetic algorithms. In machine learning, the environment is typically represented as a Markov decision process (MDP). Many reinforcement learning algorithms use dynamic programming techniques.[43] Reinforcement learning algorithms do not assume knowledge of an exact mathematical model of the MDP, and are used when exact models are infeasible. Reinforcement learning algorithms are used in autonomous vehicles or in learning to play a game against a human opponent.
# The Dimensionality reduction is a process of reducing the number of random variables under the consideration by obtaining a set of principal variables.[44] In other words, it is a process of reducing the dimension of your feature set also called no of features. Most of the dimensionality reduction techniques can be considered as either feature elimination or extraction.
# One of the popular method of dimensionality reduction is called as principal component analysis.
# The PCA involves changing higher dimensional data (eg. 3D) to a smaller space (eg. 2D). This results in a smaller dimension of data, (2D instead of 3D) while keeping all original variables in the model without changing the data.[45]
# Other approaches have been developed which don't fit neatly into this three-fold categorisation, and sometimes more than one is used by the same machine learning system. For example topic modeling,  meta learning.[46]
# As of 2020, deep learning has become the dominant approach for much ongoing work in the field of machine learning.[7]
# Self-learning as a machine learning paradigm was introduced in 1982 along with a neural network capable of self-learning named crossbar adaptive array (CAA).[47] It is a learning with no external rewards and no external teacher advice. The CAA self-learning algorithm computes, in a crossbar fashion, both decisions about actions and emotions (feelings) about consequence situations. The system is driven by the interaction between cognition and emotion.[48]
# The self-learning algorithm updates a memory matrix W =||w(a,s)|| such that in each iteration executes the following machine learning routine:
# It is a system with only one input, situation s, and only one output, action (or behavior) a. There is neither a separate reinforcement input nor an advice input from the environment. The backpropagated value (secondary reinforcement) is the emotion toward the consequence situation. The CAA exists in two environments, one is the behavioral environment where it behaves, and the other is the genetic environment, wherefrom it initially and only once receives initial emotions about situations to be encountered in the behavioral environment. After receiving the genome (species) vector from the genetic environment, the CAA learns a goal-seeking behavior, in an environment that contains both desirable and undesirable situations.[49]
# Several learning algorithms aim at discovering better representations of the inputs provided during training.[50] Classic examples include principal components analysis and cluster analysis. Feature learning algorithms, also called representation learning algorithms, often attempt to preserve the information in their input but also transform it in a way that makes it useful, often as a pre-processing step before performing classification or predictions. This technique allows reconstruction of the inputs coming from the unknown data-generating distribution, while not being necessarily faithful to configurations that are implausible under that distribution. This replaces manual feature engineering, and allows a machine to both learn the features and use them to perform a specific task.
# Feature learning can be either supervised or unsupervised. In supervised feature learning, features are learned using labeled input data. Examples include artificial neural networks, multilayer perceptrons, and supervised dictionary learning. In unsupervised feature learning, features are learned with unlabeled input data.  Examples include dictionary learning, independent component analysis, autoencoders, matrix factorization[51] and various forms of clustering.[52][53][54]
# Manifold learning algorithms attempt to do so under the constraint that the learned representation is low-dimensional. Sparse coding algorithms attempt to do so under the constraint that the learned representation is sparse, meaning that the mathematical model has many zeros. Multilinear subspace learning algorithms aim to learn low-dimensional representations directly from tensor representations for multidimensional data, without reshaping them into higher-dimensional vectors.[55] Deep learning algorithms discover multiple levels of representation, or a hierarchy of features, with higher-level, more abstract features defined in terms of (or generating) lower-level features. It has been argued that an intelligent machine is one that learns a representation that disentangles the underlying factors of variation that explain the observed data.[56]
# Feature learning is motivated by the fact that machine learning tasks such as classification often require input that is mathematically and computationally convenient to process. However, real-world data such as images, video, and sensory data has not yielded to attempts to algorithmically define specific features. An alternative is to discover such features or representations through examination, without relying on explicit algorithms.
# Sparse dictionary learning is a feature learning method where a training example is represented as a linear combination of basis functions, and is assumed to be a sparse matrix. The method is strongly NP-hard and difficult to solve approximately.[57] A popular heuristic method for sparse dictionary learning is the K-SVD algorithm. Sparse dictionary learning has been applied in several contexts. In classification, the problem is to determine the class to which a previously unseen training example belongs. For a dictionary where each class has already been built, a new training example is associated with the class that is best sparsely represented by the corresponding dictionary. Sparse dictionary learning has also been applied in image de-noising. The key idea is that a clean image patch can be sparsely represented by an image dictionary, but the noise cannot.[58]
# In data mining, anomaly detection, also known as outlier detection, is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.[59] Typically, the anomalous items represent an issue such as bank fraud, a structural defect, medical problems or errors in a text. Anomalies are referred to as outliers, novelties, noise, deviations and exceptions.[60]
# In particular, in the context of abuse and network intrusion detection, the interesting objects are often not rare objects, but unexpected bursts of inactivity. This pattern does not adhere to the common statistical definition of an outlier as a rare object, and many outlier detection methods (in particular, unsupervised algorithms) will fail on such data unless it has been aggregated appropriately. Instead, a cluster analysis algorithm may be able to detect the micro-clusters formed by these patterns.[61]
# Three broad categories of anomaly detection techniques exist.[62] Unsupervised anomaly detection techniques detect anomalies in an unlabeled test data set under the assumption that the majority of the instances in the data set are normal, by looking for instances that seem to fit least to the remainder of the data set. Supervised anomaly detection techniques require a data set that has been labeled as "normal" and "abnormal" and involves training a classifier (the key difference to many other statistical classification problems is the inherently unbalanced nature of outlier detection). Semi-supervised anomaly detection techniques construct a model representing normal behavior from a given normal training data set and then test the likelihood of a test instance to be generated by the model.
# In developmental robotics, robot learning algorithms generate their own sequences of learning experiences, also known as a curriculum, to cumulatively acquire new skills through self-guided exploration and social interaction with humans. These robots use guidance mechanisms such as active learning, maturation, motor synergies and imitation.
# Association rule learning is a rule-based machine learning method for discovering relationships between variables in large databases. It is intended to identify strong rules discovered in databases using some measure of "interestingness".[63]
# Rule-based machine learning is a general term for any machine learning method that identifies, learns, or evolves "rules" to store, manipulate or apply knowledge. The defining characteristic of a rule-based machine learning algorithm is the identification and utilization of a set of relational rules that collectively represent the knowledge captured by the system. This is in contrast to other machine learning algorithms that commonly identify a singular model that can be universally applied to any instance in order to make a prediction.[64] Rule-based machine learning approaches include learning classifier systems, association rule learning, and artificial immune systems.
# Based on the concept of strong rules, Rakesh Agrawal, Tomasz Imieliński and Arun Swami introduced association rules for discovering regularities between products in large-scale transaction data recorded by point-of-sale (POS) systems in supermarkets.[65] For example, the rule
#
#
#
# {
#
# o
# n
# i
# o
# n
# s
# ,
# p
# o
# t
# a
# t
# o
# e
# s
#
# }
# ⇒
# {
#
# b
# u
# r
# g
# e
# r
#
# }
#
#
# {\displaystyle \{\mathrm {onions,potatoes} \}\Rightarrow \{\mathrm {burger} \}}
#
#  found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat. Such information can be used as the basis for decisions about marketing activities such as promotional pricing or product placements. In addition to market basket analysis, association rules are employed today in application areas including Web usage mining, intrusion detection, continuous production, and bioinformatics. In contrast with sequence mining, association rule learning typically does not consider the order of items either within a transaction or across transactions.
# Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning. They seek to identify a set of context-dependent rules that collectively store and apply knowledge in a piecewise manner in order to make predictions.[66]
# Inductive logic programming (ILP) is an approach to rule-learning using logic programming as a uniform representation for input examples, background knowledge, and hypotheses. Given an encoding of the known background knowledge and a set of examples represented as a logical database of facts, an ILP system will derive a hypothesized logic program that entails all positive and no negative examples. Inductive programming is a related field that considers any kind of programming language for representing hypotheses (and not only logic programming), such as functional programs.
# Inductive logic programming is particularly useful in bioinformatics and natural language processing. Gordon Plotkin and Ehud Shapiro laid the initial theoretical foundation for inductive machine learning in a logical setting.[67][68][69] Shapiro built their first implementation (Model Inference System) in 1981: a Prolog program that inductively inferred logic programs from positive and negative examples.[70] The term inductive here refers to philosophical induction, suggesting a theory to explain observed facts, rather than mathematical induction, proving a property for all members of a well-ordered set.
# Performing machine learning involves creating a model, which is trained on some training data and then can process additional data to make predictions. Various types of models have been used and researched for machine learning systems.
# Artificial neural networks (ANNs), or connectionist systems, are computing systems vaguely inspired by the biological neural networks that constitute animal brains. Such systems "learn" to perform tasks by considering examples, generally without being programmed with any task-specific rules.
# An ANN is a model based on a collection of connected units or nodes called "artificial neurons", which loosely model the neurons in a biological brain. Each connection, like the synapses in a biological brain, can transmit information, a "signal", from one artificial neuron to another. An artificial neuron that receives a signal can process it and then signal additional artificial neurons connected to it. In common ANN implementations, the signal at a connection between artificial neurons is a real number, and the output of each artificial neuron is computed by some non-linear function of the sum of its inputs. The connections between artificial neurons are called "edges". Artificial neurons and edges typically have a weight that adjusts as learning proceeds. The weight increases or decreases the strength of the signal at a connection. Artificial neurons may have a threshold such that the signal is only sent if the aggregate signal crosses that threshold. Typically, artificial neurons are aggregated into layers. Different layers may perform different kinds of transformations on their inputs. Signals travel from the first layer (the input layer) to the last layer (the output layer), possibly after traversing the layers multiple times.
# The original goal of the ANN approach was to solve problems in the same way that a human brain would. However, over time, attention moved to performing specific tasks, leading to deviations from biology. Artificial neural networks have been used on a variety of tasks, including computer vision, speech recognition, machine translation, social network filtering, playing board and video games and medical diagnosis.
# Deep learning consists of multiple hidden layers in an artificial neural network. This approach tries to model the way the human brain processes light and sound into vision and hearing. Some successful applications of deep learning are computer vision and speech recognition.[71]
# Decision tree learning uses a decision tree as a predictive model to go from observations about an item (represented in the branches) to conclusions about the item's target value (represented in the leaves). It is one of the predictive modeling approaches used in statistics, data mining, and machine learning. Tree models where the target variable can take a discrete set of values are called classification trees; in these tree structures, leaves represent class labels and branches represent conjunctions of features that lead to those class labels. Decision trees where the target variable can take continuous values (typically real numbers) are called regression trees. In decision analysis, a decision tree can be used to visually and explicitly represent decisions and decision making. In data mining, a decision tree describes data, but the resulting classification tree can be an input for decision making.
# Support-vector machines (SVMs), also known as support-vector networks, are a set of related supervised learning methods used for classification and regression. Given a set of training examples, each marked as belonging to one of two categories, an SVM training algorithm builds a model that predicts whether a new example falls into one category or the other.[72]  An SVM training algorithm is a non-probabilistic, binary, linear classifier, although methods such as Platt scaling exist to use SVM in a probabilistic classification setting. In addition to performing linear classification, SVMs can efficiently perform a non-linear classification using what is called the kernel trick, implicitly mapping their inputs into high-dimensional feature spaces.
# Regression analysis encompasses a large variety of statistical methods to estimate the relationship between input variables and their associated features. Its most common form is linear regression, where a single line is drawn to best fit the given data according to a mathematical criterion such as ordinary least squares. The latter is often extended by regularization (mathematics) methods to mitigate overfitting and bias, as in ridge regression. When dealing with non-linear problems, go-to models include polynomial regression (for example, used for trendline fitting in Microsoft Excel[73]), logistic regression (often used in statistical classification) or even kernel regression, which introduces non-linearity by taking advantage of the kernel trick to implicitly map input variables to higher-dimensional space.
# A Bayesian network, belief network, or directed acyclic graphical model is a probabilistic graphical model that represents a set of random variables and their conditional independence with a directed acyclic graph (DAG). For example, a Bayesian network could represent the probabilistic relationships between diseases and symptoms. Given symptoms, the network can be used to compute the probabilities of the presence of various diseases. Efficient algorithms exist that perform inference and learning. Bayesian networks that model sequences of variables, like speech signals or protein sequences, are called dynamic Bayesian networks. Generalizations of Bayesian networks that can represent and solve decision problems under uncertainty are called influence diagrams.
# A genetic algorithm (GA) is a search algorithm and heuristic technique that mimics the process of natural selection, using methods such as mutation and crossover to generate new genotypes in the hope of finding good solutions to a given problem. In machine learning, genetic algorithms were used in the 1980s and 1990s.[74][75] Conversely, machine learning techniques have been used to improve the performance of genetic and evolutionary algorithms.[76]
# Usually, machine learning models require a lot of data in order for them to perform well. Usually, when training a machine learning model, one needs to collect a large, representative sample of data from a training set. Data from the training set can be as varied as a corpus of text, a collection of images, and data collected from individual users of a service. Overfitting is something to watch out for when training a machine learning model. Trained models derived from biased data can result in skewed or undesired predictions. Algorithmic bias is a potential result from data not fully prepared for training.
# Federated learning is an adapted form of distributed artificial intelligence to training machine learning models that decentralizes the training process, allowing for users' privacy to be maintained by not needing to send their data to a centralized server. This also increases efficiency by decentralizing the training process to many devices. For example, Gboard uses federated machine learning to train search query prediction models on users' mobile phones without having to send individual searches back to Google.[77]
# There are many applications for machine learning, including:
# In 2006, the media-services provider Netflix held the first "Netflix Prize" competition to find a program to better predict user preferences and improve the accuracy of its existing Cinematch movie recommendation algorithm by at least 10%.  A joint team made up of researchers from AT&T Labs-Research in collaboration with the teams Big Chaos and Pragmatic Theory built an ensemble model to win the Grand Prize in 2009 for $1 million.[79] Shortly after the prize was awarded, Netflix realized that viewers' ratings were not the best indicators of their viewing patterns ("everything is a recommendation") and they changed their recommendation engine accordingly.[80] In 2010 The Wall Street Journal wrote about the firm Rebellion Research and their use of machine learning to predict the financial crisis.[81] In 2012, co-founder of Sun Microsystems, Vinod Khosla, predicted that 80% of medical doctors' jobs would be lost in the next two decades to automated machine learning medical diagnostic software.[82] In 2014, it was reported that a machine learning algorithm had been applied in the field of art history to study fine art paintings and that it may have revealed previously unrecognized influences among artists.[83] In 2019 Springer Nature published the first research book created using machine learning.[84] In 2020, machine learning technology was used to help make diagnoses and aid researchers in developing a cure for COVID-19.[85] Machine learning is recently applied to predict the green behavior of human-being.[86] Recently, machine learning technology is also applied to optimise smartphone's performance and thermal behaviour based on the user's interaction with the phone.[87][88]
# Although machine learning has been transformative in some fields, machine-learning programs often fail to deliver expected results.[89][90][91] Reasons for this are numerous: lack of (suitable) data, lack of access to the data, data bias, privacy problems, badly chosen tasks and algorithms, wrong tools and people, lack of resources, and evaluation problems.[92]
# In 2018, a self-driving car from Uber failed to detect a pedestrian, who was killed after a collision.[93] Attempts to use machine learning in healthcare with the IBM Watson system failed to deliver even after years of time and billions of dollars invested.[94][95]
# Machine learning has been used as a strategy to update the evidence related to systematic review and increased reviewer burden related to the growth of biomedical literature. While it has improved with training sets, it has not yet developed sufficiently to reduce the workload burden without limiting the necessary sensitivity for the findings research themselves.[96]
# Machine learning approaches in particular can suffer from different data biases. A machine learning system trained specifically on current customers may not be able to predict the needs of new customer groups that are not represented in the training data. When trained on man-made data, machine learning is likely to pick up the constitutional and unconscious biases already present in society.[97] Language models learned from data have been shown to contain human-like biases.[98][99] Machine learning systems used for criminal risk assessment have been found to be biased against black people.[100][101] In 2015, Google photos would often tag black people as gorillas,[102] and in 2018 this still was not well resolved, but Google reportedly was still using the workaround to remove all gorillas from the training data, and thus was not able to recognize real gorillas at all.[103] Similar issues with recognizing non-white people have been found in many other systems.[104] In 2016, Microsoft tested a chatbot that learned from Twitter, and it quickly picked up racist and sexist language.[105] Because of such challenges, the effective use of machine learning may take longer to be adopted in other domains.[106] Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...It’s inspired by people, it’s created by people, and—most importantly—it impacts people. It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”[107]
# Classification of machine learning models can be validated by accuracy estimation techniques like the holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set. In comparison, the K-fold-cross-validation method randomly partitions the data into K subsets and then K experiments are performed each respectively considering 1 subset for evaluation and the remaining K-1 subsets for training the model. In addition to the holdout and cross-validation methods, bootstrap, which samples n instances with replacement from the dataset, can be used to assess model accuracy.[108]
# In addition to overall accuracy, investigators frequently report sensitivity and specificity meaning True Positive Rate (TPR) and True Negative Rate (TNR) respectively. Similarly, investigators sometimes report the false positive rate (FPR) as well as the false negative rate (FNR). However, these rates are ratios that fail to reveal their numerators and denominators. The total operating characteristic (TOC) is an effective method to express a model's diagnostic ability. TOC shows the numerators and denominators of the previously mentioned rates, thus TOC provides more information than the commonly used receiver operating characteristic (ROC) and ROC's associated area under the curve (AUC).[109]
# Machine learning poses a host of ethical questions. Systems which are trained on datasets collected with biases may exhibit these biases upon use (algorithmic bias), thus digitizing cultural prejudices.[110] For example, in 1988, the UK's Commission for Racial Equality found that St. George's Medical School had been using a computer program trained from data of previous admissions staff and this program had denied nearly 60 candidates who were found to be either women or had non-European sounding names.[97] Using job hiring data from a firm with racist hiring policies may lead to a machine learning system duplicating the bias by scoring job applicants by similarity to previous successful applicants.[111][112] Responsible collection of data and documentation of algorithmic rules used by a system thus is a critical part of machine learning.
# AI can be well-equipped to make decisions in technical fields, which rely heavily on data and historical information. These decisions rely on objectivity and logical reasoning.[113] Because human languages contain biases, machines trained on language corpora will necessarily also learn these biases.[114][115]
# Other forms of ethical challenges, not related to personal biases, are seen in health care. There are concerns among health care professionals that these systems might not be designed in the public's interest but as income-generating machines.[116] This is especially true in the United States where there is a long-standing ethical dilemma of improving health care, but also increasing profits. For example, the algorithms could be designed to provide patients with unnecessary tests or medication in which the algorithm's proprietary owners hold stakes. There is  potential for machine learning in health care to provide professionals an additional tool to diagnose, medicate, and plan recovery paths for patients, but this requires these biases to be mitigated.[117]
# Since the 2010s, advances in both machine learning algorithms and computer hardware have led to more efficient methods for training deep neural networks (a particular narrow subdomain of machine learning) that contain many layers of non-linear hidden units.[118] By 2019, graphic processing units (GPUs), often with AI-specific enhancements, had displaced CPUs as the dominant method of training large-scale commercial cloud AI.[119] OpenAI estimated the hardware compute used in the largest deep learning projects from AlexNet (2012) to AlphaZero (2017), and found a 300,000-fold increase in the amount of compute required, with a doubling-time trendline of 3.4 months.[120][121]
# Software suites containing a variety of machine learning algorithms include the following:

# %% [markdown]
# ## Raw Article Processing

# %%
# tokenize by word using nltk
article_tokens = nltk.word_tokenize(article_content)

# %%
# get stop words
stop_words = stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# clean up tokens - stopWords, nonAlpha, convert to lower case
print(f"Before cleaning, length is {len(article_tokens)}")
token_cleaned = [word.lower() for word in article_tokens if word.isalpha() and word not in stop_words];
print(f"After cleaning characters, length is {len(token_cleaned)}\n")
print(token_cleaned)
# Out:
# Before cleaning, length is 7720
# After cleaning characters, length is 3982
#
# ['machine', 'learning', 'ml', 'study', 'computer', 'algorithms', 'improve', 'automatically', 'experience', 'use', 'data', 'it', 'seen', 'part', 'artificial', 'intelligence', 'machine', 'learning', 'algorithms', 'build', 'model', 'based', 'sample', 'data', 'known', 'training', 'data', 'order', 'make', 'predictions', 'decisions', 'without', 'explicitly', 'programmed', 'machine', 'learning', 'algorithms', 'used', 'wide', 'variety', 'applications', 'medicine', 'email', 'filtering', 'speech', 'recognition', 'computer', 'vision', 'difficult', 'unfeasible', 'develop', 'conventional', 'algorithms', 'perform', 'needed', 'tasks', 'a', 'subset', 'machine', 'learning', 'closely', 'related', 'computational', 'statistics', 'focuses', 'making', 'predictions', 'using', 'computers', 'machine', 'learning', 'statistical', 'learning', 'the', 'study', 'mathematical', 'optimization', 'delivers', 'methods', 'theory', 'application', 'domains', 'field', 'machine', 'learning', 'data', 'mining', 'related', 'field', 'study', 'focusing', 'exploratory', 'data', 'analysis', 'unsupervised', 'learning', 'in', 'application', 'across', 'business', 'problems', 'machine', 'learning', 'also', 'referred', 'predictive', 'analytics', 'machine', 'learning', 'involves', 'computers', 'discovering', 'perform', 'tasks', 'without', 'explicitly', 'programmed', 'it', 'involves', 'computers', 'learning', 'data', 'provided', 'carry', 'certain', 'tasks', 'for', 'simple', 'tasks', 'assigned', 'computers', 'possible', 'program', 'algorithms', 'telling', 'machine', 'execute', 'steps', 'required', 'solve', 'problem', 'hand', 'computer', 'part', 'learning', 'needed', 'for', 'advanced', 'tasks', 'challenging', 'human', 'manually', 'create', 'needed', 'algorithms', 'in', 'practice', 'turn', 'effective', 'help', 'machine', 'develop', 'algorithm', 'rather', 'human', 'programmers', 'specify', 'every', 'needed', 'step', 'the', 'discipline', 'machine', 'learning', 'employs', 'various', 'approaches', 'teach', 'computers', 'accomplish', 'tasks', 'fully', 'satisfactory', 'algorithm', 'available', 'in', 'cases', 'vast', 'numbers', 'potential', 'answers', 'exist', 'one', 'approach', 'label', 'correct', 'answers', 'valid', 'this', 'used', 'training', 'data', 'computer', 'improve', 'algorithm', 'uses', 'determine', 'correct', 'answers', 'for', 'example', 'train', 'system', 'task', 'digital', 'character', 'recognition', 'mnist', 'dataset', 'handwritten', 'digits', 'often', 'used', 'the', 'term', 'machine', 'learning', 'coined', 'arthur', 'samuel', 'american', 'ibmer', 'pioneer', 'field', 'computer', 'gaming', 'artificial', 'intelligence', 'a', 'representative', 'book', 'machine', 'learning', 'research', 'nilsson', 'book', 'learning', 'machines', 'dealing', 'mostly', 'machine', 'learning', 'pattern', 'classification', 'interest', 'related', 'pattern', 'recognition', 'continued', 'described', 'duda', 'hart', 'in', 'report', 'given', 'using', 'teaching', 'strategies', 'neural', 'network', 'learns', 'recognize', 'characters', 'letters', 'digits', 'special', 'symbols', 'computer', 'terminal', 'tom', 'mitchell', 'provided', 'widely', 'quoted', 'formal', 'definition', 'algorithms', 'studied', 'machine', 'learning', 'field', 'a', 'computer', 'program', 'said', 'learn', 'experience', 'e', 'respect', 'class', 'tasks', 't', 'performance', 'measure', 'p', 'performance', 'tasks', 't', 'measured', 'p', 'improves', 'experience', 'this', 'definition', 'tasks', 'machine', 'learning', 'concerned', 'offers', 'fundamentally', 'operational', 'definition', 'rather', 'defining', 'field', 'cognitive', 'terms', 'this', 'follows', 'alan', 'turing', 'proposal', 'paper', 'computing', 'machinery', 'intelligence', 'question', 'can', 'machines', 'think', 'replaced', 'question', 'can', 'machines', 'thinking', 'entities', 'modern', 'day', 'machine', 'learning', 'two', 'objectives', 'one', 'classify', 'data', 'based', 'models', 'developed', 'purpose', 'make', 'predictions', 'future', 'outcomes', 'based', 'models', 'a', 'hypothetic ...

# %% [markdown]
# ## Weighted Term Frequency & Sentence Scoring

# %%
# get words freq
freq = {}
for word in token_cleaned:
    freq[word] =  freq.get(word, 0) + 1
#print(freq)
# sort from high to low
sorted_freq = dict(sorted(freq.items(), key = lambda item: item[1], reverse = True))
print(sorted_freq)
# Out:
# {'learning': 166, 'machine': 93, 'data': 87, 'training': 48, 'algorithms': 44, 'in': 36, 'model': 34, 'the': 30, 'set': 30, 'used': 29, 'artificial': 22, 'algorithm': 21, 'methods': 19, 'also': 18, 'classification': 18, 'one': 17, 'example': 17, 'ai': 17, 'field': 16, 'models': 16, 'systems': 16, 'supervised': 15, 'examples': 15, 'computer': 14, 'tasks': 14, 'using': 14, 'often': 14, 'unsupervised': 13, 'many': 13, 'input': 13, 'analysis': 12, 'this': 12, 'system': 12, 'called': 12, 'features': 12, 'use': 11, 'it': 11, 'known': 11, 'predictions': 11, 'a': 11, 'related': 11, 'mining': 11, 'problems': 11, 'for': 11, 'performance': 11, 'may': 11, 'networks': 11, 'knowledge': 11, 'method': 11, 'feature': 11, 'regression': 11, 'based': 10, 'perform': 10, 'statistics': 10, 'theory': 10, 'neural': 10, 'learn': 10, 'learned': 10, 'inputs': 10, 'represented': 10, 'decision': 10, 'detection': 10, 'without': 9, 'research': 9, 'network': 9, 'time': 9, 'environment': 9, 'function': 9, 'trained': 9, 'new': 9, 'signal': 9, 'techniques': 9, 'process': 9, 'dictionary': 9, 'rules': 9, 'biases': 9, 'ml': 8, 'intelligence': 8, 'make': 8, 'statistical': 8, 'two': 8, 'found': 8, 'programming': 8, 'variables': 8, 'neurons': 8, 'part': 7, 'mathematical': 7, 'program': 7, 'human': 7, 'approaches': 7, 'approach': 7, 'machines': 7, 'given': 7, 'class': 7, 'representation': 7, 'logic': 7, 'information': 7, 'would': 7, 'different': 7, 'accuracy': 7, 'deep': 7, 'output': 7, 'include': 7, 'test': 7, 'reinforcement': 7, 'genetic': 7, 'typically': 7, 'sparse': 7, 'represent': 7, 'tree': 7, 'people': 7, 'order': 6, 'decisions': 6, 'recognition': 6, 'optimization': 6, 'various': 6, 'probabilistic': 6, 'medical': 6, 'inductive': 6, 'observations': 6, 'take': 6, 'predict': 6, 'labels': 6, 'generalization': 6, 'there': 6, 'an': 6, 'labeled': 6, 'applied': 6, 'bias': 6, 'study': 5, 'improve': 5, 'vision': 5, 'computers': 5, 'involves': 5, 'problem': 5, 'task': 5, 'learns': 5, 'researchers': 5, 'linear': 5, 'however': 5, 'including': 5, 'goal': 5, 'discovery': 5, 'previously': 5, 'instances': 5, 'algorithmic': 5, 'like': 5, 'complexity': 5, 'addition': 5, 'results': 5, 'positive': 5, 'negative': 5, 'similarity': 5, 'cluster': 5, 'either': 5, 'performing': 5, 'anomaly': 5, 'association': 5, 'language': 5, 'layers': 5, 'bayesian': 5, 'experience': 4, 'variety': 4, 'applications': 4, 'speech': 4, 'needed': 4, 'computational': 4, 'application': 4, 'predictive': 4, 'discovering': 4, 'solve': 4, 'effective': 4, 'step': 4, 'potential': 4, 'exist': 4, 'uses': 4, 'term': 4, 'book': 4, 'pattern': 4, 'definition': 4, 'specific': 4, 'as': 4, 'well': 4, 'logical': 4, 'theoretical': 4, 'within': 4, 'separate': 4, 'nature': 4, 'difference': 4, 'unknown': 4, 'usually': 4, 'loss': 4, 'principal': 4, 'space': 4, 'instead': 4, 'common': 4, 'way': 4, 'best': 4, 'polynomial': 4, 'outputs': 4, 'matrix': 4, 'associated': 4, 'recommendation': 4, 'identify': 4, 'component': 4, 'caa': 4, 'behavior': 4, 'representations': 4, 'outlier': 4, 'particular': 4, 'normal': 4, 'classifier': 4, 'rule': 4, 'first': 4, 'brain': 4, 'layer': 4, 'thus': 4, 'rate': 4, 'health': 4, 'care': 4, 'build': 3, 'sample': 3, 'explicitly': 3, 'programmed': 3, 'email': 3, 'subset': 3, 'closely': 3, 'focuses': 3, 'making': 3, 'domains': 3, 'provided': 3, 'certain': 3, 'rather': 3, 'answers': 3, 'determine': 3, 'train': 3, 'representative': 3, 'report': 3, 'e': 3, 'respect': 3, 't': 3, 'p': 3, 'concerned': 3, 'terms': 3, 'question': 3, 'developed': 3, 'future': 3, 'especially': 3, 'work': 3, 'leading': 3, 'line': 3, 'science': 3, 'probability': 3, 'could': 3, 'actions': 3, 'prediction': 3, 'databases': 3, 'learner': 3, 'evaluated': 3, 'ability': 3, 'key': 3, 'functions': 3, 'unseen': 3, 'active': 3, 'fields': 3, 'patterns': 3, 'according': 3, 'modeling': 3, 'random': 3, 'some': 3, 'context': 3, 'distribution': 3, 'considered': 3, 'because': 3, 'sets': 3, 'hypothesis': 3, 'overfitting': 3, 'categories': 3, 'contains': 3,  ...

# %%
# Calculate words weighted freq
weighted_freq = {}
# get maximum freq
max_freq = max(sorted_freq.values())
print(max_freq)

# compute and add to weighted_freq
weighted_freq = {word: count/max_freq for (word, count) in sorted_freq.items()}
print(weighted_freq)
# Out:
# 166
# {'learning': 1.0, 'machine': 0.5602409638554217, 'data': 0.5240963855421686, 'training': 0.2891566265060241, 'algorithms': 0.26506024096385544, 'in': 0.21686746987951808, 'model': 0.20481927710843373, 'the': 0.18072289156626506, 'set': 0.18072289156626506, 'used': 0.1746987951807229, 'artificial': 0.13253012048192772, 'algorithm': 0.12650602409638553, 'methods': 0.1144578313253012, 'also': 0.10843373493975904, 'classification': 0.10843373493975904, 'one': 0.10240963855421686, 'example': 0.10240963855421686, 'ai': 0.10240963855421686, 'field': 0.0963855421686747, 'models': 0.0963855421686747, 'systems': 0.0963855421686747, 'supervised': 0.09036144578313253, 'examples': 0.09036144578313253, 'computer': 0.08433734939759036, 'tasks': 0.08433734939759036, 'using': 0.08433734939759036, 'often': 0.08433734939759036, 'unsupervised': 0.0783132530120482, 'many': 0.0783132530120482, 'input': 0.0783132530120482, 'analysis': 0.07228915662650602, 'this': 0.07228915662650602, 'system': 0.07228915662650602, 'called': 0.07228915662650602, 'features': 0.07228915662650602, 'use': 0.06626506024096386, 'it': 0.06626506024096386, 'known': 0.06626506024096386, 'predictions': 0.06626506024096386, 'a': 0.06626506024096386, 'related': 0.06626506024096386, 'mining': 0.06626506024096386, 'problems': 0.06626506024096386, 'for': 0.06626506024096386, 'performance': 0.06626506024096386, 'may': 0.06626506024096386, 'networks': 0.06626506024096386, 'knowledge': 0.06626506024096386, 'method': 0.06626506024096386, 'feature': 0.06626506024096386, 'regression': 0.06626506024096386, 'based': 0.060240963855421686, 'perform': 0.060240963855421686, 'statistics': 0.060240963855421686, 'theory': 0.060240963855421686, 'neural': 0.060240963855421686, 'learn': 0.060240963855421686, 'learned': 0.060240963855421686, 'inputs': 0.060240963855421686, 'represented': 0.060240963855421686, 'decision': 0.060240963855421686, 'detection': 0.060240963855421686, 'without': 0.05421686746987952, 'research': 0.05421686746987952, 'network': 0.05421686746987952, 'time': 0.05421686746987952, 'environment': 0.05421686746987952, 'function': 0.05421686746987952, 'trained': 0.05421686746987952, 'new': 0.05421686746987952, 'signal': 0.05421686746987952, 'techniques': 0.05421686746987952, 'process': 0.05421686746987952, 'dictionary': 0.05421686746987952, 'rules': 0.05421686746987952, 'biases': 0.05421686746987952, 'ml': 0.04819277108433735, 'intelligence': 0.04819277108433735, 'make': 0.04819277108433735, 'statistical': 0.04819277108433735, 'two': 0.04819277108433735, 'found': 0.04819277108433735, 'programming': 0.04819277108433735, 'variables': 0.04819277108433735, 'neurons': 0.04819277108433735, 'part': 0.04216867469879518, 'mathematical': 0.04216867469879518, 'program': 0.04216867469879518, 'human': 0.04216867469879518, 'approaches': 0.04216867469879518, 'approach': 0.04216867469879518, 'machines': 0.04216867469879518, 'given': 0.04216867469879518, 'class': 0.04216867469879518, 'representation': 0.04216867469879518, 'logic': 0.04216867469879518, 'information': 0.04216867469879518, 'would': 0.04216867469879518, 'different': 0.04216867469879518, 'accuracy': 0.04216867469879518, 'deep': 0.04216867469879518, 'output': 0.04216867469879518, 'include': 0.04216867469879518, 'test': 0.04216867469879518, 'reinforcement': 0.04216867469879518, 'genetic': 0.04216867469879518, 'typically': 0.04216867469879518, 'sparse': 0.04216867469879518, 'represent': 0.04216867469879518, 'tree': 0.04216867469879518, 'people': 0.04216867469879518, 'order': 0.03614457831325301, 'decisions': 0.03614457831325301, 'recognition': 0.03614457831325301, 'optimization': 0.03614457831325301, 'various': 0.03614457831325301, 'probabilistic': 0.03614457831325301, 'medical': 0.03614457831325301, 'inductive': 0.03614457831325301, 'observations': 0.03614457831325301, 'take': 0.03614457831325301, 'predict': 0.03614457831325301, 'labels': 0.03614457831325301, 'generalization': 0.03614457831325301, 'there': 0.03614457831325301, 'an': 0.03614 ...

# %%
# tokenize by sentence and get their scores, store in a dictionary
tokens_sentence = nltk.sent_tokenize(article_content)
sentence_with_scores = {}
# grade sentence based on the sum of its words' total weight
for sentence in tokens_sentence:
    words = nltk.word_tokenize(sentence)
    cur_score = 0
    for word in words:
        cur_score += weighted_freq.get(word.lower(), 0)
    sentence_with_scores[sentence] = cur_score
sentence_with_scores
# Out:
# {'Machine learning (ML) is the study of computer algorithms that improve automatically through experience and by the use of data.': 3.0180722891566263,
#  '[1] It is seen as a part of artificial intelligence.': 0.39156626506024095,
#  'Machine learning algorithms build a model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.': 4.1144578313253,
#  '[2] Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.': 3.5240963855421685,
#  '[3]\nA subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers; but not all machine learning is statistical learning.': 4.644578313253012,
#  'The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning.': 2.3493975903614457,
#  'Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning.': 2.5421686746987953,
#  '[5][6] In its application across business problems, machine learning is also referred to as predictive analytics.': 2.066265060240964,
#  'Machine learning involves computers discovering how they can perform tasks without being explicitly programmed to do so.': 1.903614457831325,
#  'It involves computers learning from data provided so that they carry out certain tasks.': 1.7891566265060241,
#  "For simple tasks assigned to computers, it is possible to program algorithms telling the machine how to execute all steps required to solve the problem at hand; on the computer's part, no learning is needed.": 2.927710843373494,
#  'For more advanced tasks, it can be challenging for a human to manually create the needed algorithms.': 0.8975903614457832,
#  'In practice, it can turn out to be more effective to help the machine develop its own algorithm, rather than having human programmers specify every needed step.': 1.3554216867469884,
#  '[7]\nThe discipline of machine learning employs various approaches to teach computers to accomplish tasks where no fully satisfactory algorithm is available.': 2.132530120481928,
#  'In cases where vast numbers of potential answers exist, one approach is to label some of the correct answers as valid.': 0.7349397590361445,
#  'This can then be used as training data for the computer to improve the algorithm(s) it uses to determine correct answers.': 1.903614457831325,
#  'For example, to train a system for the task of digital character recognition, the MNIST dataset of handwritten digits has often been used.': 1.1265060240963856,
#  '[7]\nThe term machine learning was coined in 1959 by Arthur Samuel, an American IBMer and pioneer in the field of computer gaming and artificial intelligence.': 2.83132530120482,
#  "[8][9] A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.": 5.120481927710843,
#  '[10] Interest related to pattern recognition continued into the 1970s, as described by Duda and Hart in 1973.': 0.6024096385542169,
#  '[11] In 1981 a report was given on using teaching strategies so that a neural network learns to recognize 40 characters (26 letters, 10 digits, and 4 special symbols) from a computer terminal.': 0.855421686746988,
#  '[12]\nTom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E."[13] This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms.': 6.55421686746988,
#  'This follows Alan Turing\'s proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?"': 0.8614457831325302,
#  'is replaced with the question "Can machines do what we (as thinking entities) can do?".': 0.30722891566265065,
#  '[14]\nModern day machine learning has two objectives, one is to classify data based on models which have been developed, the other purpose is to make predictions for future outcomes based on these models.': 3.0180722891566254,
#  'A hypothetical algorithm specific to classifying data may use computer vision of moles coupled with supervised learning in order to train it to classify the cancerous moles.': 2.6566265060240966,
#  'Where as, a machine learning algorithm for stock trading may inform the trader of future potential predictions.': 2.228915662650602,
#  '[15]\nAs a scientific endeavor, machine learning grew out of the quest for artificial intelligence.': 2.1024096385542173,
#  'In the early days of AI as an academic discipline, some researchers were interested in having machines learn from data.': 1.4879518072289155,
#  'They attempted to approach the problem with various symbolic methods, as well as what was then termed "neural networks"; these were mostly perceptrons and other models that were later found to be reinventions of the generalized linear models of statistics.': 1.2228915662650603,
#  '[18] Probabilistic reasoning was also employed, especially in automated medical diagnosis.': 0.463855421686747,
#  '[19]:488\nHowever, an increasing emphasis on the logical, knowledge-based approach caused a rift between AI and machine learning.': 2.072289156626506,
#  'Probabilistic systems were plagued by theoretical and practical problems of data acquisition and representation.': 0.825301204819277,
#  '[19]:488 By 1980, expert systems had come to dominate AI, and statistics was out of favor.': 0.30120481927710846,
#  '[20] Work on symbolic/knowledge-based learning did continue within AI, leading to inductive logic programming, but the more statistical line of research was now outside the field of AI proper, in pattern recognition and information retrieval.': 2.3313253012048194,
#  '[19]:708–710; 755 Neural networks research had been abandoned by AI and computer science around the same time.': 0.6445783132530121,
#  'This line, too, was continued outside the AI/CS field, as "connectionism", by researchers from other disciplines including Hopfield, Rumelhart and Hinton.': 0.542168674698795,
#  'Their main success came in the mid-1980s with the reinvention of backpropagation.': 0.6204819277108433,
#  '[19]:25\nMachine learning (ML), reorganized as a separate field, started to flourish in the 1990s.': 2.234939759036145,
#  'The field changed its goal from achieving artificial intelligence to tackling solvable problems of a practical nature.': 0.6987951807228916,
#  'It shifted focus away from the symbolic approaches it had inherited from AI, and toward methods and models borrowed from statistics and probability theory.': 0.86144578313253,
#  '[20]\nAs of 2020, many sources continue to assert that machine learning remains a subfield of AI.': 1.8674698795180724,
#  '[21][22][16] The main disagreement is whether all of ML is part of AI, as this would mean that anyone using ML could claim they are using AI.': 0.9096385542168675,
#  "Others have the view that not all of ML is part of AI[23][24][25] where only an 'intelligent' subset of ML is part of AI.": 0.6385542168674698,
#  '[26]\nThe question to what is the difference between ML and AI is answered by Judea Pearl in The Book of Why.': 1.0120481927710845,
#  '[27] Accordingly ML learns and predicts based on passive observations, whereas AI implies an agent  interacting with the environment to learn and take actions that maximize its chance of successfully achieving its goals.': 0.7771084337349398,
#  '[30]\nMachine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).': 7.843373493975906,
#  'Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.': 6.337349397590362,
#  'Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge.': 4.5120481927710845,
#  'Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.': 2.343373493975904,
#  'Machine learning also has intimate ties to optimization: many learning problems are formulated as minimization of some loss function on a training set of examples.': 3.6204819277108427,
#  'Loss functions express the discrepancy between the predictions of the model being trained and the actual problem instances (for example, in classification, one wants to assign a label to instances, and models are trained to correctly predict the pre-assigned labels of a set of examples).': 2.6445783132530116,
#  '[31]\nThe difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.': 4.939759036144579,
#  'Characterizing the generalization of various learning algorithms is an active topic of current research, especially for deep learning algorithms.': 3.0481927710843375,
#  'Machine learning and statistics are closely related fields in terms of methods, but distinct in their principal goal: statistics draws population inferences from a sample, while machine learning finds generalizable predictive patterns.': 4.144578313253013,
#  '[32] According to Michael I. Jordan, the ideas of machine learning, from methodological principles to theoretical tools, have had a long pre-history in statistics.': 2.174698795180723,
#  '[33] He also suggested the term data science as a placeholder to call the overall field.': 1.2650602409638554,
#  '[33]\nLeo Breiman distinguished two statistical modeling paradigms: data model and algorithmic model,[34] wherein "algorithmic model" means more or less the machine learning algorithms like Random forest.': 3.4216867469879517,
#  'Some statisticians have adopted methods from machine learning, leading to a combined field that they call statistical learning.': 2.969879518072289,
#  '[35]\n\nA core objective of a learner is to generalize from its experience.': 0.20481927710843373,
#  '[4][36] Generalization in this context is the ability of a learning machine to perform accurately on new, unseen examples/tasks after having experienced a learning data set.': 4.090361445783132,
#  'The training examples come from some generally unknown probability distribution (considered representative of the space of occurrences) and the learner has to build a general model about this space that enables it to produce sufficiently accurate predictions in new cases.': 1.9578313253012045,
#  'The computational analysis of machine learning algorithms and their performance is a branch of theoretical computer science known as computational learning theory.': 3.5481927710843366,
#  'Because training sets are finite and the future is uncertain, learning theory usually does not yield guarantees of the performance of algorithms.': 2.1445783132530125,
#  'Instead, probabilistic bounds on the performance are quite common.': 0.3493975903614458,
#  'The bias–variance decomposition is one way to quantify generalization error.': 0.3674698795180723,
#  'For the best performance in the context of generalization, the complexity of the hypothesis should match the complexity of the function underlying the data.': 2.3674698795180724,
#  'If the hypothesis is less complex than the function, then the model has under fitted the data.': 1.5662650602409638,
#  'If the complexity of the model is increased in response, then the training error decreases.': 1.3373493975903614,
#  'But if the hypothesis is too complex, then the model is subject to overfitting and generalization will be poorer.': 0.680722891566265,
#  '[37]\nIn addition to performance bounds, learning theorists study the time complexity and feasibility of learning.': 2.6325301204819276,
#  'In computational learning theory, a computation is considered feasible if it can be done in polynomial time.': 1.7891566265060241,
#  'There are two kinds of time complexity results.': 0.21084337349397586,
#  'Positive results show that a certain class of functions can be learned in polynomial time.': 0.5843373493975904,
#  'Negative results show that certain classes cannot be learned in polynomial time.': 0.46385542168674704,
#  'Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:\nSupervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.': 6.313253012048192,
#  '[38] The data is known as training data, and consists of a set of training examples.': 2.2469879518072284,
#  'Each training example has one or more inputs and the desired output, also known as a supervisory signal.': 1.1265060240963856,
#  'In the mathematical model, each training example is represented by an array or vector, sometimes called a feature vector, and the training data is represented by a matrix.': 2.58433734939759,
#  'Through iterative optimization of an objective function, supervised learning algorithms learn a function that can be used to predict the output associated with new inputs.': 2.271084337349397,
#  '[39] An optimal function will allow the algorithm to correctly determine the output for inputs that were not a part of the training data.': 1.891566265060241,
#  'An algorithm that improves the accuracy of its outputs or predictions over time is said to have learned to perform that task.': 0.7108433734939759,
#  '[13]\nTypes of supervised learning algorithms include active learning, classification and regression.': 2.602409638554217,
#  '[40] Classification algorithms are used when the outputs are restricted to a limited set of values, and regression algorithms are used when the outputs may have any numerical value within a range.': 1.957831325301205,
#  'As an example, for a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email.': 1.9638554216867474,
#  'Similarity learning is an area of supervised machine learning closely related to regression and classification, but the goal is to learn from examples using a similarity function that measures how similar or related two objects are.': 3.75301204819277,
#  'It has applications in ranking, recommendation systems, visual identity tracking, face verification, and speaker verification.': 0.4879518072289158,
#  'Unsupervised learning algorithms take a set of data that contains only inputs, and find structure in the data, like grouping or clustering of data points.': 3.759036144578313,
#  'The algorithms, therefore, learn from test data that has not been labeled, classified or categorized.': 1.1265060240963858,
#  'Instead of responding to feedback, unsupervised learning algorithms identify commonalities in the data and react based on the presence or absence of such commonalities in each new piece of data.': 3.4457831325301207,
#  'A central application of unsupervised learning is in the field of density estimation in statistics, such as finding the probability density function.': 2.295180722891566,
#  '[41] Though unsupervised learning encompasses other domains involving summarizing and explaining data features.': 1.7469879518072289,
#  'Cluster analysis is the assignment of a set of observations into subsets (called clusters) so that observations within the same cluster are similar according to one or more predesignated criteria, while observations drawn from different clusters are dissimilar.': 1.2228915662650606,
#  'Different clustering techniques make different assumptions on the structure of the data, often defined by some similarity metric and evaluated, for example, by internal compactness, or the similarity between members of the same cluster, and separation, the difference between clusters.': 2.1506024096385534,
#  'Other methods are based on estimated density and graph connectivity.': 0.24096385542168675,
#  'Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data).': 4.939759036144578,
#  'Some of the training examples are missing training labels,  yet many machine-learning researchers have found that unlabeled data, when used in conjunction with a small amount of labeled data, can produce a considerable improvement in learning accuracy.': 4.036144578313253,
#  'In weakly supervised learning, the training labels are noisy, limited, or imprecise; however, these labels are often cheaper to obtain, resulting in larger effective training sets.': 2.5843373493975905,
#  '[42]\nReinforcement learning is an area of machine learning concerned with how software agents ought to take actions in an environment so as to maximize some notion of cumulative reward.': 3.1385542168674694,
#  'Due to its generality, the field is studied in many other disciplines, such as game theory, control theory, operations research, information theory, simulation-based optimization, multi-agent systems, swarm intelligence, statistics and genetic algorithms.': 1.5301204819277108,
#  'In machine learning, the environment is typically represented as a Markov decision process (MDP).': 2.3373493975903608,
#  'Many reinforcement learning algorithms use dynamic programming techniques.': 1.5662650602409636,
#  '[43] Reinforcement learning algorithms do not assume knowledge of an exact mathematical model of the MDP, and are used when exact models are infeasible.': 2.168674698795181,
#  'Reinforcement learning algorithms are used in autonomous vehicles or in learning to play a game against a human opponent.': 3.126506024096386,
#  'The Dimensionality reduction is a process of reducing the number of random variables under the consideration by obtaining a set of principal variables.': 1.13855421686747,
#  '[44] In other words, it is a process of reducing the dimension of your feature set also called no of features.': 1.13855421686747,
#  'Most of the dimensionality reduction techniques can be considered as either feature elimination or extraction.': 0.43975903614457834,
#  'One of the popular method of dimensionality reduction is called as principal component analysis.': 0.6144578313253012,
#  'The PCA involves changing higher dimensional data (eg.': 0.7771084337349398,
#  '3D) to a smaller space (eg.': 0.1144578313253012,
#  '2D).': 0,
#  'This results in a smaller dimension of data, (2D instead of 3D) while keeping all original variables in the model without changing the data.': 2.403614457831325,
#  "[45]\nOther approaches have been developed which don't fit neatly into this three-fold categorisation, and sometimes more than one is used by the same machine learning system.": 2.3012048192771086,
#  'For example topic modeling,  meta learning.': 1.2048192771084336,
#  '[46]\nAs of 2020, deep learning has become the dominant approach for much ongoing work in the field of machine learning.': 3.463855421686747,
#  '[7]\nSelf-learning as a machine learning paradigm was introduced in 1982 along with a neural network capable of self-learning named crossbar adaptive array (CAA).': 2.1385542168674703,
#  '[47] It is a learning with no external rewards and no external teacher advice.': 1.180722891566265,
#  'The CAA self-learning algorithm computes, in a crossbar fashion, both decisions about actions and emotions (feelings) about consequence situations.': 0.7409638554216869,
#  'The system is driven by the interaction between cognition and emotion.': 0.4879518072289156,
#  '[48]\nThe self-learning algorithm updates a memory matrix W =||w(a,s)|| such that in each iteration executes the following machine learning routine: \nIt is a system with only one input, situation s, and only one output, action (or behavior) a.': 3.1325301204819276,
#  'There is neither a separate reinforcement input nor an advice input from the environment.': 0.6144578313253013,
#  'The backpropagated value (secondary reinforcement) is the emotion toward the consequence situation.': 0.6626506024096386,
#  'The CAA exists in two environments, one is the behavioral environment where it behaves, and the other is the genetic environment, wherefrom it initially and only once receives initial emotions about situations to be encountered in the behavioral environment.': 1.9879518072289157,
#  'After receiving the genome (species) vector from the genetic environment, the CAA learns a goal-seeking behavior, in an environment that contains both desirable and undesirable situations.': 1.1807228915662653,
#  '[49]\nSeveral learning algorithms aim at discovering better representations of the inputs provided during training.': 1.9036144578313254,
#  '[50] Classic examples include principal components analysis and cluster analysis.': 0.3433734939759036,
#  'Feature learning algorithms, also called representation learning algorithms, often attempt to preserve the information in their input but also transform it in a way that makes it useful, often as a pre-processing step before performing classification or predictions.': 4.433734939759037,
#  'This technique allows reconstruction of the inputs coming from the unknown data-generating distribution, while not being necessarily faithful to configurations that are implausible under that distribution.': 0.6265060240963853,
#  'This replaces manual feature engineering, and allows a machine to both learn the features and use them to perform a specific task.': 1.355421686746988,
#  'Feature learning can be either supervised or unsupervised.': 1.2771084337349397,
#  'In supervised feature learning, features are learned using labeled input data.': 2.2289156626506026,
#  'Examples include artificial neural networks, multilayer perceptrons, and supervised dictionary learning.': 1.5542168674698793,
#  'In unsupervised feature learning, features are learned with unlabeled input data.': 2.1144578313253013,
#  'Examples include dictionary learning, independent component analysis, autoencoders, matrix factorization[51] and various forms of clustering.': 1.3915662650602414,
#  '[52][53][54]\nManifold learning algorithms attempt to do so under the constraint that the learned representation is low-dimensional.': 1.7650602409638556,
#  'Sparse coding algorithms attempt to do so under the constraint that the learned representation is sparse, meaning that the mathematical model has many zeros.': 1.3734939759036147,
#  'Multilinear subspace learning algorithms aim to learn low-dimensional representations directly from tensor representations for multidimensional data, without reshaping them into higher-dimensional vectors.': 2.072289156626506,
#  '[55] Deep learning algorithms discover multiple levels of representation, or a hierarchy of features, with higher-level, more abstract features defined in terms of (or generating) lower-level features.': 1.9337349397590364,
#  'It has been argued that an intelligent machine is one that learns a representation that disentangles the underlying factors of variation that explain the observed data.': 1.855421686746988,
#  '[56]\nFeature learning is motivated by the fact that machine learning tasks such as classification often require input that is mathematically and computationally convenient to process.': 3.313253012048193,
#  'However, real-world data such as images, video, and sensory data has not yielded to attempts to algorithmically define specific features.': 1.2710843373493979,
#  'An alternative is to discover such features or representations through examination, without relying on explicit algorithms.': 0.5060240963855421,
#  'Sparse dictionary learning is a feature learning method where a training example is represented as a linear combination of basis functions, and is assumed to be a sparse matrix.': 3.114457831325301,
#  'The method is strongly NP-hard and difficult to solve approximately.': 0.2951807228915663,
#  '[57] A popular heuristic method for sparse dictionary learning is the K-SVD algorithm.': 1.6265060240963856,
#  'Sparse dictionary learning has been applied in several contexts.': 1.3674698795180724,
#  'In classification, the problem is to determine the class to which a previously unseen training example belongs.': 1.2891566265060241,
#  'For a dictionary where each class has already been built, a new training example is associated with the class that is best sparsely represented by the corresponding dictionary.': 1.385542168674699,
#  'Sparse dictionary learning has also been applied in image de-noising.': 1.4759036144578315,
#  'The key idea is that a clean image patch can be sparsely represented by an image dictionary, but the noise cannot.': 0.7168674698795181,
#  '[58]\nIn data mining, anomaly detection, also known as outlier detection, is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.': 2.3915662650602414,
#  '[59] Typically, the anomalous items represent an issue such as bank fraud, a structural defect, medical problems or errors in a text.': 0.8614457831325303,
#  'Anomalies are referred to as outliers, novelties, noise, deviations and exceptions.': 0.09036144578313253,
#  '[60]\nIn particular, in the context of abuse and network intrusion detection, the interesting objects are often not rare objects, but unexpected bursts of inactivity.': 1.1385542168674703,
#  'This pattern does not adhere to the common statistical definition of an outlier as a rare object, and many outlier detection methods (in particular, unsupervised algorithms) will fail on such data unless it has been aggregated appropriately.': 2.060240963855422,
#  'Instead, a cluster analysis algorithm may be able to detect the micro-clusters formed by these patterns.': 0.6506024096385542,
#  '[61]\nThree broad categories of anomaly detection techniques exist.': 0.2108433734939759,
#  '[62] Unsupervised anomaly detection techniques detect anomalies in an unlabeled test data set under the assumption that the majority of the instances in the data set are normal, by looking for instances that seem to fit least to the remainder of the data set.': 4.216867469879517,
#  'Supervised anomaly detection techniques require a data set that has been labeled as "normal" and "abnormal" and involves training a classifier (the key difference to many other statistical classification problems is the inherently unbalanced nature of outlier detection).': 2.367469879518072,
#  'Semi-supervised anomaly detection techniques construct a model representing normal behavior from a given normal training data set and then test the likelihood of a test instance to be generated by the model.': 2.36144578313253,
#  'In developmental robotics, robot learning algorithms generate their own sequences of learning experiences, also known as a curriculum, to cumulatively acquire new skills through self-guided exploration and social interaction with humans.': 2.933734939759036,
#  'These robots use guidance mechanisms such as active learning, maturation, motor synergies and imitation.': 1.1746987951807233,
#  'Association rule learning is a rule-based machine learning method for discovering relationships between variables in large databases.': 3.150602409638554,
#  'It is intended to identify strong rules discovered in databases using some measure of "interestingness".': 0.5240963855421686,
#  '[63]\nRule-based machine learning is a general term for any machine learning method that identifies, learns, or evolves "rules" to store, manipulate or apply knowledge.': 3.548192771084337,
#  'The defining characteristic of a rule-based machine learning algorithm is the identification and utilization of a set of relational rules that collectively represent the knowledge captured by the system.': 3.0421686746987957,
#  'This is in contrast to other machine learning algorithms that commonly identify a singular model that can be universally applied to any instance in order to make a prediction.': 2.9096385542168677,
#  '[64] Rule-based machine learning approaches include learning classifier systems, association rule learning, and artificial immune systems.': 4.054216867469879,
#  'Based on the concept of strong rules, Rakesh Agrawal, Tomasz Imieliński and Arun Swami introduced association rules for discovering regularities between products in large-scale transaction data recorded by point-of-sale (POS) systems in supermarkets.': 1.6445783132530125,
#  '[65] For example, the rule \n\n\n\n{\n\no\nn\ni\no\nn\ns\n,\np\no\nt\na\nt\no\ne\ns\n\n}\n⇒\n{\n\nb\nu\nr\ng\ne\nr\n\n}\n\n\n{\\displaystyle \\{\\mathrm {onions,potatoes} \\}\\Rightarrow \\{\\mathrm {burger} \\}}\n\n found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat.': 2.0120481927710845,
#  'Such information can be used as the basis for decisions about marketing activities such as promotional pricing or product placements.': 0.6325301204819275,
#  'In addition to market basket analysis, association rules are employed today in application areas including Web usage mining, intrusion detection, continuous production, and bioinformatics.': 0.8915662650602411,
#  'In contrast with sequence mining, association rule learning typically does not consider the order of items either within a transaction or across transactions.': 1.7891566265060241,
#  'Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.': 7.789156626506025,
#  'They seek to identify a set of context-dependent rules that collectively store and apply knowledge in a piecewise manner in order to make predictions.': 1.108433734939759,
#  '[66]\nInductive logic programming (ILP) is an approach to rule-learning using logic programming as a uniform representation for input examples, background knowledge, and hypotheses.': 0.8554216867469882,
#  'Given an encoding of the known background knowledge and a set of examples represented as a logical database of facts, an ILP system will derive a hypothesized logic program that entails all positive and no negative examples.': 1.3795180722891567,
#  'Inductive programming is a related field that considers any kind of programming language for representing hypotheses (and not only logic programming), such as functional programs.': 0.6445783132530121,
#  'Inductive logic programming is particularly useful in bioinformatics and natural language processing.': 0.42771084337349397,
#  'Gordon Plotkin and Ehud Shapiro laid the initial theoretical foundation for inductive machine learning in a logical setting.': 2.2409638554216866,
#  '[67][68][69] Shapiro built their first implementation (Model Inference System) in 1981: a Prolog program that inductively inferred logic programs from positive and negative examples.': 0.9096385542168675,
#  '[70] The term inductive here refers to philosophical induction, suggesting a theory to explain observed facts, rather than mathematical induction, proving a property for all members of a well-ordered set.': 0.9096385542168676,
#  'Performing machine learning involves creating a model, which is trained on some training data and then can process additional data to make predictions.': 3.506024096385542,
#  'Various types of models have been used and researched for machine learning systems.': 2.0481927710843375,
#  'Artificial neural networks (ANNs), or connectionist systems, are computing systems vaguely inspired by the biological neural networks that constitute animal brains.': 0.8493975903614458,
#  'Such systems "learn" to perform tasks by considering examples, generally without being programmed with any task-specific rules.': 0.5662650602409638,
#  'An ANN is a model based on a collection of connected units or nodes called "artificial neurons", which loosely model the neurons in a biological brain.': 1.5240963855421685,
#  'Each connection, like the synapses in a biological brain, can transmit information, a "signal", from one artificial neuron to another.': 1.0120481927710843,
#  'An artificial neuron that receives a signal can process it and then signal additional artificial neurons connected to it.': 0.783132530120482,
#  'In common ANN implementations, the signal at a connection between artificial neurons is a real number, and the output of each artificial neuron is computed by some non-linear function of the sum of its inputs.': 1.5963855421686752,
#  'The connections between artificial neurons are called "edges".': 0.4518072289156626,
#  'Artificial neurons and edges typically have a weight that adjusts as learning proceeds.': 1.349397590361446,
#  'The weight increases or decreases the strength of the signal at a connection.': 0.7289156626506025,
#  'Artificial neurons may have a threshold such that the signal is only sent if the aggregate signal crosses that threshold.': 0.8493975903614458,
#  'Typically, artificial neurons are aggregated into layers.': 0.26506024096385544,
#  'Different layers may perform different kinds of transformations on their inputs.': 0.32530120481927716,
#  'Signals travel from the first layer (the input layer) to the last layer (the output layer), possibly after traversing the layers multiple times.': 1.2409638554216866,
#  'The original goal of the ANN approach was to solve problems in the same way that a human brain would.': 1.1506024096385545,
#  'However, over time, attention moved to performing specific tasks, leading to deviations from biology.': 0.2710843373493976,
#  'Artificial neural networks have been used on a variety of tasks, including computer vision, speech recognition, machine translation, social network filtering, playing board and video games and medical diagnosis.': 1.5361445783132532,
#  'Deep learning consists of multiple hidden layers in an artificial neural network.': 1.6144578313253013,
#  'This approach tries to model the way the human brain processes light and sound into vision and hearing.': 0.8313253012048191,
#  'Some successful applications of deep learning are computer vision and speech recognition.': 1.2710843373493976,
#  "[71]\nDecision tree learning uses a decision tree as a predictive model to go from observations about an item (represented in the branches) to conclusions about the item's target value (represented in the leaves).": 2.879518072289157,
#  'It is one of the predictive modeling approaches used in statistics, data mining, and machine learning.': 3.036144578313253,
#  'Tree models where the target variable can take a discrete set of values are called classification trees; in these tree structures, leaves represent class labels and branches represent conjunctions of features that lead to those class labels.': 1.5060240963855425,
#  'Decision trees where the target variable can take continuous values (typically real numbers) are called regression trees.': 0.6024096385542168,
#  'In decision analysis, a decision tree can be used to visually and explicitly represent decisions and decision making.': 0.8855421686746988,
#  'In data mining, a decision tree describes data, but the resulting classification tree can be an input for decision making.': 2.1265060240963853,
#  'Support-vector machines (SVMs), also known as support-vector networks, are a set of related supervised learning methods used for classification and regression.': 2.253012048192771,
#  'Given a set of training examples, each marked as belonging to one of two categories, an SVM training algorithm builds a model that predicts whether a new example falls into one category or the other.': 2.198795180722891,
#  '[72]  An SVM training algorithm is a non-probabilistic, binary, linear classifier, although methods such as Platt scaling exist to use SVM in a probabilistic classification setting.': 1.3192771084337347,
#  'In addition to performing linear classification, SVMs can efficiently perform a non-linear classification using what is called the kernel trick, implicitly mapping their inputs into high-dimensional feature spaces.': 1.2048192771084338,
#  'Regression analysis encompasses a large variety of statistical methods to estimate the relationship between input variables and their associated features.': 0.8433734939759036,
#  'Its most common form is linear regression, where a single line is drawn to best fit the given data according to a mathematical criterion such as ordinary least squares.': 1.240963855421687,
#  'The latter is often extended by regularization (mathematics) methods to mitigate overfitting and bias, as in ridge regression.': 0.7891566265060241,
#  'When dealing with non-linear problems, go-to models include polynomial regression (for example, used for trendline fitting in Microsoft Excel[73]), logistic regression (often used in statistical classification) or even kernel regression, which introduces non-linearity by taking advantage of the kernel trick to implicitly map input variables to higher-dimensional space.': 2.1927710843373496,
#  'A Bayesian network, belief network, or directed acyclic graphical model is a probabilistic graphical model that represents a set of random variables and their conditional independence with a directed acyclic graph (DAG).': 1.216867469879518,
#  'For example, a Bayesian network could represent the probabilistic relationships between diseases and symptoms.': 0.6325301204819278,
#  'Given symptoms, the network can be used to compute the probabilities of the presence of various diseases.': 0.9216867469879518,
#  'Efficient algorithms exist that perform inference and learning.': 1.3734939759036144,
#  'Bayesian networks that model sequences of variables, like speech signals or protein sequences, are called dynamic Bayesian networks.': 0.6385542168674699,
#  'Generalizations of Bayesian networks that can represent and solve decision problems under uncertainty are called influence diagrams.': 0.3975903614457832,
#  'A genetic algorithm (GA) is a search algorithm and heuristic technique that mimics the process of natural selection, using methods such as mutation and crossover to generate new genotypes in the hope of finding good solutions to a given problem.': 1.6204819277108433,
#  'In machine learning, genetic algorithms were used in the 1980s and 1990s.': 2.6566265060240966,
#  '[74][75] Conversely, machine learning techniques have been used to improve the performance of genetic and evolutionary algorithms.': 2.3855421686746987,
#  '[76]\nUsually, machine learning models require a lot of data in order for them to perform well.': 2.6987951807228914,
#  'Usually, when training a machine learning model, one needs to collect a large, representative sample of data from a training set.': 3.457831325301204,
#  'Data from the training set can be as varied as a corpus of text, a collection of images, and data collected from individual users of a service.': 2.0602409638554215,
#  'Overfitting is something to watch out for when training a machine learning model.': 2.228915662650602,
#  'Trained models derived from biased data can result in skewed or undesired predictions.': 1.0120481927710843,
#  'Algorithmic bias is a potential result from data not fully prepared for training.': 1.0662650602409638,
#  "Federated learning is an adapted form of distributed artificial intelligence to training machine learning models that decentralizes the training process, allowing for users' privacy to be maintained by not needing to send their data to a centralized server.": 4.475903614457832,
#  'This also increases efficiency by decentralizing the training process to many devices.': 0.825301204819277,
#  "For example, Gboard uses federated machine learning to train search query prediction models on users' mobile phones without having to send individual searches back to Google.": 2.060240963855422,
#  '[77]\nThere are many applications for machine learning, including:\nIn 2006, the media-services provider Netflix held the first "Netflix Prize" competition to find a program to better predict user preferences and improve the accuracy of its existing Cinematch movie recommendation algorithm by at least 10%.': 3.120481927710843,
#  'A joint team made up of researchers from AT&T Labs-Research in collaboration with the teams Big Chaos and Pragmatic Theory built an ensemble model to win the Grand Prize in 2009 for $1\xa0million.': 1.391566265060241,
#  '[79] Shortly after the prize was awarded, Netflix realized that viewers\' ratings were not the best indicators of their viewing patterns ("everything is a recommendation") and they changed their recommendation engine accordingly.': 0.6626506024096386,
#  '[80] In 2010 The Wall Street Journal wrote about the firm Rebellion Research and their use of machine learning to predict the financial crisis.': 2.5361445783132535,
#  "[81] In 2012, co-founder of Sun Microsystems, Vinod Khosla, predicted that 80% of medical doctors' jobs would be lost in the next two decades to automated machine learning medical diagnostic software.": 2.4397590361445785,
#  '[82] In 2014, it was reported that a machine learning algorithm had been applied in the field of art history to study fine art paintings and that it may have revealed previously unrecognized influences among artists.': 2.8433734939759043,
#  '[83] In 2019 Springer Nature published the first research book created using machine learning.': 2.192771084337349,
#  '[84] In 2020, machine learning technology was used to help make diagnoses and aid researchers in developing a cure for COVID-19.': 2.427710843373494,
#  '[85] Machine learning is recently applied to predict the green behavior of human-being.': 1.855421686746988,
#  "[86] Recently, machine learning technology is also applied to optimise smartphone's performance and thermal behaviour based on the user's interaction with the phone.": 2.27710843373494,
#  '[87][88]\nAlthough machine learning has been transformative in some fields, machine-learning programs often fail to deliver expected results.': 2.0,
#  '[89][90][91] Reasons for this are numerous: lack of (suitable) data, lack of access to the data, data bias, privacy problems, badly chosen tasks and algorithms, wrong tools and people, lack of resources, and evaluation problems.': 2.590361445783133,
#  '[92]\nIn 2018, a self-driving car from Uber failed to detect a pedestrian, who was killed after a collision.': 0.4819277108433736,
#  '[93] Attempts to use machine learning in healthcare with the IBM Watson system failed to deliver even after years of time and billions of dollars invested.': 2.2469879518072298,
#  '[94][95]\nMachine learning has been used as a strategy to update the evidence related to systematic review and increased reviewer burden related to the growth of biomedical literature.': 2.3975903614457836,
#  'While it has improved with training sets, it has not yet developed sufficiently to reduce the workload burden without limiting the necessary sensitivity for the findings research themselves.': 1.2650602409638556,
#  '[96]\nMachine learning approaches in particular can suffer from different data biases.': 2.4819277108433733,
#  'A machine learning system trained specifically on current customers may not be able to predict the needs of new customer groups that are not represented in the training data.': 3.433734939759036,
#  'When trained on man-made data, machine learning is likely to pick up the constitutional and unconscious biases already present in society.': 2.656626506024097,
#  '[97] Language models learned from data have been shown to contain human-like biases.': 0.789156626506024,
#  '[98][99] Machine learning systems used for criminal risk assessment have been found to be biased against black people.': 2.0301204819277108,
#  '[100][101] In 2015, Google photos would often tag black people as gorillas,[102] and in 2018 this still was not well resolved, but Google reportedly was still using the workaround to remove all gorillas from the training data, and thus was not able to recognize real gorillas at all.': 2.228915662650602,
#  '[103] Similar issues with recognizing non-white people have been found in many other systems.': 0.5301204819277108,
#  '[104] In 2016, Microsoft tested a chatbot that learned from Twitter, and it quickly picked up racist and sexist language.': 0.5000000000000001,
#  '[105] Because of such challenges, the effective use of machine learning may take longer to be adopted in other domains.': 2.2469879518072284,
#  '[106] Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...It’s inspired by people, it’s created by people, and—most importantly—it impacts people.': 4.734939759036145,
#  'It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”[107]\nClassification of machine learning models can be validated by accuracy estimation techniques like the holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.': 5.969879518072286,
#  'In comparison, the K-fold-cross-validation method randomly partitions the data into K subsets and then K experiments are performed each respectively considering 1 subset for evaluation and the remaining K-1 subsets for training the model.': 2.3192771084337345,
#  'In addition to the holdout and cross-validation methods, bootstrap, which samples n instances with replacement from the dataset, can be used to assess model accuracy.': 1.2590361445783134,
#  '[108]\nIn addition to overall accuracy, investigators frequently report sensitivity and specificity meaning True Positive Rate (TPR) and True Negative Rate (TNR) respectively.': 0.536144578313253,
#  'Similarly, investigators sometimes report the false positive rate (FPR) as well as the false negative rate (FNR).': 0.6325301204819278,
#  'However, these rates are ratios that fail to reveal their numerators and denominators.': 0.1144578313253012,
#  "The total operating characteristic (TOC) is an effective method to express a model's diagnostic ability.": 0.674698795180723,
#  "TOC shows the numerators and denominators of the previously mentioned rates, thus TOC provides more information than the commonly used receiver operating characteristic (ROC) and ROC's associated area under the curve (AUC).": 1.2108433734939763,
#  '[109]\nMachine learning poses a host of ethical questions.': 1.6626506024096386,
#  'Systems which are trained on datasets collected with biases may exhibit these biases upon use (algorithmic bias), thus digitizing cultural prejudices.': 0.542168674698795,
#  "[110] For example, in 1988, the UK's Commission for Racial Equality found that St. George's Medical School had been using a computer program trained from data of previous admissions staff and this program had denied nearly 60 candidates who were found to be either women or had non-European sounding names.": 1.8614457831325306,
#  '[97] Using job hiring data from a firm with racist hiring policies may lead to a machine learning system duplicating the bias by scoring job applicants by similarity to previous successful applicants.': 2.8614457831325315,
#  '[111][112] Responsible collection of data and documentation of algorithmic rules used by a system thus is a critical part of machine learning.': 2.662650602409639,
#  'AI can be well-equipped to make decisions in technical fields, which rely heavily on data and historical information.': 1.0301204819277108,
#  'These decisions rely on objectivity and logical reasoning.': 0.10240963855421688,
#  '[113] Because human languages contain biases, machines trained on language corpora will necessarily also learn these biases.': 0.5180722891566265,
#  '[114][115]\nOther forms of ethical challenges, not related to personal biases, are seen in health care.': 0.4638554216867471,
#  "There are concerns among health care professionals that these systems might not be designed in the public's interest but as income-generating machines.": 0.7289156626506024,
#  '[116] This is especially true in the United States where there is a long-standing ethical dilemma of improving health care, but also increasing profits.': 0.8373493975903612,
#  "For example, the algorithms could be designed to provide patients with unnecessary tests or medication in which the algorithm's proprietary owners hold stakes.": 1.234939759036145,
#  'There is  potential for machine learning in health care to provide professionals an additional tool to diagnose, medicate, and plan recovery paths for patients, but this requires these biases to be mitigated.': 2.3072289156626513,
#  '[117]\nSince the 2010s, advances in both machine learning algorithms and computer hardware have led to more efficient methods for training deep neural networks (a particular narrow subdomain of machine learning) that contain many layers of non-linear hidden units.': 4.807228915662653,
#  '[118] By 2019, graphic processing units (GPUs), often with AI-specific enhancements, had displaced CPUs as the dominant method of training large-scale commercial cloud AI.': 0.8433734939759034,
#  '[119] OpenAI estimated the hardware compute used in the largest deep learning projects from AlexNet (2012) to AlphaZero (2017), and found a 300,000-fold increase in the amount of compute required, with a doubling-time trendline of 3.4 months.': 2.5120481927710845,
#  '[120][121]\nSoftware suites containing a variety of machine learning algorithms include the following:': 2.180722891566265}

# %% [markdown]
# ## Summarization with Sentences of Highest Scores

# %%
# sort sentence by scores
sorted_sentence_tokens = dict(sorted(sentence_with_scores.items(), key = lambda pair: pair[1], reverse = True))
print(sorted_sentence_tokens)
print(len(sorted_sentence_tokens))
# Out:
# {'[30]\nMachine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).': 7.843373493975906, 'Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.': 7.789156626506025, '[12]\nTom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E."[13] This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms.': 6.55421686746988, 'Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.': 6.337349397590362, 'Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:\nSupervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.': 6.313253012048192, 'It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”[107]\nClassification of machine learning models can be validated by accuracy estimation techniques like the holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.': 5.969879518072286, "[8][9] A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.": 5.120481927710843, '[31]\nThe difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.': 4.939759036144579, 'Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data).': 4.939759036144578, '[117]\nSince the 2010s, advances in both machine learning algorithms and computer hardware have led to more efficient methods for training deep neural networks (a particular narrow subdomain of machine learning) that contain many layers of non-linear hidden units.': 4.807228915662653, '[106] Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...It’s inspired by people, it’s created by people, and—most importantly—it impacts people.': 4.734939759036145, '[3]\nA subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers; but not all machine learning is statistical learning.': 4.644578313253012, 'Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usual ...
# 286

# %%
# top 10
from itertools import count, takewhile
sen_choice = 10
counter = count()
selected_sentences = list(takewhile(lambda x: next(counter) < sen_choice, (items[0] for items in sorted_sentence_tokens.items())))
for i, sentence in enumerate(selected_sentences):
    print('---> Sentence %d: %s' % (i, sentence))
# Out:
# ---> Sentence 0: [30]
# Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).
# ---> Sentence 1: Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.
# ---> Sentence 2: [12]
# Tom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E."[13] This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms.
# ---> Sentence 3: Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.
# ---> Sentence 4: Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:
# Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.
# ---> Sentence 5: It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”[107]
# Classification of machine learning models can be validated by accuracy estimation techniques like the holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.
# ---> Sentence 6: [8][9] A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.
# ---> Sentence 7: [31]
# The difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.
# ---> Sentence 8: Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data).
# ---> Sentence 9: [117]
# Since the 2010s, advances in both machine learning algorithms and computer hardware have led to more efficient methods for training deep neural networks (a particular narrow subdomain of machine learning) that contain many layers of non-linear hidden units.

# %% [markdown]
# # Using Spacy

# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_trf')

# %%
# process with spacy
doc = nlp(article_content)

# %%
for token in doc.sents:
    print(token)
# Out:
# Machine learning (ML) is the study of computer algorithms that improve automatically through experience and by the use of data.[1]
# It is seen as a part of artificial intelligence.
# Machine learning algorithms build a model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.[2]
# Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.[3]
#
# A subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers; but not all machine learning is statistical learning.
# The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning.
# Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning.[5][6]
# In its application across business problems, machine learning is also referred to as predictive analytics.
#
# Machine learning involves computers discovering how they can perform tasks without being explicitly programmed to do so.
# It involves computers learning from data provided so that they carry out certain tasks.
# For simple tasks assigned to computers, it is possible to program algorithms telling the machine how to execute all steps required to solve the problem at hand; on the computer's part, no learning is needed.
# For more advanced tasks, it can be challenging for a human to manually create the needed algorithms.
# In practice, it can turn out to be more effective to help the machine develop its own algorithm, rather than having human programmers specify every needed step.[7]
#
# The discipline of machine learning employs various approaches to teach computers to accomplish tasks where no fully satisfactory algorithm is available.
# In cases where vast numbers of potential answers exist, one approach is to label some of the correct answers as valid.
# This can then be used as training data for the computer to improve the algorithm(s) it uses to determine correct answers.
# For example, to train a system for the task of digital character recognition, the MNIST dataset of handwritten digits has often been used.[7]
#
# The term machine learning was coined in 1959 by Arthur Samuel, an American IBMer and pioneer in the field of computer gaming and artificial intelligence.[8][9]
# A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.[10]
# Interest related to pattern recognition continued into the 1970s, as described by Duda and Hart in 1973.[11]
# In 1981 a report was given on using teaching strategies so that a neural network learns to recognize 40 characters (26 letters, 10 digits, and 4 special symbols) from a computer terminal.[12]
#
# Tom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E."[13]
# This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms.
# This follows Alan Turing's proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?" is replaced with the question "Can machines do what we (as thinking entities) can do?".[14]
#
# Modern day machine learning has two objectives, one is to classify data based on models which have been developed, the other purpose is to make predictions for future outcomes based on these models.
# A hypothetical algorithm specific to classifying data may use computer vision of moles coupled with supervised learning in order to train it to classify the cancerous moles.
# Where as, a machine learning algorithm for stock trading may inform the trader of future potential predictions.[15]
#
# As a scientific endeavor, machine learning grew out of the quest for artificial intelligence.
# In the early days of AI as an academic discipline, some researchers were interested in having machines learn from data.
# They attempted to approach the problem with various symbolic methods, as well as what was then termed "neural networks"; these were mostly perceptrons and other models that were later found to be reinventions of the generalized linear models of statistics.[18]
# Probabilistic reasoning was also employed, especially in automated medical diagnosis.[19]:488
#
# However, an increasing emphasis on the logical, knowledge-based approach caused a rift between AI and machine learning.
# Probabilistic systems were plagued by theoretical and practical problems of data acquisition and representation.[19]:488
# By 1980, expert systems had come to dominate AI, and statistics was out of favor.[20]
# Work on symbolic/knowledge-based learning did continue within AI, leading to inductive logic programming, but the more statistical line of research was now outside the field of AI proper, in pattern recognition and information retrieval.[19]:708–710; 755
# Neural networks research had been abandoned by AI and computer science around the same time.
# This line, too, was continued outside the AI/CS field, as "connectionism", by researchers from other disciplines including Hopfield, Rumelhart and Hinton.
# Their main success came in the mid-1980s with the reinvention of backpropagation.[19]:25
#
# Machine learning (ML), reorganized as a separate field, started to flourish in the 1990s.
# The field changed its goal from achieving artificial intelligence to tackling solvable problems of a practical nature.
# It shifted focus away from the symbolic approaches it had inherited from AI, and toward methods and models borrowed from statistics and probability theory.[20]
#
# As of 2020, many sources continue to assert that machine learning remains a subfield of AI.[21][22][16]
# The main disagreement is whether all of ML is part of AI, as this would mean that anyone using ML could claim they are using AI.
# Others have the view that not all of ML is part of AI[23][24][25] where only an 'intelligent' subset of ML is part of AI.[26]
#
# The question to what is the difference between ML and AI is answered by Judea Pearl in The Book of Why.[27]
# Accordingly ML learns and predicts based on passive observations, whereas AI implies an agent  interacting with the environment to learn and take actions that maximize its chance of successfully achieving its goals.[30]
#
# Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).
# Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.
# Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge.
# Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.
#
# Machine learning also has intimate ties to optimization: many learning problems are formulated as minimization of some loss function on a training set of examples.
# Loss functions express the discrepancy between the predictions of the model being trained and the actual problem instances (for example, in classification, one wants to assign a label to instances, and models are trained to correctly predict the pre-assigned labels of a set of examples).[31]
#
# The difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.
# Characterizing the generalization of various learning algorithms is an active topic of current research, especially for deep learning algorithms.
#
# Machine learning and statistics are closely related fields in terms of methods, but distinct in their principal goal: statistics draws population inferences from a sample, while machine learning finds generalizable predictive patterns.[32]
# According to Michael I. Jordan, the ideas of machine learning, from methodological principles to theoretical tools, have had a long pre-history in statistics.[33]
# He also suggested the term data science as a placeholder to call the overall field.[33]
#
# Leo Breiman distinguished two statistical modeling paradigms: data model and algorithmic model,[34] wherein "algorithmic model" means more or less the machine learning algorithms like Random forest.
#
# Some statisticians have adopted methods from machine learning, leading to a combined field that they call statistical learning.[35]
#
# A core objective of a learner is to generalize from its experience.[4][36]
# Generalization in this context is the ability of a learning machine to perform accurately on new, unseen examples/tasks after having experienced a learning data set.
# The training examples come from some generally unknown probability distribution (considered representative of the space of occurrences) and the learner has to build a general model about this space that enables it to produce sufficiently accurate predictions in new cases.
#
# The computational analysis of machine learning algorithms and their performance is a branch of theoretical computer science known as computational learning theory.
# Because training sets are finite and the future is uncertain, learning theory usually does not yield guarantees of the performance of algorithms.
# Instead, probabilistic bounds on the performance are quite common.
# The bias–variance decomposition is one way to quantify generalization error.
#
# For the best performance in the context of generalization, the complexity of the hypothesis should match the complexity of the function underlying the data.
# If the hypothesis is less complex than the function, then the model has under fitted the data.
# If the complexity of the model is increased in response, then the training error decreases.
# But if the hypothesis is too complex, then the model is subject to overfitting and generalization will be
# poorer.[37]
#
# In addition to performance bounds, learning theorists study the time complexity and feasibility of learning.
# In computational learning theory, a computation is considered feasible if it can be done in polynomial time.
# There are two kinds of time complexity results.
# Positive results show that a certain class of functions can be learned in polynomial time.
# Negative results show that certain classes cannot be learned in polynomial time.
#
#
# Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:
# Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.[38]
# The data is known as training data, and consists of a set of training examples.
# Each training example has one or more inputs and the desired output, also known as a supervisory signal.
#  In the mathematical model, each training example is represented by an array or vector, sometimes called a feature vector, and the training data is represented by a matrix.
# Through iterative optimization of an objective function, supervised learning algorithms learn a function that can be used to predict the output associated with new inputs.[39]
# An optimal function will allow the algorithm to correctly determine the output for inputs that were not a part of the training data.
# An algorithm that improves the accuracy of its outputs or predictions over time is said to have learned to perform that task.[13]
#
# Types of supervised learning algorithms include active learning, classification and regression.[40]
# Classification algorithms are used when the outputs are restricted to a limited set of values, and regression algorithms are used when the outputs may have any numerical value within a range.
# As an example, for a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email.
#
# Similarity learning is an area of supervised machine learning closely related to regression and classification, but the goal is to learn from examples using a similarity function that measures how similar or related two objects are.
# It has applications in ranking, recommendation systems, visual identity tracking, face verification, and speaker verification.
#
# Unsupervised learning algorithms take a set of data that contains only inputs, and find structure in the data, like grouping or clustering of data points.
# The algorithms, therefore, learn from test data that has not been labeled, classified or categorized.
# Instead of responding to feedback, unsupervised learning algorithms identify commonalities in the data and react based on the presence or absence of such commonalities in each new piece of data.
# A central application of unsupervised learning is in the field of density estimation in statistics, such as finding the probability density function.[41]
# Though unsupervised learning encompasses other domains involving summarizing and explaining data features.
#
# Cluster analysis is the assignment of a set of observations into subsets (called clusters) so that observations within the same cluster are similar according to one or more predesignated criteria, while observations drawn from different clusters are dissimilar.
# Different clustering techniques make different assumptions on the structure of the data, often defined by some similarity metric and evaluated, for example, by internal compactness, or the similarity between members of the same cluster, and separation, the difference between clusters.
# Other methods are based on estimated density and graph connectivity.
#
# Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data).
# Some of the training examples are missing training labels,  yet many machine-learning researchers have found that unlabeled data, when used in conjunction with a small amount of labeled data, can produce a considerable improvement in learning accuracy.
#
# In weakly supervised learning, the training labels are noisy, limited, or imprecise; however, these labels are often cheaper to obtain, resulting in larger effective training sets.[42]
#
# Reinforcement learning is an area of machine learning concerned with how software agents ought to take actions in an environment so as to maximize some notion of cumulative reward.
# Due to its generality, the field is studied in many other disciplines, such as game theory, control theory, operations research, information theory, simulation-based optimization, multi-agent systems, swarm intelligence, statistics and genetic algorithms.
# In machine learning, the environment is typically represented as a Markov decision process (MDP).
# Many reinforcement learning algorithms use dynamic programming techniques.[43]
# Reinforcement learning algorithms do not assume knowledge of an exact mathematical model of the MDP, and are used when exact models are infeasible.
# Reinforcement learning algorithms are used in autonomous vehicles or in learning to play a game against a human opponent.
#
# The Dimensionality reduction is a process of reducing the number of random variables under the consideration by obtaining a set of principal variables.[44]
# In other words, it is a process of reducing the dimension of your feature set also called no of features.
# Most of the dimensionality reduction techniques can be considered as either feature elimination or extraction.
#
# One of the popular method of dimensionality reduction is called as principal component analysis.
#
# The PCA involves changing higher dimensional data (eg. 3D) to a smaller space (eg. 2D).
# This results in a smaller dimension of data, (2D instead of 3D) while keeping all original variables in the model without changing the data.[45]
#
# Other approaches have been developed which don't fit neatly into this three-fold categorisation, and sometimes more than one is used by the same machine learning system.
# For example topic modeling,  meta learning.[46]
#
# As of 2020, deep learning has become the dominant approach for much ongoing work in the field of machine learning.[7]
#
# Self-learning as a machine learning paradigm was introduced in 1982 along with a neural network capable of self-learning named crossbar adaptive array (CAA).[47]
# It is a learning with no external rewards and no external teacher advice.
# The CAA self-learning algorithm computes, in a crossbar fashion, both decisions about actions and emotions (feelings) about consequence situations.
# The system is driven by the interaction between cognition and emotion.[48]
#
#
# The self-learning algorithm updates a memory matrix W =||w(a,s)|| such that in each iteration executes the following machine learning routine:
# It is a system with only one input, situation s, and only one output, action (or behavior) a.
# There is neither a separate reinforcement input nor an advice input from the environment.
# The backpropagated value (secondary reinforcement) is the emotion toward the consequence situation.
# The CAA exists in two environments, one is the behavioral environment where it behaves, and the other is the genetic environment, wherefrom it initially and only once receives initial emotions about situations to be encountered in the behavioral environment.
# After receiving the genome (species) vector from the genetic environment, the CAA learns a goal-seeking behavior, in an environment that contains both desirable and undesirable situations.[49]
#
#
# Several learning algorithms aim at discovering better representations of the inputs provided during training.[50]
# Classic examples include principal components analysis and cluster analysis.
# Feature learning algorithms, also called representation learning algorithms, often attempt to preserve the information in their input but also transform it in a way that makes it useful, often as a pre-processing step before performing classification or predictions.
# This technique allows reconstruction of the inputs coming from the unknown data-generating distribution, while not being necessarily faithful to configurations that are implausible under that distribution.
# This replaces manual feature engineering, and allows a machine to both learn the features and use them to perform a specific task.
#
#
# Feature learning can be either supervised or unsupervised.
# In supervised feature learning, features are learned using labeled input data.
# Examples include artificial neural networks, multilayer perceptrons, and supervised dictionary learning.
# In unsupervised feature learning, features are learned with unlabeled input data.
#  Examples include dictionary learning, independent component analysis, autoencoders, matrix factorization[51] and various forms of clustering.[52][53][54]
#
#
# Manifold learning algorithms attempt to do so under the constraint that the learned representation is low-dimensional.
# Sparse coding algorithms attempt to do so under the constraint that the learned representation is sparse, meaning that the mathematical model has many zeros.
# Multilinear subspace learning algorithms aim to learn low-dimensional representations directly from tensor representations for multidimensional data, without reshaping them into higher-dimensional vectors.[55]
# Deep learning algorithms discover multiple levels of representation, or a hierarchy of features, with higher-level, more abstract features defined in terms of (or generating) lower-level features.
# It has been argued that an intelligent machine is one that learns a representation that disentangles the underlying factors of variation that explain the observed data.[56]
#
# Feature learning is motivated by the fact that machine learning tasks such as classification often require input that is mathematically and computationally convenient to process.
# However, real-world data such as images, video, and sensory data has not yielded to attempts to algorithmically define specific features.
# An alternative is to discover such features or representations through examination, without relying on explicit algorithms.
#
# Sparse dictionary learning is a feature learning method where a training example is represented as a linear combination of basis functions, and is assumed to be a sparse matrix.
# The method is strongly NP-hard and difficult to solve approximately.[57]
# A popular heuristic method for sparse dictionary learning is the K-SVD algorithm.
# Sparse dictionary learning has been applied in several contexts.
# In classification, the problem is to determine the class to which a previously unseen training example belongs.
# For a dictionary where each class has already been built, a new training example is associated with the class that is best sparsely represented by the corresponding dictionary.
# Sparse dictionary learning has also been applied in image de-noising.
# The key idea is that a clean image patch can be sparsely represented by an image dictionary, but the noise cannot.[58]
#
# In data mining, anomaly detection, also known as outlier detection, is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.[59]
# Typically, the anomalous items represent an issue such as bank fraud, a structural defect, medical problems or errors in a text.
# Anomalies are referred to as outliers, novelties, noise, deviations and exceptions.[60]
#
# In particular, in the context of abuse and network intrusion detection, the interesting objects are often not rare objects, but unexpected bursts of inactivity.
# This pattern does not adhere to the common statistical definition of an outlier as a rare object, and many outlier detection methods (in particular, unsupervised algorithms) will fail on such data unless it has been aggregated appropriately.
# Instead, a cluster analysis algorithm may be able to detect the micro-clusters formed by these patterns.[61]
#
#
# Three broad categories of anomaly detection techniques exist.[62]
# Unsupervised anomaly detection techniques detect anomalies in an unlabeled test data set under the assumption that the majority of the instances in the data set are normal, by looking for instances that seem to fit least to the remainder of the data set.
# Supervised anomaly detection techniques require a data set that has been labeled as "normal" and "abnormal" and involves training a classifier (the key difference to many other statistical classification problems is the inherently unbalanced nature of outlier detection).
# Semi-supervised anomaly detection techniques construct a model representing normal behavior from a given normal training data set and then test the likelihood of a test instance to be generated by the model.
#
# In developmental robotics, robot learning algorithms generate their own sequences of learning experiences, also known as a curriculum, to cumulatively acquire new skills through self-guided exploration and social interaction with humans.
# These robots use guidance mechanisms such as active learning, maturation, motor synergies and imitation.
#
# Association rule learning is a rule-based machine learning method for discovering relationships between variables in large databases.
# It is intended to identify strong rules discovered in databases using some measure of "interestingness".[63]
#
# Rule-based machine learning is a general term for any machine learning method that identifies, learns, or evolves "rules" to store, manipulate or apply knowledge.
# The defining characteristic of a rule-based machine learning algorithm is the identification and utilization of a set of relational rules that collectively represent the knowledge captured by the system.
# This is in contrast to other machine learning algorithms that commonly identify a singular model that can be universally applied to any instance in order to make a prediction.[64]
# Rule-based machine learning approaches include learning classifier systems, association rule learning, and artificial immune systems.
#
# Based on the concept of strong rules, Rakesh Agrawal, Tomasz Imieliński and Arun Swami introduced association rules for discovering regularities between products in large-scale transaction data recorded by point-of-sale (POS) systems in supermarkets.[65]
# For example, the rule
#
#
#
# {
#
# o
# n
# i
# o
# n
# s
# ,
# p
# o
# t
# a
# t
# o
# e
# s
#
# }
# ⇒
# {
#
# b
# u
# r
# g
# e
# r
#
# }
#
#
# {\displaystyle \{\mathrm {onions,potatoes} \}\Rightarrow \{\mathrm {burger} \}}
#
#  found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat.
# Such information can be used as the basis for decisions about marketing activities such as promotional pricing or product placements.
# In addition to market basket analysis, association rules are employed today in application areas including Web usage mining, intrusion detection, continuous production, and bioinformatics.
# In contrast with sequence mining, association rule learning typically does not consider the order of items either within a transaction or across transactions.
#
# Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.
# They seek to identify a set of context-dependent rules that collectively store and apply knowledge in a piecewise manner in order to make predictions.[66]
#
# Inductive logic programming (ILP) is an approach to rule-learning using logic programming as a uniform representation for input examples, background knowledge, and hypotheses.
# Given an encoding of the known background knowledge and a set of examples represented as a logical database of facts, an ILP system will derive a hypothesized logic program that entails all positive and no negative examples.
# Inductive programming is a related field that considers any kind of programming language for representing hypotheses (and not only logic programming), such as functional programs.
#
# Inductive logic programming is particularly useful in bioinformatics and natural language processing.
# Gordon Plotkin and Ehud Shapiro laid the initial theoretical foundation for inductive machine learning in a logical setting.[67][68][69]
# Shapiro built their first implementation (Model Inference System) in 1981: a Prolog program that inductively inferred logic programs from positive and negative examples.[70]
# The term inductive here refers to philosophical induction, suggesting a theory to explain observed facts, rather than mathematical induction, proving a property for all members of a well-ordered set.
#
# Performing machine learning involves creating a model, which is trained on some training data and then can process additional data to make predictions.
# Various types of models have been used and researched for machine learning systems.
#
# Artificial neural networks (ANNs), or connectionist systems, are computing systems vaguely inspired by the biological neural networks that constitute animal brains.
# Such systems "learn" to perform tasks by considering examples, generally without being programmed with any task-specific rules.
#
# An ANN is a model based on a collection of connected units or nodes called "artificial neurons", which loosely model the neurons in a biological brain.
# Each connection, like the synapses in a biological brain, can transmit information, a "signal", from one artificial neuron to another.
# An artificial neuron that receives a signal can process it and then signal additional artificial neurons connected to it.
# In common ANN implementations, the signal at a connection between artificial neurons is a real number, and the output of each artificial neuron is computed by some non-linear function of the sum of its inputs.
# The connections between artificial neurons are called "edges".
# Artificial neurons and edges typically have a weight that adjusts as learning proceeds.
# The weight increases or decreases the strength of the signal at a connection.
# Artificial neurons may have a threshold such that the signal is only sent if the aggregate signal crosses that threshold.
# Typically, artificial neurons are aggregated into layers.
# Different layers may perform different kinds of transformations on their inputs.
# Signals travel from the first layer (the input layer) to the last layer (the output layer), possibly after traversing the layers multiple times.
#
# The original goal of the ANN approach was to solve problems in the same way that a human brain would.
# However, over time, attention moved to performing specific tasks, leading to deviations from biology.
# Artificial neural networks have been used on a variety of tasks, including computer vision, speech recognition, machine translation, social network filtering, playing board and video games and medical diagnosis.
#
# Deep learning consists of multiple hidden layers in an artificial neural network.
# This approach tries to model the way the human brain processes light and sound into vision and hearing.
# Some successful applications of deep learning are computer vision and speech recognition.[71]
#
# Decision tree learning uses a decision tree as a predictive model to go from observations about an item (represented in the branches) to conclusions about the item's target value (represented in the leaves).
# It is one of the predictive modeling approaches used in statistics, data mining, and machine learning.
# Tree models where the target variable can take a discrete set of values are called classification trees; in these tree structures, leaves represent class labels and branches represent conjunctions of features that lead to those class labels.
# Decision trees where the target variable can take continuous values (typically real numbers) are called regression trees.
# In decision analysis, a decision tree can be used to visually and explicitly represent decisions and decision making.
# In data mining, a decision tree describes data, but the resulting classification tree can be an input for decision making.
#
# Support-vector machines (SVMs), also known as support-vector networks, are a set of related supervised learning methods used for classification and regression.
# Given a set of training examples, each marked as belonging to one of two categories, an SVM training algorithm builds a model that predicts whether a new example falls into one category or the other.[72
# ]
#  An SVM training algorithm is a non-probabilistic, binary, linear classifier, although methods such as Platt scaling exist to use SVM in a probabilistic classification setting.
# In addition to performing linear classification, SVMs can efficiently perform a non-linear classification using what is called the kernel trick, implicitly mapping their inputs into high-dimensional feature spaces.
#
# Regression analysis encompasses a large variety of statistical methods to estimate the relationship between input variables and their associated features.
# Its most common form is linear regression, where a single line is drawn to best fit the given data according to a mathematical criterion such as ordinary least squares.
# The latter is often extended by regularization (mathematics) methods to mitigate overfitting and bias, as in ridge regression.
# When dealing with non-linear problems, go-to models include polynomial regression (for example, used for trendline fitting in Microsoft Excel[73]), logistic regression (often used in statistical classification) or even kernel regression, which introduces non-linearity by taking advantage of the kernel trick to implicitly map input variables to higher-dimensional space.
#
# A Bayesian network, belief network, or directed acyclic graphical model is a probabilistic graphical model that represents a set of random variables and their conditional independence with a directed acyclic graph (DAG).
# For example, a Bayesian network could represent the probabilistic relationships between diseases and symptoms.
# Given symptoms, the network can be used to compute the probabilities of the presence of various diseases.
# Efficient algorithms exist that perform inference and learning.
# Bayesian networks that model sequences of variables, like speech signals or protein sequences, are called dynamic Bayesian networks.
# Generalizations of Bayesian networks that can represent and solve decision problems under uncertainty are called influence diagrams.
#
# A genetic algorithm (GA) is a search algorithm and heuristic technique that mimics the process of natural selection, using methods such as mutation and crossover to generate new genotypes in the hope of finding good solutions to a given problem.
# In machine learning, genetic algorithms were used in the 1980s and 1990s.[74][75]
# Conversely, machine learning techniques have been used to improve the performance of genetic and evolutionary algorithms.[76]
#
# Usually, machine learning models require a lot of data in order for them to perform well.
# Usually, when training a machine learning model, one needs to collect a large, representative sample of data from a training set.
# Data from the training set can be as varied as a corpus of text, a collection of images, and data collected from individual users of a service.
# Overfitting is something to watch out for when training a machine learning model.
# Trained models derived from biased data can result in skewed or undesired predictions.
# Algorithmic bias is a potential result from data not fully prepared for training.
#
# Federated learning is an adapted form of distributed artificial intelligence to training machine learning models that decentralizes the training process, allowing for users' privacy to be maintained by not needing to send their data to a centralized server.
# This also increases efficiency by decentralizing the training process to many devices.
# For example, Gboard uses federated machine learning to train search query prediction models on users' mobile phones without having to send individual searches back to Google.[77]
#
# There are many applications for machine learning, including:
# In 2006, the media-services provider Netflix held the first "Netflix Prize" competition to find a program to better predict user preferences and improve the accuracy of its existing Cinematch movie recommendation algorithm by at least 10%.
#  A joint team made up of researchers from AT&T Labs-Research in collaboration with the teams Big Chaos and Pragmatic Theory built an ensemble model to win the Grand Prize in 2009 for $1 million.[79]
# Shortly after the prize was awarded, Netflix realized that viewers' ratings were not the best indicators of their viewing patterns ("everything is a recommendation") and they changed their recommendation engine accordingly.[80]
# In 2010 The Wall Street Journal wrote about the firm Rebellion Research and their use of machine learning to predict the financial crisis.[81]
# In 2012, co-founder of Sun Microsystems, Vinod Khosla, predicted that 80% of medical doctors' jobs would be lost in the next two decades to automated machine learning medical diagnostic software.[82]
# In 2014, it was reported that a machine learning algorithm had been applied in the field of art history to study fine art paintings and that it may have revealed previously unrecognized influences among artists.[83]
# In 2019 Springer Nature published the first research book created using machine learning.[84]
# In 2020, machine learning technology was used to help make diagnoses and aid researchers in developing a cure for COVID-19.[85]
# Machine learning is recently applied to predict the green behavior of human-being.[86]
# Recently, machine learning technology is also applied to optimise smartphone's performance and thermal behaviour based on the user's interaction with the phone.[87][88]
#
# Although machine learning has been transformative in some fields, machine-learning programs often fail to deliver expected results.[89][90][91]
# Reasons for this are numerous: lack of (suitable) data, lack of access to the data, data bias, privacy problems, badly chosen tasks and algorithms, wrong tools and people, lack of resources, and evaluation problems.[92]
#
# In 2018, a self-driving car from Uber failed to detect a pedestrian, who was killed after a collision.[93]
# Attempts to use machine learning in healthcare with the IBM Watson system failed to deliver even after years of time and billions of dollars invested.[94][95]
#
# Machine learning has been used as a strategy to update the evidence related to systematic review and increased reviewer burden related to the growth of biomedical literature.
# While it has improved with training sets, it has not yet developed sufficiently to reduce the workload burden without limiting the necessary sensitivity for the findings research themselves.[96]
#
# Machine learning approaches in particular can suffer from different data biases.
# A machine learning system trained specifically on current customers may not be able to predict the needs of new customer groups that are not represented in the training data.
# When trained on man-made data, machine learning is likely to pick up the constitutional and unconscious biases already present in society.[97]
# Language models learned from data have been shown to contain human-like biases.[98][99]
# Machine learning systems used for criminal risk assessment have been found to be biased against black people.[100][101]
# In 2015, Google photos would often tag black people as gorillas,[102] and in 2018 this still was not well resolved, but Google reportedly was still using the workaround to remove all gorillas from the training data, and thus was not able to recognize real gorillas
# at all.[103
# ]
# Similar issues with recognizing non-white people have been found in many other systems.[104]
# In 2016, Microsoft tested a chatbot that learned from Twitter, and it quickly picked up racist and sexist language.[105]
# Because of such challenges, the effective use of machine learning may take longer to be adopted in other domains.[106]
# Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...
# It’s inspired by people, it’s created by people, and—most importantly—it impacts people.
# It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”[107]
# Classification of machine learning models can be validated by accuracy estimation techniques like the holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.
# In comparison, the K-fold-cross-validation method randomly partitions the data into K subsets and then K experiments are performed each respectively considering 1 subset for evaluation and the remaining K-1 subsets for training the model.
# In addition to the holdout and cross-validation methods, bootstrap, which samples n instances with replacement from the dataset, can be used to assess model accuracy.[108]
#
# In addition to overall accuracy, investigators frequently report sensitivity and specificity meaning True Positive Rate (TPR) and True Negative Rate (TNR) respectively.
# Similarly, investigators sometimes report the false positive rate (FPR) as well as the false negative rate (FNR).
# However, these rates are ratios that fail to reveal their numerators and denominators.
# The total operating characteristic (TOC) is an effective method to express a model's diagnostic ability.
# TOC shows the numerators and denominators of the previously mentioned rates, thus TOC provides more information than the commonly used receiver operating characteristic (ROC) and ROC's associated area under the curve (AUC).[109]
#
# Machine learning poses a host of ethical questions.
# Systems which are trained on datasets collected with biases may exhibit these biases upon use (algorithmic bias), thus digitizing cultural prejudices.[110]
# For example, in 1988, the UK's Commission for Racial Equality found that St. George's Medical School had been using a computer program trained from data of previous admissions staff and this program had denied nearly 60 candidates who were found to be either women or had non-European sounding names.[97]
# Using job hiring data from a firm with racist hiring policies may lead to a machine learning system duplicating the bias by scoring job applicants by similarity to previous successful applicants.[111][112]
# Responsible collection of data and documentation of algorithmic rules used by a system thus is a critical part of machine learning.
#
# AI can be well-equipped to make decisions in technical fields, which rely heavily on data and historical information.
# These decisions rely on objectivity and logical reasoning.[113]
# Because human languages contain biases, machines trained on language corpora will necessarily also learn these biases.[114][115]
#
# Other forms of ethical challenges, not related to personal biases, are seen in health care.
# There are concerns among health care professionals that these systems might not be designed in the public's interest but as income-generating machines.[116]
# This is especially true in the United States where there is a long-standing ethical dilemma of improving health care, but also increasing profits.
# For example, the algorithms could be designed to provide patients with unnecessary tests or medication in which the algorithm's proprietary owners hold stakes.
# There is  potential for machine learning in health care to provide professionals an additional tool to diagnose, medicate, and plan recovery paths for patients, but this requires these biases to be mitigated.[117]
#
# Since the 2010s, advances in both machine learning algorithms and computer hardware have led to more efficient methods for training deep neural networks (a particular narrow subdomain of machine learning) that contain many layers of non-linear hidden units.[118]
# By 2019, graphic processing units (GPUs), often with AI-specific enhancements, had displaced CPUs as the dominant method of training large-scale commercial cloud AI.[119]
# OpenAI estimated the hardware compute used in the largest deep learning projects from AlexNet (2012) to AlphaZero (2017), and found a 300,000-fold increase in the amount of compute required, with a doubling-time trendline of 3.4 months.[120][121]
#
# Software suites containing a variety of machine learning algorithms include the following:

# %% [markdown]
# ## Clean and lemmatize words using spacy

# %%
# clean words and lemmatize
token_lemma_cleaned = [token.lemma_ for token in doc if not token.is_stop]
token_lemma_cleaned = [token.lower() for token in token_lemma_cleaned if token.isalpha()]
print(token_lemma_cleaned)
# Out:
# ['machine', 'learning', 'ml', 'study', 'computer', 'algorithm', 'improve', 'automatically', 'experience', 'use', 'see', 'artificial', 'intelligence', 'machine', 'learning', 'algorithm', 'build', 'model', 'base', 'sample', 'datum', 'know', 'training', 'datum', 'order', 'prediction', 'decision', 'explicitly', 'program', 'machine', 'learning', 'algorithm', 'wide', 'variety', 'application', 'medicine', 'email', 'filtering', 'speech', 'recognition', 'computer', 'vision', 'difficult', 'unfeasible', 'develop', 'conventional', 'algorithm', 'perform', 'need', 'subset', 'machine', 'learning', 'closely', 'relate', 'computational', 'statistic', 'focus', 'make', 'prediction', 'computer', 'machine', 'learning', 'statistical', 'learning', 'study', 'mathematical', 'optimization', 'deliver', 'method', 'theory', 'application', 'domain', 'field', 'machine', 'learning', 'datum', 'mining', 'related', 'field', 'study', 'focus', 'exploratory', 'datum', 'analysis', 'unsupervised', 'application', 'business', 'problem', 'machine', 'learning', 'refer', 'predictive', 'analytic', 'machine', 'learning', 'involve', 'computer', 'discover', 'perform', 'task', 'explicitly', 'program', 'involve', 'computer', 'learn', 'datum', 'provide', 'carry', 'certain', 'task', 'simple', 'task', 'assign', 'computer', 'possible', 'program', 'algorithm', 'tell', 'machine', 'execute', 'step', 'require', 'solve', 'problem', 'hand', 'computer', 'learning', 'need', 'advanced', 'task', 'challenging', 'human', 'manually', 'create', 'need', 'algorithm', 'practice', 'turn', 'effective', 'help', 'machine', 'develop', 'algorithm', 'have', 'human', 'programmer', 'specify', 'need', 'discipline', 'machine', 'learning', 'employ', 'approach', 'teach', 'computer', 'accomplish', 'task', 'fully', 'satisfactory', 'algorithm', 'available', 'case', 'vast', 'number', 'potential', 'answer', 'exist', 'approach', 'label', 'correct', 'answer', 'valid', 'training', 'datum', 'computer', 'improve', 'use', 'determine', 'correct', 'answer', 'example', 'train', 'system', 'task', 'digital', 'character', 'recognition', 'mnist', 'dataset', 'handwritten', 'digit', 'term', 'machine', 'learning', 'coin', 'arthur', 'samuel', 'american', 'ibmer', 'pioneer', 'field', 'computer', 'gaming', 'artificial', 'representative', 'book', 'machine', 'learning', 'research', 'nilsson', 'book', 'learning', 'machine', 'deal', 'machine', 'learning', 'pattern', 'interest', 'relate', 'pattern', 'recognition', 'continue', 'describe', 'duda', 'hart', 'report', 'give', 'teaching', 'strategy', 'neural', 'network', 'learn', 'recognize', 'character', 'letter', 'digit', 'special', 'symbol', 'computer', 'tom', 'mitchell', 'provide', 'widely', 'quote', 'formal', 'definition', 'algorithm', 'study', 'machine', 'learning', 'field', 'computer', 'program', 'say', 'learn', 'experience', 'e', 'respect', 'class', 'task', 't', 'performance', 'measure', 'p', 'performance', 'task', 't', 'measure', 'p', 'improve', 'experience', 'definition', 'task', 'machine', 'learning', 'concern', 'offer', 'fundamentally', 'operational', 'definition', 'define', 'field', 'cognitive', 'term', 'follow', 'alan', 'turing', 'proposal', 'paper', 'computing', 'machinery', 'intelligence', 'question', 'machine', 'think', 'replace', 'question', 'machine', 'think', 'entity', 'modern', 'day', 'machine', 'learning', 'objective', 'classify', 'datum', 'base', 'model', 'develop', 'purpose', 'prediction', 'future', 'outcome', 'base', 'model', 'hypothetical', 'algorithm', 'specific', 'classify', 'datum', 'use', 'computer', 'vision', 'mole', 'couple', 'supervise', 'learning', 'order', 'train', 'classify', 'cancerous', 'mole', 'machine', 'learning', 'algorithm', 'stock', 'trading', 'inform', 'trader', 'future', 'potential', 'scientific', 'endeavor', 'machine', 'learning', 'grow', 'quest', 'artificial', 'intelligence', 'early', 'day', 'ai', 'academic', 'discipline', 'researcher', 'interested', 'have', 'machine', 'learn', 'datum', 'attempt', 'approach', 'problem', 'symbolic', 'method', 'term' ...

# %% [markdown]
# ## weighted freq and sentence scoring

# %%
# get words freq
freq_spacy = {}
for word in token_lemma_cleaned:
    freq_spacy[word] =  freq_spacy.get(word, 0) + 1
# sort from high to low
sorted_freq_spacy = dict(sorted(freq_spacy.items(), key = lambda item: item[1], reverse = True))
print(sorted_freq_spacy)
# Out:
# {'learning': 161, 'machine': 101, 'datum': 67, 'algorithm': 63, 'model': 49, 'training': 41, 'learn': 32, 'set': 32, 'example': 31, 'method': 30, 'system': 27, 'feature': 23, 'artificial': 22, 'input': 22, 'network': 20, 'represent': 20, 'computer': 19, 'task': 19, 'rule': 19, 'base': 18, 'field': 18, 'train': 18, 'data': 17, 'classification': 17, 'decision': 16, 'perform': 16, 'use': 15, 'problem': 15, 'ai': 15, 'approach': 14, 'label': 14, 'bias': 14, 'program': 13, 'unsupervised': 13, 'find': 13, 'knowledge': 13, 'analysis': 12, 'include': 12, 'call': 12, 'prediction': 11, 'mining': 11, 'research': 11, 'performance': 11, 'time': 11, 'function': 11, 'signal': 11, 'process': 11, 'neuron': 11, 'human': 10, 'neural': 10, 'environment': 10, 'supervised': 10, 'output': 10, 'regression': 10, 'technique': 10, 'representation': 10, 'detection': 10, 'tree': 10, 'improve': 9, 'theory': 9, 'linear': 9, 'predict': 9, 'new': 9, 'test': 9, 'cluster': 9, 'variable': 9, 'dictionary': 9, 'layer': 9, 'ml': 8, 'know': 8, 'application': 8, 'statistical': 8, 'term': 8, 'class': 8, 'programming': 8, 'result': 8, 'apply': 8, 'non': 8, 'study': 7, 'intelligence': 7, 'build': 7, 'order': 7, 'need': 7, 'mathematical': 7, 'discover': 7, 'give': 7, 'supervise': 7, 'probabilistic': 7, 'increase': 7, 'logic': 7, 'information': 7, 'goal': 7, 'different': 7, 'instance': 7, 'generalization': 7, 'deep': 7, 'consider': 7, 'contain': 7, 'large': 7, 'reinforcement': 7, 'genetic': 7, 'typically': 7, 'sparse': 7, 'anomaly': 7, 'develop': 6, 'subset': 6, 'relate': 6, 'statistic': 6, 'optimization': 6, 'involve': 6, 'provide': 6, 'require': 6, 'specific': 6, 'attempt': 6, 'medical': 6, 'lead': 6, 'inductive': 6, 'observation': 6, 'accuracy': 6, 'like': 6, 'value': 6, 'dimensional': 6, 'self': 6, 'compute': 6, 'generate': 6, 'people': 6, 'rate': 6, 'experience': 5, 'sample': 5, 'recognition': 5, 'vision': 5, 'focus': 5, 'related': 5, 'employ': 5, 'exist': 5, 'pattern': 5, 'concern': 5, 'define': 5, 'researcher': 5, 'come': 5, 'discovery': 5, 'previously': 5, 'algorithmic': 5, 'context': 5, 'space': 5, 'complexity': 5, 'hypothesis': 5, 'addition': 5, 'positive': 5, 'negative': 5, 'vector': 5, 'similarity': 5, 'identify': 5, 'component': 5, 'form': 5, 'image': 5, 'outlier': 5, 'item': 5, 'fail': 5, 'association': 5, 'language': 5, 'brain': 5, 'bayesian': 5, 'user': 5, 'variety': 4, 'email': 4, 'speech': 4, 'computational': 4, 'predictive': 4, 'step': 4, 'solve': 4, 'create': 4, 'effective': 4, 'discipline': 4, 'number': 4, 'potential': 4, 'answer': 4, 'book': 4, 'continue': 4, 'report': 4, 'definition': 4, 't': 4, 'measure': 4, 'question': 4, 'classify': 4, 'logical': 4, 'theoretical': 4, 'separate': 4, 'change': 4, 'nature': 4, 'probability': 4, 'mean': 4, 'difference': 4, 'action': 4, 'unknown': 4, 'database': 4, 'usually': 4, 'evaluate': 4, 'loss': 4, 'principal': 4, 'tool': 4, 'instead': 4, 'common': 4, 'way': 4, 'good': 4, 'fit': 4, 'polynomial': 4, 'category': 4, 'matrix': 4, 'allow': 4, 'area': 4, 'object': 4, 'recommendation': 4, 'reduce': 4, 'situation': 4, 'behavior': 4, 'well': 4, 'high': 4, 'real': 4, 'k': 4, 'particular': 4, 'normal': 4, 'classifier': 4, 'sequence': 4, 'o': 4, 'connection': 4, 'health': 4, 'care': 4, 'explicitly': 3, 'closely': 3, 'deliver': 3, 'refer': 3, 'certain': 3, 'have': 3, 'determine': 3, 'dataset': 3, 'representative': 3, 'recognize': 3, 'e': 3, 'respect': 3, 'p': 3, 'objective': 3, 'future': 3, 'symbolic': 3, 'especially': 3, 'work': 3, 'line': 3, 'science': 3, 'agent': 3, 'known': 3, 'property': 3, 'learner': 3, 'assumption': 3, 'ability': 3, 'key': 3, 'express': 3, 'pre': 3, 'unseen': 3, 'active': 3, 'draw': 3, 'inference': 3, 'accord': 3, 'long': 3, 'modeling': 3, 'random': 3, 'distribution': 3, 'branch': 3, 'error': 3, 'overfitting': 3, 'kind': 3, 'associate': 3, 'similar': 3, 'structure': 3, 'density': 3, 'explain': 3, 'estimate': 3, 'unlabeled': 3, 'small': 3, 'game': 3, 'dimensionality': 3, 'reduction': 3, 'fold': 3, 'int ...

# %%
# Calculate words weighted freq
weighted_freq_spacy = {}
# get maximum freq
max_freq_spacy = max(sorted_freq_spacy.values())
print(max_freq_spacy)

# compute and add to weighted_freq
weighted_freq_spacy = {word: count/max_freq_spacy for (word, count) in sorted_freq_spacy.items()}
print(weighted_freq_spacy)
# Out:
# 161
# {'learning': 1.0, 'machine': 0.6273291925465838, 'datum': 0.4161490683229814, 'algorithm': 0.391304347826087, 'model': 0.30434782608695654, 'training': 0.2546583850931677, 'learn': 0.19875776397515527, 'set': 0.19875776397515527, 'example': 0.19254658385093168, 'method': 0.18633540372670807, 'system': 0.16770186335403728, 'feature': 0.14285714285714285, 'artificial': 0.13664596273291926, 'input': 0.13664596273291926, 'network': 0.12422360248447205, 'represent': 0.12422360248447205, 'computer': 0.11801242236024845, 'task': 0.11801242236024845, 'rule': 0.11801242236024845, 'base': 0.11180124223602485, 'field': 0.11180124223602485, 'train': 0.11180124223602485, 'data': 0.10559006211180125, 'classification': 0.10559006211180125, 'decision': 0.09937888198757763, 'perform': 0.09937888198757763, 'use': 0.09316770186335403, 'problem': 0.09316770186335403, 'ai': 0.09316770186335403, 'approach': 0.08695652173913043, 'label': 0.08695652173913043, 'bias': 0.08695652173913043, 'program': 0.08074534161490683, 'unsupervised': 0.08074534161490683, 'find': 0.08074534161490683, 'knowledge': 0.08074534161490683, 'analysis': 0.07453416149068323, 'include': 0.07453416149068323, 'call': 0.07453416149068323, 'prediction': 0.06832298136645963, 'mining': 0.06832298136645963, 'research': 0.06832298136645963, 'performance': 0.06832298136645963, 'time': 0.06832298136645963, 'function': 0.06832298136645963, 'signal': 0.06832298136645963, 'process': 0.06832298136645963, 'neuron': 0.06832298136645963, 'human': 0.062111801242236024, 'neural': 0.062111801242236024, 'environment': 0.062111801242236024, 'supervised': 0.062111801242236024, 'output': 0.062111801242236024, 'regression': 0.062111801242236024, 'technique': 0.062111801242236024, 'representation': 0.062111801242236024, 'detection': 0.062111801242236024, 'tree': 0.062111801242236024, 'improve': 0.055900621118012424, 'theory': 0.055900621118012424, 'linear': 0.055900621118012424, 'predict': 0.055900621118012424, 'new': 0.055900621118012424, 'test': 0.055900621118012424, 'cluster': 0.055900621118012424, 'variable': 0.055900621118012424, 'dictionary': 0.055900621118012424, 'layer': 0.055900621118012424, 'ml': 0.049689440993788817, 'know': 0.049689440993788817, 'application': 0.049689440993788817, 'statistical': 0.049689440993788817, 'term': 0.049689440993788817, 'class': 0.049689440993788817, 'programming': 0.049689440993788817, 'result': 0.049689440993788817, 'apply': 0.049689440993788817, 'non': 0.049689440993788817, 'study': 0.043478260869565216, 'intelligence': 0.043478260869565216, 'build': 0.043478260869565216, 'order': 0.043478260869565216, 'need': 0.043478260869565216, 'mathematical': 0.043478260869565216, 'discover': 0.043478260869565216, 'give': 0.043478260869565216, 'supervise': 0.043478260869565216, 'probabilistic': 0.043478260869565216, 'increase': 0.043478260869565216, 'logic': 0.043478260869565216, 'information': 0.043478260869565216, 'goal': 0.043478260869565216, 'different': 0.043478260869565216, 'instance': 0.043478260869565216, 'generalization': 0.043478260869565216, 'deep': 0.043478260869565216, 'consider': 0.043478260869565216, 'contain': 0.043478260869565216, 'large': 0.043478260869565216, 'reinforcement': 0.043478260869565216, 'genetic': 0.043478260869565216, 'typically': 0.043478260869565216, 'sparse': 0.043478260869565216, 'anomaly': 0.043478260869565216, 'develop': 0.037267080745341616, 'subset': 0.037267080745341616, 'relate': 0.037267080745341616, 'statistic': 0.037267080745341616, 'optimization': 0.037267080745341616, 'involve': 0.037267080745341616, 'provide': 0.037267080745341616, 'require': 0.037267080745341616, 'specific': 0.037267080745341616, 'attempt': 0.037267080745341616, 'medical': 0.037267080745341616, 'lead': 0.037267080745341616, 'inductive': 0.037267080745341616, 'observation': 0.037267080745341616, 'accuracy': 0.037267080745341616, 'like': 0.037267080745341616, 'value': 0.037267080745341616, 'dimensional': 0.037267080745341616, 'self': 0.037267080745341616, 'com ...

# %%
# tokenize by sentence and get their scores, store in a dictionary
tokens_sentence_spacy = doc.sents
sentence_with_scores_spacy = {}
# grade sentence based on the sum of its words' total weight
for sentence in tokens_sentence_spacy:
    words = nlp(sentence.text)
    cur_score = 0
    for word in words:
        cur_score += weighted_freq_spacy.get(word.text.lower(), 0)
    sentence_with_scores_spacy[sentence] = cur_score
print(sentence_with_scores_spacy)
# Out:
# {Machine learning (ML) is the study of computer algorithms that improve automatically through experience and by the use of data.[1]: 2.024844720496894, It is seen as a part of artificial intelligence.: 0.18012422360248448, Machine learning algorithms build a model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.[2]: 2.565217391304348, Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.[3]: 2.0683229813664594,
# A subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers; but not all machine learning is statistical learning.: 4.440993788819876, The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning.: 1.968944099378882, Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning.[5][6]: 0.6273291925465839, In its application across business problems, machine learning is also referred to as predictive analytics.: 1.7080745341614907,
# Machine learning involves computers discovering how they can perform tasks without being explicitly programmed to do so.: 1.7453416149068322, It involves computers learning from data provided so that they carry out certain tasks.: 1.1304347826086956, For simple tasks assigned to computers, it is possible to program algorithms telling the machine how to execute all steps required to solve the problem at hand; on the computer's part, no learning is needed.: 1.9875776397515528, For more advanced tasks, it can be challenging for a human to manually create the needed algorithms.: 0.10559006211180125, In practice, it can turn out to be more effective to help the machine develop its own algorithm, rather than having human programmers specify every needed step.[7]: 1.180124223602484,
# The discipline of machine learning employs various approaches to teach computers to accomplish tasks where no fully satisfactory algorithm is available.: 2.08695652173913, In cases where vast numbers of potential answers exist, one approach is to label some of the correct answers as valid.: 0.2546583850931677, This can then be used as training data for the computer to improve the algorithm(s) it uses to determine correct answers.: 0.5652173913043479, For example, to train a system for the task of digital character recognition, the MNIST dataset of handwritten digits has often been used.[7]: 0.6708074534161491,
# The term machine learning was coined in 1959 by Arthur Samuel, an American IBMer and pioneer in the field of computer gaming and artificial intelligence.[8][9]: 2.080745341614906, A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.[10]: 4.428571428571429, Interest related to pattern recognition continued into the 1970s, as described by Duda and Hart in 1973.[11]: 0.11801242236024845, In 1981 a report was given on using teaching strategies so that a neural network learns to recognize 40 characters (26 letters, 10 digits, and 4 special symbols) from a computer terminal.[12]: 0.36024844720496896,
# Tom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E."[13]: 2.5838509316770186, This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms.: 1.807453416149068, This follows Alan Turing's proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?" is replaced with the question "Can machines do what we (as thinking entities) can do?".[14]: 0.14285714285714282,
# Modern day machine learning has two objectives, one is to classify data based on models which have been developed, the other purpose is to make predictions for future outcomes based on these models.: 1.8322981366459625, A hypothetical algorithm specific to classifying data may use computer vision of moles coupled with supervised learning in order to train it to classify the cancerous moles.: 2.0310559006211175, Where as, a machine learning algorithm for stock trading may inform the trader of future potential predictions.[15]: 2.0869565217391304,
# As a scientific endeavor, machine learning grew out of the quest for artificial intelligence.: 1.826086956521739, In the early days of AI as an academic discipline, some researchers were interested in having machines learn from data.: 0.44720496894409933, They attempted to approach the problem with various symbolic methods, as well as what was then termed "neural networks"; these were mostly perceptrons and other models that were later found to be reinventions of the generalized linear models of statistics.[18]: 0.35403726708074534, Probabilistic reasoning was also employed, especially in automated medical diagnosis.[19]:488
# : 0.10559006211180123, However, an increasing emphasis on the logical, knowledge-based approach caused a rift between AI and machine learning.: 1.9254658385093166, Probabilistic systems were plagued by theoretical and practical problems of data acquisition and representation.[19]:488: 0.19254658385093168, By 1980, expert systems had come to dominate AI, and statistics was out of favor.[20]: 0.14906832298136644, Work on symbolic/knowledge-based learning did continue within AI, leading to inductive logic programming, but the more statistical line of research was now outside the field of AI proper, in pattern recognition and information retrieval.[19]:708–710; 755: 1.8322981366459627, Neural networks research had been abandoned by AI and computer science around the same time.: 0.42857142857142855, This line, too, was continued outside the AI/CS field, as "connectionism", by researchers from other disciplines including Hopfield, Rumelhart and Hinton.: 0.26708074534161497, Their main success came in the mid-1980s with the reinvention of backpropagation.[19]:25
# : 0.031055900621118012, Machine learning (ML), reorganized as a separate field, started to flourish in the 1990s.: 1.8198757763975155, The field changed its goal from achieving artificial intelligence to tackling solvable problems of a practical nature.: 0.37888198757763975, It shifted focus away from the symbolic approaches it had inherited from AI, and toward methods and models borrowed from statistics and probability theory.[20]: 0.18633540372670807,
# As of 2020, many sources continue to assert that machine learning remains a subfield of AI.[21][22][16]: 1.6645962732919253, The main disagreement is whether all of ML is part of AI, as this would mean that anyone using ML could claim they are using AI.: 0.3354037267080745, Others have the view that not all of ML is part of AI[23][24][25] where only an 'intelligent' subset of ML is part of AI.[26]: 0.17391304347826086,
# The question to what is the difference between ML and AI is answered by Judea Pearl in The Book of Why.[27]: 0.22981366459627328, Accordingly ML learns and predicts based on passive observations, whereas AI implies an agent  interacting with the environment to learn and take actions that maximize its chance of successfully achieving its goals.[30]: 0.46583850931677023,
# Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).: 4.503105590062111, Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.: 4.881987577639752, Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge.: 2.658385093167701, Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.: 1.0248447204968945,
# Machine learning also has intimate ties to optimization: many learning problems are formulated as minimization of some loss function on a training set of examples.: 3.2236024844720492, Loss functions express the discrepancy between the predictions of the model being trained and the actual problem instances (for example, in classification, one wants to assign a label to instances, and models are trained to correctly predict the pre-assigned labels of a set of examples).[31]: 1.1428571428571428,
# The difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.: 3.975155279503106, Characterizing the generalization of various learning algorithms is an active topic of current research, especially for deep learning algorithms.: 2.217391304347826,
# Machine learning and statistics are closely related fields in terms of methods, but distinct in their principal goal: statistics draws population inferences from a sample, while machine learning finds generalizable predictive patterns.[32]: 3.4720496894409933, According to Michael I. Jordan, the ideas of machine learning, from methodological principles to theoretical tools, have had a long pre-history in statistics.[33]: 1.7391304347826084, He also suggested the term data science as a placeholder to call the overall field.[33]: 0.26708074534161497,
# Leo Breiman distinguished two statistical modeling paradigms: data model and algorithmic model,[34] wherein "algorithmic model" means more or less the machine learning algorithms like Random forest.: 2.5465838509316767,
# Some statisticians have adopted methods from machine learning, leading to a combined field that they call statistical learning.[35]
#
# A core objective of a learner is to generalize from its experience.[4][36]: 1.93167701863354, Generalization in this context is the ability of a learning machine to perform accurately on new, unseen examples/tasks after having experienced a learning data set.: 3.211180124223602, The training examples come from some generally unknown probability distribution (considered representative of the space of occurrences) and the learner has to build a general model about this space that enables it to produce sufficiently accurate predictions in new cases.: 0.9130434782608695,
# The computational analysis of machine learning algorithms and their performance is a branch of theoretical computer science known as computational learning theory.: 3.074534161490683, Because training sets are finite and the future is uncertain, learning theory usually does not yield guarantees of the performance of algorithms.: 1.4472049689440993, Instead, probabilistic bounds on the performance are quite common.: 0.16149068322981364, The bias–variance decomposition is one way to quantify generalization error.: 0.19254658385093168,
# For the best performance in the context of generalization, the complexity of the hypothesis should match the complexity of the function underlying the data.: 0.4161490683229814, If the hypothesis is less complex than the function, then the model has under fitted the data.: 0.5217391304347826, If the complexity of the model is increased in response, then the training error decreases.: 0.6149068322981367, But if the hypothesis is too complex, then the model is subject to overfitting and generalization will be: 0.4161490683229814, poorer.[37]: 0,
# In addition to performance bounds, learning theorists study the time complexity and feasibility of learning.: 2.2484472049689437, In computational learning theory, a computation is considered feasible if it can be done in polynomial time.: 1.186335403726708, There are two kinds of time complexity results.: 0.09937888198757765, Positive results show that a certain class of functions can be learned in polynomial time.: 0.20496894409937888, Negative results show that certain classes cannot be learned in polynomial time.: 0.15527950310559008,
#
# Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:
# Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.[38]: 4.689440993788821, The data is known as training data, and consists of a set of training examples.: 0.9378881987577639, Each training example has one or more inputs and the desired output, also known as a supervisory signal.: 0.6024844720496895,  In the mathematical model, each training example is represented by an array or vector, sometimes called a feature vector, and the training data is represented by a matrix.: 1.3975155279503104, Through iterative optimization of an objective function, supervised learning algorithms learn a function that can be used to predict the output associated with new inputs.[39]: 1.6397515527950308, An optimal function will allow the algorithm to correctly determine the output for inputs that were not a part of the training data.: 0.9440993788819877, An algorithm that improves the accuracy of its outputs or predictions over time is said to have learned to perform that task.[13]: 0.6149068322981367,
# Types of supervised learning algorithms include active learning, classification and regression.[40]: 2.260869565217391, Classification algorithms are used when the outputs are restricted to a limited set of values, and regression algorithms are used when the outputs may have any numerical value within a range.: 0.4472049689440994, As an example, for a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email.: 0.9627329192546586,
# Similarity learning is an area of supervised machine learning closely related to regression and classification, but the goal is to learn from examples using a similarity function that measures how similar or related two objects are.: 3.354037267080745, It has applications in ranking, recommendation systems, visual identity tracking, face verification, and speaker verification.: 0.08695652173913042,
# Unsupervised learning algorithms take a set of data that contains only inputs, and find structure in the data, like grouping or clustering of data points.: 1.7577639751552796, The algorithms, therefore, learn from test data that has not been labeled, classified or categorized.: 0.36024844720496896, Instead of responding to feedback, unsupervised learning algorithms identify commonalities in the data and react based on the presence or absence of such commonalities in each new piece of data.: 1.4472049689440991, A central application of unsupervised learning is in the field of density estimation in statistics, such as finding the probability density function.[41]: 1.341614906832298, Though unsupervised learning encompasses other domains involving summarizing and explaining data features.: 1.1863354037267082,
# Cluster analysis is the assignment of a set of observations into subsets (called clusters) so that observations within the same cluster are similar according to one or more predesignated criteria, while observations drawn from different clusters are dissimilar.: 0.4658385093167702, Different clustering techniques make different assumptions on the structure of the data, often defined by some similarity metric and evaluated, for example, by internal compactness, or the similarity between members of the same cluster, and separation, the difference between clusters.: 0.5962732919254659, Other methods are based on estimated density and graph connectivity.: 0.037267080745341616,
# Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data).: 3.9440993788819876, Some of the training examples are missing training labels,  yet many machine-learning researchers have found that unlabeled data, when used in conjunction with a small amount of labeled data, can produce a considerable improvement in learning accuracy.: 3.4782608695652173,
# In weakly supervised learning, the training labels are noisy, limited, or imprecise; however, these labels are often cheaper to obtain, resulting in larger effective training sets.[42]: 1.6397515527950308,
# Reinforcement learning is an area of machine learning concerned with how software agents ought to take actions in an environment so as to maximize some notion of cumulative reward.: 2.8198757763975144, Due to its generality, the field is studied in many other disciplines, such as game theory, control theory, operations research, information theory, simulation-based optimization, multi-agent systems, swarm intelligence, statistics and genetic algorithms.: 0.5962732919254659, In machine learning, the environment is typically represented as a Markov decision process (MDP).: 1.919254658385093, Many reinforcement learning algorithms use dynamic programming techniques.[43]: 1.1987577639751554, Reinforcement learning algorithms do not assume knowledge of an exact mathematical model of the MDP, and are used when exact models are infeasible.: 1.5279503105590062, Reinforcement learning algorithms are used in autonomous vehicles or in learning to play a game against a human opponent.: 2.142857142857143,
# The Dimensionality reduction is a process of reducing the number of random variables under the consideration by obtaining a set of principal variables.[44]: 0.37888198757763975, In other words, it is a process of reducing the dimension of your feature set also called no of features.: 0.42236024844720493, Most of the dimensionality reduction techniques can be considered as either feature elimination or extraction.: 0.1925465838509317,
# One of the popular method of dimensionality reduction is called as principal component analysis.: 0.36645962732919257,
# The PCA involves changing higher dimensional data (eg. 3D) to a smaller space (eg. 2D).: 0.2111801242236025, This results in a smaller dimension of data, (2D instead of 3D) while keeping all original variables in the model without changing the data.[45]: 0.45962732919254656,
# Other approaches have been developed which don't fit neatly into this three-fold categorisation, and sometimes more than one is used by the same machine learning system.: 1.8695652173913042, For example topic modeling,  meta learning.[46]: 0.2298136645962733,
# As of 2020, deep learning has become the dominant approach for much ongoing work in the field of machine learning.[7]: 1.9068322981366457,
# Self-learning as a machine learning paradigm was introduced in 1982 along with a neural network capable of self-learning named crossbar adaptive array (CAA).[47]: 3.9378881987577627, It is a learning with no external rewards and no external teacher advice.: 1.0434782608695652, The CAA self-learning algorithm computes, in a crossbar fashion, both decisions about actions and emotions (feelings) about consequence situations.: 1.4782608695652173, The system is driven by the interaction between cognition and emotion.[48]: 0.1925465838509317,
# : 0, The self-learning algorithm updates a memory matrix W =||w(a,s)|| such that in each iteration executes the following machine learning routine:
# It is a system with only one input, situation s, and only one output, action (or behavior) a.: 3.571428571428571, There is neither a separate reinforcement input nor an advice input from the environment.: 0.4161490683229814, The backpropagated value (secondary reinforcement) is the emotion toward the consequence situation.: 0.14906832298136644, The CAA exists in two environments, one is the behavioral environment where it behaves, and the other is the genetic environment, wherefrom it initially and only once receives initial emotions about situations to be encountered in the behavioral environment.: 0.2981366459627329, After receiving the genome (species) vector from the genetic environment, the CAA learns a goal-seeking behavior, in an environment that contains both desirable and undesirable situations.[49]: 0.30434782608695654,
# : 0, Several learning algorithms aim at discovering better representations of the inputs provided during training.[50]: 1.0124223602484472, Classic examples include principal components analysis and cluster analysis.: 0.31055900621118016, Feature learning algorithms, also called representation learning algorithms, often attempt to preserve the information in their input but also transform it in a way that makes it useful, often as a pre-processing step before performing classification or predictions.: 2.633540372670807, This technique allows reconstruction of the inputs coming from the unknown data-generating distribution, while not being necessarily faithful to configurations that are implausible under that distribution.: 0.26086956521739135, This replaces manual feature engineering, and allows a machine to both learn the features and use them to perform a specific task.: 1.329192546583851,
# : 0, Feature learning can be either supervised or unsupervised.: 1.2857142857142856, In supervised feature learning, features are learned using labeled input data.: 1.4472049689440996, Examples include artificial neural networks, multilayer perceptrons, and supervised dictionary learning.: 1.3975155279503106, In unsupervised feature learning, features are learned with unlabeled input data.: 1.484472049689441,  Examples include dictionary learning, independent component analysis, autoencoders, matrix factorization[51] and various forms of clustering.[52][53][54]: 1.2670807453416146,
# : 0, Manifold learning algorithms attempt to do so under the constraint that the learned representation is low-dimensional.: 1.1739130434782608, Sparse coding algorithms attempt to do so under the constraint that the learned representation is sparse, meaning that the mathematical model has many zeros.: 0.546583850931677, Multilinear subspace learning algorithms aim to learn low-dimensional representations directly from tensor representations for multidimensional data, without reshaping them into higher-dimensional vectors.[55]: 1.4472049689440991, Deep learning algorithms discover multiple levels of representation, or a hierarchy of features, with higher-level, more abstract features defined in terms of (or generating) lower-level features.: 1.223602484472049, It has been argued that an intelligent machine is one that learns a representation that disentangles the underlying factors of variation that explain the observed data.[56]: 0.7267080745341615,
# Feature learning is motivated by the fact that machine learning tasks such as classification often require input that is mathematically and computationally convenient to process.: 3.1552795031055894, However, real-world data such as images, video, and sensory data has not yielded to attempts to algorithmically define specific features.: 0.3354037267080746, An alternative is to discover such features or representations through examination, without relying on explicit algorithms.: 0.06211180124223602,
# Sparse dictionary learning is a feature learning method where a training example is represented as a linear combination of basis functions, and is assumed to be a sparse matrix.: 3.0186335403726705, The method is strongly NP-hard and difficult to solve approximately.[57]: 0.2422360248447205, A popular heuristic method for sparse dictionary learning is the K-SVD algorithm.: 1.732919254658385, Sparse dictionary learning has been applied in several contexts.: 1.0993788819875776, In classification, the problem is to determine the class to which a previously unseen training example belongs.: 0.7639751552795031, For a dictionary where each class has already been built, a new training example is associated with the class that is best sparsely represented by the corresponding dictionary.: 0.7391304347826088, Sparse dictionary learning has also been applied in image de-noising.: 1.1428571428571426, The key idea is that a clean image patch can be sparsely represented by an image dictionary, but the noise cannot.[58]: 0.18633540372670807,
# In data mining, anomaly detection, also known as outlier detection, is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.[59]: 0.453416149068323, Typically, the anomalous items represent an issue such as bank fraud, a structural defect, medical problems or errors in a text.: 0.26086956521739135, Anomalies are referred to as outliers, novelties, noise, deviations and exceptions.[60]: 0.012422360248447204,
# In particular, in the context of abuse and network intrusion detection, the interesting objects are often not rare objects, but unexpected bursts of inactivity.: 0.2981366459627329, This pattern does not adhere to the common statistical definition of an outlier as a rare object, and many outlier detection methods (in particular, unsupervised algorithms) will fail on such data unless it has been aggregated appropriately.: 0.5527950310559006, Instead, a cluster analysis algorithm may be able to detect the micro-clusters formed by these patterns.[61]: 0.5900621118012424,
# : 0, Three broad categories of anomaly detection techniques exist.[62]: 0.11801242236024845, Unsupervised anomaly detection techniques detect anomalies in an unlabeled test data set under the assumption that the majority of the instances in the data set are normal, by looking for instances that seem to fit least to the remainder of the data set.: 1.279503105590062, Supervised anomaly detection techniques require a data set that has been labeled as "normal" and "abnormal" and involves training a classifier (the key difference to many other statistical classification problems is the inherently unbalanced nature of outlier detection).: 1.1490683229813665, Semi-supervised anomaly detection techniques construct a model representing normal behavior from a given normal training data set and then test the likelihood of a test instance to be generated by the model.: 1.5900621118012424,
# In developmental robotics, robot learning algorithms generate their own sequences of learning experiences, also known as a curriculum, to cumulatively acquire new skills through self-guided exploration and social interaction with humans.: 2.2236024844720492, These robots use guidance mechanisms such as active learning, maturation, motor synergies and imitation.: 1.1366459627329188,
# Association rule learning is a rule-based machine learning method for discovering relationships between variables in large databases.: 3.1242236024844723, It is intended to identify strong rules discovered in databases using some measure of "interestingness".[63]: 0.06832298136645962,
# Rule-based machine learning is a general term for any machine learning method that identifies, learns, or evolves "rules" to store, manipulate or apply knowledge.: 3.770186335403727, The defining characteristic of a rule-based machine learning algorithm is the identification and utilization of a set of relational rules that collectively represent the knowledge captured by the system.: 2.7639751552795024, This is in contrast to other machine learning algorithms that commonly identify a singular model that can be universally applied to any instance in order to make a prediction.[64]: 2.0993788819875774, Rule-based machine learning approaches include learning classifier systems, association rule learning, and artificial immune systems.: 4.136645962732919,
# Based on the concept of strong rules, Rakesh Agrawal, Tomasz Imieliński and Arun Swami introduced association rules for discovering regularities between products in large-scale transaction data recorded by point-of-sale (POS) systems in supermarkets.[65]: 0.2981366459627329, For example, the rule
#
#
#
# {
#
# o
# n
# i
# o
# n
# s
# ,
# p
# o
# t
# a
# t
# o
# e
# s
#
# }
# ⇒
# {
#
# b
# u
# r
# g
# e
# r
#
# }
#
#
# {\displaystyle \{\mathrm {onions,potatoes} \}\Rightarrow \{\mathrm {burger} \}}
#
#  found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat.: 0.8136645962732922, Such information can be used as the basis for decisions about marketing activities such as promotional pricing or product placements.: 0.08695652173913042, In addition to market basket analysis, association rules are employed today in application areas including Web usage mining, intrusion detection, continuous production, and bioinformatics.: 0.38509316770186347, In contrast with sequence mining, association rule learning typically does not consider the order of items either within a transaction or across transactions.: 1.403726708074534,
# Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.: 7.552795031055901, They seek to identify a set of context-dependent rules that collectively store and apply knowledge in a piecewise manner in order to make predictions.[66]: 0.5031055900621119,
# Inductive logic programming (ILP) is an approach to rule-learning using logic programming as a uniform representation for input examples, background knowledge, and hypotheses.: 1.7391304347826086, Given an encoding of the known background knowledge and a set of examples represented as a logical database of facts, an ILP system will derive a hypothesized logic program that entails all positive and no negative examples.: 0.7453416149068323, Inductive programming is a related field that considers any kind of programming language for representing hypotheses (and not only logic programming), such as functional programs.: 0.4285714285714286,
# Inductive logic programming is particularly useful in bioinformatics and natural language processing.: 0.2111801242236025, Gordon Plotkin and Ehud Shapiro laid the initial theoretical foundation for inductive machine learning in a logical setting.[67][68][69]: 1.763975155279503, Shapiro built their first implementation (Model Inference System) in 1981: a Prolog program that inductively inferred logic programs from positive and negative examples.[70]: 0.7142857142857142, The term inductive here refers to philosophical induction, suggesting a theory to explain observed facts, rather than mathematical induction, proving a property for all members of a well-ordered set.: 0.47826086956521735,
# Performing machine learning involves creating a model, which is trained on some training data and then can process additional data to make predictions.: 2.4968944099378882, Various types of models have been used and researched for machine learning systems.: 1.6459627329192545,
# Artificial neural networks (ANNs), or connectionist systems, are computing systems vaguely inspired by the biological neural networks that constitute animal brains.: 0.3167701863354038, Such systems "learn" to perform tasks by considering examples, generally without being programmed with any task-specific rules.: 0.46583850931677023,
# An ANN is a model based on a collection of connected units or nodes called "artificial neurons", which loosely model the neurons in a biological brain.: 0.8385093167701864, Each connection, like the synapses in a biological brain, can transmit information, a "signal", from one artificial neuron to another.: 0.4347826086956522, An artificial neuron that receives a signal can process it and then signal additional artificial neurons connected to it.: 0.5652173913043479, In common ANN implementations, the signal at a connection between artificial neurons is a real number, and the output of each artificial neuron is computed by some non-linear function of the sum of its inputs.: 0.7701863354037267, The connections between artificial neurons are called "edges".: 0.13664596273291926, Artificial neurons and edges typically have a weight that adjusts as learning proceeds.: 1.2111801242236024, The weight increases or decreases the strength of the signal at a connection.: 0.11180124223602483, Artificial neurons may have a threshold such that the signal is only sent if the aggregate signal crosses that threshold.: 0.33540372670807456, Typically, artificial neurons are aggregated into layers.: 0.18012422360248448, Different layers may perform different kinds of transformations on their inputs.: 0.18633540372670807, Signals travel from the first layer (the input layer) to the last layer (the output layer), possibly after traversing the layers multiple times.: 0.453416149068323,
# The original goal of the ANN approach was to solve problems in the same way that a human brain would.: 0.3043478260869565, However, over time, attention moved to performing specific tasks, leading to deviations from biology.: 0.11801242236024845, Artificial neural networks have been used on a variety of tasks, including computer vision, speech recognition, machine translation, social network filtering, playing board and video games and medical diagnosis.: 1.3043478260869563,
# Deep learning consists of multiple hidden layers in an artificial neural network.: 1.3913043478260867, This approach tries to model the way the human brain processes light and sound into vision and hearing.: 0.5652173913043478, Some successful applications of deep learning are computer vision and speech recognition.[71]: 1.2298136645962732,
# Decision tree learning uses a decision tree as a predictive model to go from observations about an item (represented in the branches) to conclusions about the item's target value (represented in the leaves).: 1.7701863354037266, It is one of the predictive modeling approaches used in statistics, data mining, and machine learning.: 1.8571428571428572, Tree models where the target variable can take a discrete set of values are called classification trees; in these tree structures, leaves represent class labels and branches represent conjunctions of features that lead to those class labels.: 0.9006211180124223, Decision trees where the target variable can take continuous values (typically real numbers) are called regression trees.: 0.32298136645962733, In decision analysis, a decision tree can be used to visually and explicitly represent decisions and decision making.: 0.5962732919254659, In data mining, a decision tree describes data, but the resulting classification tree can be an input for decision making.: 0.8571428571428571,
# Support-vector machines (SVMs), also known as support-vector networks, are a set of related supervised learning methods used for classification and regression.: 1.5776397515527951, Given a set of training examples, each marked as belonging to one of two categories, an SVM training algorithm builds a model that predicts whether a new example falls into one category or the other.[72: 1.6956521739130435, ]: 0,  An SVM training algorithm is a non-probabilistic, binary, linear classifier, although methods such as Platt scaling exist to use SVM in a probabilistic classification setting.: 1.15527950310559, In addition to performing linear classification, SVMs can efficiently perform a non-linear classification using what is called the kernel trick, implicitly mapping their inputs into high-dimensional feature spaces.: 0.7701863354037268,
# Regression analysis encompasses a large variety of statistical methods to estimate the relationship between input variables and their associated features.: 0.4347826086956521, Its most common form is linear regression, where a single line is drawn to best fit the given data according to a mathematical criterion such as ordinary least squares.: 0.39130434782608703, The latter is often extended by regularization (mathematics) methods to mitigate overfitting and bias, as in ridge regression.: 0.18633540372670807, When dealing with non-linear problems, go-to models include polynomial regression (for example, used for trendline fitting in Microsoft Excel[73]), logistic regression (often used in statistical classification) or even kernel regression, which introduces non-linearity by taking advantage of the kernel trick to implicitly map input variables to higher-dimensional space.: 1.124223602484472,
# A Bayesian network, belief network, or directed acyclic graphical model is a probabilistic graphical model that represents a set of random variables and their conditional independence with a directed acyclic graph (DAG).: 1.2360248447204967, For example, a Bayesian network could represent the probabilistic relationships between diseases and symptoms.: 0.515527950310559, Given symptoms, the network can be used to compute the probabilities of the presence of various diseases.: 0.17391304347826086, Efficient algorithms exist that perform inference and learning.: 1.1614906832298137, Bayesian networks that model sequences of variables, like speech signals or protein sequences, are called dynamic Bayesian networks.: 0.44720496894409945, Generalizations of Bayesian networks that can represent and solve decision problems under uncertainty are called influence diagrams.: 0.2981366459627329,
# A genetic algorithm (GA) is a search algorithm and heuristic technique that mimics the process of natural selection, using methods such as mutation and crossover to generate new genotypes in the hope of finding good solutions to a given problem.: 1.248447204968944, In machine learning, genetic algorithms were used in the 1980s and 1990s.[74][75]: 1.670807453416149, Conversely, machine learning techniques have been used to improve the performance of genetic and evolutionary algorithms.[76]: 1.826086956521739,
# Usually, machine learning models require a lot of data in order for them to perform well.: 1.968944099378882, Usually, when training a machine learning model, one needs to collect a large, representative sample of data from a training set.: 2.881987577639752, Data from the training set can be as varied as a corpus of text, a collection of images, and data collected from individual users of a service.: 0.7391304347826088, Overfitting is something to watch out for when training a machine learning model.: 2.2111801242236027, Trained models derived from biased data can result in skewed or undesired predictions.: 0.18012422360248448, Algorithmic bias is a potential result from data not fully prepared for training.: 0.5652173913043479,
# Federated learning is an adapted form of distributed artificial intelligence to training machine learning models that decentralizes the training process, allowing for users' privacy to be maintained by not needing to send their data to a centralized server.: 3.5776397515527947, This also increases efficiency by decentralizing the training process to many devices.: 0.32919254658385094, For example, Gboard uses federated machine learning to train search query prediction models on users' mobile phones without having to send individual searches back to Google.[77]: 2.08695652173913,
# There are many applications for machine learning, including:
# In 2006, the media-services provider Netflix held the first "Netflix Prize" competition to find a program to better predict user preferences and improve the accuracy of its existing Cinematch movie recommendation algorithm by at least 10%.: 2.472049689440993,  A joint team made up of researchers from AT&T Labs-Research in collaboration with the teams Big Chaos and Pragmatic Theory built an ensemble model to win the Grand Prize in 2009 for $1 million.[79]: 0.5155279503105591, Shortly after the prize was awarded, Netflix realized that viewers' ratings were not the best indicators of their viewing patterns ("everything is a recommendation") and they changed their recommendation engine accordingly.[80]: 0.10559006211180123, In 2010 The Wall Street Journal wrote about the firm Rebellion Research and their use of machine learning to predict the financial crisis.[81]: 1.8944099378881987, In 2012, co-founder of Sun Microsystems, Vinod Khosla, predicted that 80% of medical doctors' jobs would be lost in the next two decades to automated machine learning medical diagnostic software.[82]: 1.7515527950310559, In 2014, it was reported that a machine learning algorithm had been applied in the field of art history to study fine art paintings and that it may have revealed previously unrecognized influences among artists.[83]: 2.273291925465838, In 2019 Springer Nature published the first research book created using machine learning.[84]: 0.7515527950310559, In 2020, machine learning technology was used to help make diagnoses and aid researchers in developing a cure for COVID-19.[85]: 1.6770186335403725, Machine learning is recently applied to predict the green behavior of human-being.[86]: 1.7888198757763973, Recently, machine learning technology is also applied to optimise smartphone's performance and thermal behaviour based on the user's interaction with the phone.[87][88]: 1.7950310559006206,
# Although machine learning has been transformative in some fields, machine-learning programs often fail to deliver expected results.[89][90][91]: 3.31055900621118, Reasons for this are numerous: lack of (suitable) data, lack of access to the data, data bias, privacy problems, badly chosen tasks and algorithms, wrong tools and people, lack of resources, and evaluation problems.[92]: 0.5527950310559008,
# In 2018, a self-driving car from Uber failed to detect a pedestrian, who was killed after a collision.[93]: 0.07453416149068322, Attempts to use machine learning in healthcare with the IBM Watson system failed to deliver even after years of time and billions of dollars invested.[94][95]: 1.993788819875776,
# Machine learning has been used as a strategy to update the evidence related to systematic review and increased reviewer burden related to the growth of biomedical literature.: 1.770186335403726, While it has improved with training sets, it has not yet developed sufficiently to reduce the workload burden without limiting the necessary sensitivity for the findings research themselves.[96]: 0.39751552795031064,
# Machine learning approaches in particular can suffer from different data biases.: 1.8074534161490683, A machine learning system trained specifically on current customers may not be able to predict the needs of new customer groups that are not represented in the training data.: 2.322981366459627, When trained on man-made data, machine learning is likely to pick up the constitutional and unconscious biases already present in society.[97]: 1.7826086956521736, Language models learned from data have been shown to contain human-like biases.[98][99]: 0.2981366459627329, Machine learning systems used for criminal risk assessment have been found to be biased against black people.[100][101]: 1.6894409937888195, In 2015, Google photos would often tag black people as gorillas,[102] and in 2018 this still was not well resolved, but Google reportedly was still using the workaround to remove all gorillas from the training data, and thus was not able to recognize real gorillas: 0.5465838509316772, at all.[103: 0, ]: 0, Similar issues with recognizing non-white people have been found in many other systems.[104]: 0.13043478260869565, In 2016, Microsoft tested a chatbot that learned from Twitter, and it quickly picked up racist and sexist language.[105]: 0.049689440993788817, Because of such challenges, the effective use of machine learning may take longer to be adopted in other domains.[106]: 1.7515527950310559, Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...: 4.0062111801242235, It’s inspired by people, it’s created by people, and—most importantly—it impacts people.: 0.11801242236024845, It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”[107]
# Classification of machine learning models can be validated by accuracy estimation techniques like the holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.: 4.285714285714286, In comparison, the K-fold-cross-validation method randomly partitions the data into K subsets and then K experiments are performed each respectively considering 1 subset for evaluation and the remaining K-1 subsets for training the model.: 1.049689440993789, In addition to the holdout and cross-validation methods, bootstrap, which samples n instances with replacement from the dataset, can be used to assess model accuracy.[108]: 0.4347826086956522,
# In addition to overall accuracy, investigators frequently report sensitivity and specificity meaning True Positive Rate (TPR) and True Negative Rate (TNR) respectively.: 0.329192546583851, Similarly, investigators sometimes report the false positive rate (FPR) as well as the false negative rate (FNR).: 0.22981366459627328, However, these rates are ratios that fail to reveal their numerators and denominators.: 0.043478260869565216, The total operating characteristic (TOC) is an effective method to express a model's diagnostic ability.: 0.6211180124223603, TOC shows the numerators and denominators of the previously mentioned rates, thus TOC provides more information than the commonly used receiver operating characteristic (ROC) and ROC's associated area under the curve (AUC).[109]: 0.2236024844720497,
# Machine learning poses a host of ethical questions.: 1.652173913043478, Systems which are trained on datasets collected with biases may exhibit these biases upon use (algorithmic bias), thus digitizing cultural prejudices.[110]: 0.2236024844720497, For example, in 1988, the UK's Commission for Racial Equality found that St. George's Medical School had been using a computer program trained from data of previous admissions staff and this program had denied nearly 60 candidates who were found to be either women or had non-European sounding names.[97]: 0.7329192546583853, Using job hiring data from a firm with racist hiring policies may lead to a machine learning system duplicating the bias by scoring job applicants by similarity to previous successful applicants.[111][112]: 2.167701863354037, Responsible collection of data and documentation of algorithmic rules used by a system thus is a critical part of machine learning.: 1.968944099378882,
# AI can be well-equipped to make decisions in technical fields, which rely heavily on data and historical information.: 0.31677018633540377, These decisions rely on objectivity and logical reasoning.[113]: 0.049689440993788817, Because human languages contain biases, machines trained on language corpora will necessarily also learn these biases.[114][115]: 0.34782608695652173,
# Other forms of ethical challenges, not related to personal biases, are seen in health care.: 0.10559006211180122, There are concerns among health care professionals that these systems might not be designed in the public's interest but as income-generating machines.[116]: 0.07453416149068322, This is especially true in the United States where there is a long-standing ethical dilemma of improving health care, but also increasing profits.: 0.14285714285714285, For example, the algorithms could be designed to provide patients with unnecessary tests or medication in which the algorithm's proprietary owners hold stakes.: 0.6521739130434784, There is  potential for machine learning in health care to provide professionals an additional tool to diagnose, medicate, and plan recovery paths for patients, but this requires these biases to be mitigated.[117]: 1.807453416149068,
# Since the 2010s, advances in both machine learning algorithms and computer hardware have led to more efficient methods for training deep neural networks (a particular narrow subdomain of machine learning) that contain many layers of non-linear hidden units.[118]: 3.9689440993788825, By 2019, graphic processing units (GPUs), often with AI-specific enhancements, had displaced CPUs as the dominant method of training large-scale commercial cloud AI.[119]: 0.670807453416149, OpenAI estimated the hardware compute used in the largest deep learning projects from AlexNet (2012) to AlphaZero (2017), and found a 300,000-fold increase in the amount of compute required, with a doubling-time trendline of 3.4 months.[120][121]: 1.291925465838509,
# Software suites containing a variety of machine learning algorithms include the following:
# : 1.7453416149068322}

# %% [markdown]
# ## Summarization with sentence with highest scores

# %%
# sort sentence by scores
sorted_sentence_tokens_spacy = dict(sorted(sentence_with_scores_spacy.items(), key = lambda pair: pair[1], reverse = True))
print(sorted_sentence_tokens_spacy)
print(len(sorted_sentence_tokens_spacy))
# Out:
# {
# Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.: 7.552795031055901, Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.: 4.881987577639752,
#
# Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:
# Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.[38]: 4.689440993788821,
# Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).: 4.503105590062111,
# A subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers; but not all machine learning is statistical learning.: 4.440993788819876, A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.[10]: 4.428571428571429, It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”[107]
# Classification of machine learning models can be validated by accuracy estimation techniques like the holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.: 4.285714285714286, Rule-based machine learning approaches include learning classifier systems, association rule learning, and artificial immune systems.: 4.136645962732919, Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...: 4.0062111801242235,
# The difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.: 3.975155279503106,
# Since the 2010s, advances in both machine learning algorithms and computer hardware have led to more efficient methods for training deep neural networks (a particular narrow subdomain of machine learning) that contain many layers of non-linear hidden units.[118]: 3.9689440993788825,
# Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data).: 3.9440993788819876,
# Self-learning as a machine learning paradigm was introduced in 1982 along with a neural network capable of self-learning named crossbar adaptive array (CAA).[47]: 3.9378881987577627,
# Rule-based machine learning is a general term for any machine learning method that identifies, learns, or evolves "rules" to store, manipulate or apply knowledge.: 3.770186335403727,
# Federated learning is an adapted form of distributed artificial intelligence to training machine learning models that decentralizes the training process, allowing for users' privacy to be maintained by not needing to send their data to a centralized server.: 3.5776397515527947, The self-learning algorithm updates a memory matrix W =||w(a,s)|| such that in each iteration executes the following machine learning routine:
# It is a system with only one input, situation s, and only one output, action (or behavior) a.: 3.571428571428571, Some of the training examples are missing training labels,  yet many machine-learning researchers have found that unlabeled data, when used in conjunction with a small amount of labeled data, can produce a considerable improvement in learning accuracy.: 3.4782608695652173,
# Machine learning and statistics are closely related fields in terms of methods, but distinct in their principal goal: statistics draws population inferences from a sample, while machine learning finds generalizable predictive patterns.[32]: 3.4720496894409933,
# Similarity learning is an area of supervised machine learning closely related to regression and classification, but the goal is to learn from examples using a similarity function that measures how similar or related two objects are.: 3.354037267080745,
# Although machine learning has been transformative in some fields, machine-learning programs often fail to deliver expected results.[89][90][91]: 3.31055900621118,
# Machine learning also has intimate ties to optimization: many learning problems are formulated as minimization of some loss function on a training set of examples.: 3.2236024844720492, Generalization in this context is the ability of a learning machine to perform accurately on new, unseen examples/tasks after having experienced a learning data set.: 3.211180124223602,
# Feature learning is motivated by the fact that machine learning tasks such as classification often require input that is mathematically and computationally convenient to process.: 3.1552795031055894,
# Association rule learning is a rule-based machine learning method for discovering relationships between variables in large databases.: 3.1242236024844723,
# The computational analysis of machine learning algorithms and their performance is a branch of theoretical computer science known as computational learning theory.: 3.074534161490683,
# Sparse dictionary learning is a feature learning method where a training example is represented as a linear combination of basis functions, and is assumed to be a sparse matrix.: 3.0186335403726705, Usually, when training a machine learning model, one needs to collect a large, representative sample of data from a training set.: 2.881987577639752,
# Reinforcement learning is an area of machine learning concerned with how software agents ought to take actions in an environment so as to maximize some notion of cumulative reward.: 2.8198757763975144, The defining characteristic of a rule-based machine learning algorithm is the identification and utilization of a set of relational rules that collectively represent the knowledge captured by the system.: 2.7639751552795024, Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge.: 2.658385093167701, Feature learning algorithms, also called representation learning algorithms, often attempt to preserve the information in their input but also transform it in a way that makes it useful, often as a pre-processing step before performing classification or predictions.: 2.633540372670807,
# Tom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E."[13]: 2.5838509316770186, Machine learning algorithms build a model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.[2]: 2.565217391304348,
# Leo Breiman distinguished two statistical modeling paradigms: data model and algorithmic model,[34] wherein "algorithmic model" means more or less the machine learning algorithms like Random forest.: 2.5465838509316767,
# Performing machine learning involves creating a model, which is trained on some training data and then can process additional data to make predictions.: 2.4968944099378882,
# There are many applications for machine learning, including:
# In 2006, the media-services provider Netflix held the first "Netflix Prize" competition to find a program to better predict user preferences and improve the accuracy of its existing Cinematch movie recommendation algorithm by at least 10%.: 2.472049689440993, A machine learning system trained specifically on current customers may not be able to predict the needs of new customer groups that are not represented in the training data.: 2.322981366459627, In 2014, it was reported that a machine learning algorithm had been applied in the field of art history to study fine art paintings and that it may have revealed previously unrecognized influences among artists.[83]: 2.273291925465838,
# Types of supervised learning algorithms include active learning, classification and regression.[40]: 2.260869565217391,
# In addition to performance bounds, learning theorists study the time complexity and feasibility of learning.: 2.2484472049689437,
# In developmental robotics, robot learning algorithms generate their own sequences of learning experiences, also known as a curriculum, to cumulatively acquire new skills through self-guided exploration and social interaction with humans.: 2.2236024844720492, Characterizing the generalization of various learning algorithms is an active topic of current research, especially for deep learning algorithms.: 2.217391304347826, Overfitting is something to watch out for when training a machine learning model.: 2.2111801242236027, Using job hiring data from a firm with racist hiring policies may lead to a machine learning system duplicating the bias by scoring job applicants by similarity to previous successful applicants.[111][112]: 2.167701863354037, Reinforcement learning algorithms are used in autonomous vehicles or in learning to play a game against a human opponent.: 2.142857142857143, This is in contrast to other machine learning algorithms that commonly identify a singular model that can be universally applied to any instance in order to make a prediction.[64]: 2.0993788819875774, Where as, a machine learning algorithm for stock trading may inform the trader of future potential predictions.[15]: 2.0869565217391304,
# The discipline of machine learning employs various approaches to teach computers to accomplish tasks where no fully satisfactory algorithm is available.: 2.08695652173913, For example, Gboard uses federated machine learning to train search query prediction models on users' mobile phones without having to send individual searches back to Google.[77]: 2.08695652173913,
# The term machine learning was coined in 1959 by Arthur Samuel, an American IBMer and pioneer in the field of computer gaming and artificial intelligence.[8][9]: 2.080745341614906, Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.[3]: 2.0683229813664594, A hypothetical algorithm specific to classifying data may use computer vision of moles coupled with supervised learning in order to train it to classify the cancerous moles.: 2.0310559006211175, Machine learning (ML) is the study of computer algorithms that improve automatically through experience and by the use of data.[1]: 2.024844720496894, Attempts to use machine learning in healthcare with the IBM Watson system failed to deliver even after years of time and billions of dollars invested.[94][95]: 1.993788819875776, For simple tasks assigned to computers, it is possible to program algorithms telling the machine how to execute all steps required to solve the problem at hand; on the computer's part, no learning is needed.: 1.9875776397515528, The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning.: 1.968944099378882,
# Usually, machine learning models require a lot of data in order for them to perform well.: 1.968944099378882, Responsible collection of data and documentation of algorithmic rules used by a system thus is a critical part of machine learning.: 1.968944099378882,
# Some statisticians have adopted methods from machine learning, leading to a combined field that they call statistical learning.[35]
#
# A core objective of a learner is to generalize from its experience.[4][36]: 1.93167701863354, However, an increasing emphasis on the logical, knowledge-based approach caused a rift between AI and machine learning.: 1.9254658385093166, In machine learning, the environment is typically represented as a Markov decision process (MDP).: 1.919254658385093,
# As of 2020, deep learning has become the dominant approach for much ongoing work in the field of machine learning.[7]: 1.9068322981366457, In 2010 The Wall Street Journal wrote about the firm Rebellion Research and their use of machine learning to predict the financial crisis.[81]: 1.8944099378881987,
# Other approaches have been developed which don't fit neatly into this three-fold categorisation, and sometimes more than one is used by the same machine learning system.: 1.8695652173913042, It is one of the predictive modeling approaches used in statistics, data mining, and machine learning.: 1.8571428571428572, Work on symbolic/knowledge-based learning did continue within AI, leading to inductive logic programming, but the more statistical line of research was now outside the field of AI proper, in pattern recognition and information retrieval.[19]:708–710; 755: 1.8322981366459627,
# Modern day machine learning has two objectives, one is to classify data based on models which have been developed, the other purpose is to make predictions for future outcomes based on these models.: 1.8322981366459625,
# As a scientific endeavor, machine learning grew out of the quest for artificial intelligence.: 1.826086956521739, Conversely, machine learning techniques have been used to improve the performance of genetic and evolutionary algorithms.[76]: 1.826086956521739, Machine learning (ML), reorganized as a separate field, started to flourish in the 1990s.: 1.8198757763975155,
# Machine learning approaches in particular can suffer from different data biases.: 1.8074534161490683, This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms.: 1.807453416149068, There is  potential for machine learning in health care to provide professionals an additional tool to diagnose, medicate, and plan recovery paths for patients, but this requires these biases to be mitigated.[117]: 1.807453416149068, Recently, machine learning technology is also applied to optimise smartphone's performance and thermal behaviour based on the user's interaction with the phone.[87][88]: 1.7950310559006206, Machine learning is recently applied to predict the green behavior of human-being.[86]: 1.7888198757763973, When trained on man-made data, machine learning is likely to pick up the constitutional and unconscious biases already present in society.[97]: 1.7826086956521736,
# Decision tree learning uses a decision tree as a predictive model to go from observations about an item (represented in the branches) to conclusions about the item's target value (represented in the leaves).: 1.7701863354037266,
# Machine learning has been used as a strategy to update the evidence related to systematic review and increased reviewer burden related to the growth of biomedical literature.: 1.770186335403726, Gordon Plotkin and Ehud Shapiro laid the initial theoretical foundation for inductive machine learning in a logical setting.[67][68][69]: 1.763975155279503,
# Unsupervised learning algorithms take a set of data that contains only inputs, and find structure in the data, like grouping or clustering of data points.: 1.7577639751552796, In 2012, co-founder of Sun Microsystems, Vinod Khosla, predicted that 80% of medical doctors' jobs would be lost in the next two decades to automated machine learning medical diagnostic software.[82]: 1.7515527950310559, Because of such challenges, the effective use of machine learning may take longer to be adopted in other domains.[106]: 1.7515527950310559,
# Machine learning involves computers discovering how they can perform tasks without being explicitly programmed to do so.: 1.7453416149068322,
# Software suites containing a variety of machine learning algorithms include the following:
# : 1.7453416149068322,
# Inductive logic programming (ILP) is an approach to rule-learning using logic programming as a uniform representation for input examples, background knowledge, and hypotheses.: 1.7391304347826086, According to Michael I. Jordan, the ideas of machine learning, from methodological principles to theoretical tools, have had a long pre-history in statistics.[33]: 1.7391304347826084, A popular heuristic method for sparse dictionary learning is the K-SVD algorithm.: 1.732919254658385, In its application across business problems, machine learning is also referred to as predictive analytics.: 1.7080745341614907, Given a set of training examples, each marked as belonging to one of two categories, an SVM training algorithm builds a model that predicts whether a new example falls into one category or the other.[72: 1.6956521739130435, Machine learning systems used for criminal risk assessment have been found to be biased against black people.[100][101]: 1.6894409937888195, In 2020, machine learning technology was used to help make diagnoses and aid researchers in developing a cure for COVID-19.[85]: 1.6770186335403725, In machine learning, genetic algorithms were used in the 1980s and 1990s.[74][75]: 1.670807453416149,
# As of 2020, many sources continue to assert that machine learning remains a subfield of AI.[21][22][16]: 1.6645962732919253,
# Machine learning poses a host of ethical questions.: 1.652173913043478, Various types of models have been used and researched for machine learning systems.: 1.6459627329192545, Through iterative optimization of an objective function, supervised learning algorithms learn a function that can be used to predict the output associated with new inputs.[39]: 1.6397515527950308,
# In weakly supervised learning, the training labels are noisy, limited, or imprecise; however, these labels are often cheaper to obtain, resulting in larger effective training sets.[42]: 1.6397515527950308, Semi-supervised anomaly detection techniques construct a model representing normal behavior from a given normal training data set and then test the likelihood of a test instance to be generated by the model.: 1.5900621118012424,
# Support-vector machines (SVMs), also known as support-vector networks, are a set of related supervised learning methods used for classification and regression.: 1.5776397515527951, Reinforcement learning algorithms do not assume knowledge of an exact mathematical model of the MDP, and are used when exact models are infeasible.: 1.5279503105590062, In unsupervised feature learning, features are learned with unlabeled input data.: 1.484472049689441, The CAA self-learning algorithm computes, in a crossbar fashion, both decisions about actions and emotions (feelings) about consequence situations.: 1.4782608695652173, In supervised feature learning, features are learned using labeled input data.: 1.4472049689440996, Because training sets are finite and the future is uncertain, learning theory usually does not yield guarantees of the performance of algorithms.: 1.4472049689440993, Instead of responding to feedback, unsupervised learning algorithms identify commonalities in the data and react based on the presence or absence of such commonalities in each new piece of data.: 1.4472049689440991, Multilinear subspace learning algorithms aim to learn low-dimensional representations directly from tensor representations for multidimensional data, without reshaping them into higher-dimensional vectors.[55]: 1.4472049689440991, In contrast with sequence mining, association rule learning typically does not consider the order of items either within a transaction or across transactions.: 1.403726708074534, Examples include artificial neural networks, multilayer perceptrons, and supervised dictionary learning.: 1.3975155279503106,  In the mathematical model, each training example is represented by an array or vector, sometimes called a feature vector, and the training data is represented by a matrix.: 1.3975155279503104,
# Deep learning consists of multiple hidden layers in an artificial neural network.: 1.3913043478260867, A central application of unsupervised learning is in the field of density estimation in statistics, such as finding the probability density function.[41]: 1.341614906832298, This replaces manual feature engineering, and allows a machine to both learn the features and use them to perform a specific task.: 1.329192546583851, Artificial neural networks have been used on a variety of tasks, including computer vision, speech recognition, machine translation, social network filtering, playing board and video games and medical diagnosis.: 1.3043478260869563, OpenAI estimated the hardware compute used in the largest deep learning projects from AlexNet (2012) to AlphaZero (2017), and found a 300,000-fold increase in the amount of compute required, with a doubling-time trendline of 3.4 months.[120][121]: 1.291925465838509, Feature learning can be either supervised or unsupervised.: 1.2857142857142856, Unsupervised anomaly detection techniques detect anomalies in an unlabeled test data set under the assumption that the majority of the instances in the data set are normal, by looking for instances that seem to fit least to the remainder of the data set.: 1.279503105590062,  Examples include dictionary learning, independent component analysis, autoencoders, matrix factorization[51] and various forms of clustering.[52][53][54]: 1.2670807453416146,
# A genetic algorithm (GA) is a search algorithm and heuristic technique that mimics the process of natural selection, using methods such as mutation and crossover to generate new genotypes in the hope of finding good solutions to a given problem.: 1.248447204968944,
# A Bayesian network, belief network, or directed acyclic graphical model is a probabilistic graphical model that represents a set of random variables and their conditional independence with a directed acyclic graph (DAG).: 1.2360248447204967, Some successful applications of deep learning are computer vision and speech recognition.[71]: 1.2298136645962732, Deep learning algorithms discover multiple levels of representation, or a hierarchy of features, with higher-level, more abstract features defined in terms of (or generating) lower-level features.: 1.223602484472049, Artificial neurons and edges typically have a weight that adjusts as learning proceeds.: 1.2111801242236024, Many reinforcement learning algorithms use dynamic programming techniques.[43]: 1.1987577639751554, Though unsupervised learning encompasses other domains involving summarizing and explaining data features.: 1.1863354037267082, In computational learning theory, a computation is considered feasible if it can be done in polynomial time.: 1.186335403726708, In practice, it can turn out to be more effective to help the machine develop its own algorithm, rather than having human programmers specify every needed step.[7]: 1.180124223602484, Manifold learning algorithms attempt to do so under the constraint that the learned representation is low-dimensional.: 1.1739130434782608, Efficient algorithms exist that perform inference and learning.: 1.1614906832298137,  An SVM training algorithm is a non-probabilistic, binary, linear classifier, although methods such as Platt scaling exist to use SVM in a probabilistic classification setting.: 1.15527950310559, Supervised anomaly detection techniques require a data set that has been labeled as "normal" and "abnormal" and involves training a classifier (the key difference to many other statistical classification problems is the inherently unbalanced nature of outlier detection).: 1.1490683229813665, Loss functions express the discrepancy between the predictions of the model being trained and the actual problem instances (for example, in classification, one wants to assign a label to instances, and models are trained to correctly predict the pre-assigned labels of a set of examples).[31]: 1.1428571428571428, Sparse dictionary learning has also been applied in image de-noising.: 1.1428571428571426, These robots use guidance mechanisms such as active learning, maturation, motor synergies and imitation.: 1.1366459627329188, It involves computers learning from data provided so that they carry out certain tasks.: 1.1304347826086956, When dealing with non-linear problems, go-to models include polynomial regression (for example, used for trendline fitting in Microsoft Excel[73]), logistic regression (often used in statistical classification) or even kernel regression, which introduces non-linearity by taking advantage of the kernel trick to implicitly map input variables to higher-dimensional space.: 1.124223602484472, Sparse dictionary learning has been applied in several contexts.: 1.0993788819875776, In comparison, the K-fold-cross-validation method randomly partitions the data into K subsets and then K experiments are performed each respectively considering 1 subset for evaluation and the remaining K-1 subsets for training the model.: 1.049689440993789, It is a learning with no external rewards and no external teacher advice.: 1.0434782608695652, Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.: 1.0248447204968945, Several learning algorithms aim at discovering better representations of the inputs provided during training.[50]: 1.0124223602484472, As an example, for a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email.: 0.96273291 ...
# An ANN is a model based on a collection of connected units or nodes called "artificial neurons", which loosely model the neurons in a biological brain.: 0.8385093167701864, For example, the rule
#
#
#
# {
#
# o
# n
# i
# o
# n
# s
# ,
# p
# o
# t
# a
# t
# o
# e
# s
#
# }
# ⇒
# {
#
# b
# u
# r
# g
# e
# r
#
# }
#
#
# {\displaystyle \{\mathrm {onions,potatoes} \}\Rightarrow \{\mathrm {burger} \}}
#
#  found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat.: 0.8136645962732922, In addition to performing linear classification, SVMs can efficiently perform a non-linear classification using what is called the kernel trick, implicitly mapping their inputs into high-dimensional feature spaces.: 0.7701863354037268, In common ANN implementations, the signal at a connection between artificial neurons is a real number, and the output of each artificial neuron is computed by some non-linear function of the sum of its inputs.: 0.7701863354037267, In classification, the problem is to determine the class to which a previously unseen training example belongs.: 0.7639751552795031, In 2019 Springer Nature published the first research book created using machine learning.[84]: 0.7515527950310559, Given an encoding of the known background knowledge and a set of examples represented as a logical database of facts, an ILP system will derive a hypothesized logic program that entails all positive and no negative examples.: 0.7453416149068323, For a dictionary where each class has already been built, a new training example is associated with the class that is best sparsely represented by the corresponding dictionary.: 0.7391304347826088, Data from the training set can be as varied as a corpus of text, a collection of images, and data collected from individual users of a service.: 0.7391304347826088, For example, in 1988, the UK's Commission for Racial Equality found that St. George's Medical School had been using a computer program trained from data of previous admissions staff and this program had denied nearly 60 candidates who were found to be either women or had non-European sounding names.[97]: 0.7329192546583853, It has been argued that an intelligent machine is one that learns a representation that disentangles the underlying factors of variation that explain the observed data.[56]: 0.7267080745341615, Shapiro built their first implementation (Model Inference System) in 1981: a Prolog program that inductively inferred logic programs from positive and negative examples.[70]: 0.7142857142857142, For example, to train a system for the task of digital character recognition, the MNIST dataset of handwritten digits has often been used.[7]: 0.6708074534161491, By 2019, graphic processing units (GPUs), often with AI-specific enhancements, had displaced CPUs as the dominant method of training large-scale commercial cloud AI.[119]: 0.670807453416149, For example, the algorithms could be designed to provide patients with unnecessary tests or medication in which the algorithm's proprietary owners hold stakes.: 0.6521739130434784, Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning.[5][6]: 0.6273291925465839, The total operating characteristic (TOC) is an effective method to express a model's diagnostic ability.: 0.6211180124223603, If the complexity of the model is increased in response, then the training error decreases.: 0.6149068322981367, An algorithm that improves the accuracy of its outputs or predictions over time is said to have learned to perform that task.[13]: 0.6149068322981367, Each training example has one or more inputs and the desired output, also known as a supervisory signal.: 0.6024844720496895, Different clustering techniques make different assumptions on the structure of the data, often defined by some similarity metric and evaluated, for example, by internal compactness, or the similarity between members of the same cluster, and separation, the difference between clusters.: 0.5962732919254659, Due to its generality, the field is studied in many other disciplines, such as game theory, control theory, operations research, information theory, simulation-based optimization, multi-agent systems, swarm intelligence, statistics and genetic algorithms.: 0.5962732919254659, In decision a ...
# Cluster analysis is the assignment of a set of observations into subsets (called clusters) so that observations within the same cluster are similar according to one or more predesignated criteria, while observations drawn from different clusters are dissimilar.: 0.4658385093167702, This results in a smaller dimension of data, (2D instead of 3D) while keeping all original variables in the model without changing the data.[45]: 0.45962732919254656,
# In data mining, anomaly detection, also known as outlier detection, is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.[59]: 0.453416149068323, Signals travel from the first layer (the input layer) to the last layer (the output layer), possibly after traversing the layers multiple times.: 0.453416149068323, Bayesian networks that model sequences of variables, like speech signals or protein sequences, are called dynamic Bayesian networks.: 0.44720496894409945, Classification algorithms are used when the outputs are restricted to a limited set of values, and regression algorithms are used when the outputs may have any numerical value within a range.: 0.4472049689440994, In the early days of AI as an academic discipline, some researchers were interested in having machines learn from data.: 0.44720496894409933, Each connection, like the synapses in a biological brain, can transmit information, a "signal", from one artificial neuron to another.: 0.4347826086956522, In addition to the holdout and cross-validation methods, bootstrap, which samples n instances with replacement from the dataset, can be used to assess model accuracy.[108]: 0.4347826086956522,
# Regression analysis encompasses a large variety of statistical methods to estimate the relationship between input variables and their associated features.: 0.4347826086956521, Inductive programming is a related field that considers any kind of programming language for representing hypotheses (and not only logic programming), such as functional programs.: 0.4285714285714286, Neural networks research had been abandoned by AI and computer science around the same time.: 0.42857142857142855, In other words, it is a process of reducing the dimension of your feature set also called no of features.: 0.42236024844720493,
# For the best performance in the context of generalization, the complexity of the hypothesis should match the complexity of the function underlying the data.: 0.4161490683229814, But if the hypothesis is too complex, then the model is subject to overfitting and generalization will be: 0.4161490683229814, There is neither a separate reinforcement input nor an advice input from the environment.: 0.4161490683229814, While it has improved with training sets, it has not yet developed sufficiently to reduce the workload burden without limiting the necessary sensitivity for the findings research themselves.[96]: 0.39751552795031064, Its most common form is linear regression, where a single line is drawn to best fit the given data according to a mathematical criterion such as ordinary least squares.: 0.39130434782608703, In addition to market basket analysis, association rules are employed today in application areas including Web usage mining, intrusion detection, continuous production, and bioinformatics.: 0.38509316770186347, The field changed its goal from achieving artificial intelligence to tackling solvable problems of a practical nature.: 0.37888198757763975,
# The Dimensionality reduction is a process of reducing the number of random variables under the consideration by obtaining a set of principal variables.[44]: 0.37888198757763975,
# One of the popular method of dimensionality reduction is called as principal component analysis.: 0.36645962732919257, In 1981 a report was given on using teaching strategies so that a neural network learns to recognize 40 characters (26 letters, 10 digits, and 4 special symbols) from a computer terminal.[12]: 0.36024844720496896, The algorithms, therefore, learn from test data that has not been labeled, classified or categorized.: 0.36024844720496896, They attempted to approach the problem with various symbolic methods, as well as what was then termed "neural networks"; these were mostly perceptrons and other models that were later found to be reinventions of the generalized linear models of statistics.[18]: 0.35403726708074534, Because human languages contain biases, machines trained on language corpora will necessarily also learn these biases.[114][115]: 0.34782608695652173, However, real-world data such as images, video, and sensory data has not yielded to attempts to algorithmically define specific features.: 0.3354037267080746, Artificial neurons may have a threshold such that the signal is only sent if the aggregate signal crosses that threshold.: 0.33540372670807456, The main disagreement is whether all of ML is part of AI, as this would mean that anyone using ML could claim they are using AI.: 0.3354037267080745,
# In addition to overall accuracy, investigators frequently report sensitivity and specificity meaning True Positive Rate (TPR) and True Negative Rate (TNR) respectively.: 0.329192546583851, This also increases efficiency by decentralizing the training process to many devices.: 0.32919254658385094, Decision trees where the target variable can take continuous values (typically real numbers) are called regression trees.: 0.32298136645962733,
# Artificial neural networks (ANNs), or connectionist systems, are computing systems vaguely inspired by the biological neural networks that constitute animal brains.: 0.3167701863354038,
# AI can be well-equipped to make decisions in technical fields, which rely heavily on data and historical information.: 0.31677018633540377, Classic examples include principal components analysis and cluster analysis.: 0.31055900621118016, After receiving the genome (species) vector from the genetic environment, the CAA learns a goal-seeking behavior, in an environment that contains both desirable and undesirable situations.[49]: 0.30434782608695654,
# The original goal of the ANN approach was to solve problems in the same way that a human brain would.: 0.3043478260869565, The CAA exists in two environments, one is the behavioral environment where it behaves, and the other is the genetic environment, wherefrom it initially and only once receives initial emotions about situations to be encountered in the behavioral environment.: 0.2981366459627329,
# In particular, in the context of abuse and network intrusion detection, the interesting objects are often not rare objects, but unexpected bursts of inactivity.: 0.2981366459627329,
# Based on the concept of strong rules, Rakesh Agrawal, Tomasz Imieliński and Arun Swami introduced association rules for discovering regularities between products in large-scale transaction data recorded by point-of-sale (POS) systems in supermarkets.[65]: 0.2981366459627329, Generalizations of Bayesian networks that can represent and solve decision problems under uncertainty are called influence diagrams.: 0.2981366459627329, Language models learned from data have been shown to contain human-like biases.[98][99]: 0.2981366459627329, This line, too, was continued outside the AI/CS field, as "connectionism", by researchers from other disciplines including Hopfield, Rumelhart and Hinton.: 0.26708074534161497, He also suggested the term data science as a placeholder to call the overall field.[33]: 0.26708074534161497, This technique allows reconstruction of the inputs coming from the unknown data-generating distribution, while not being necessarily faithful to configurations that are implausible under that distribution.: 0.26086956521739135, Typically, the anomalous items represent an issue such as bank fraud, a structural defect, medical problems or errors in a text.: 0.26086956521739135, In cases where vast numbers of potential answers exist, one approach is to label some of the correct answers as valid.: 0.2546583850931677, The method is strongly NP-hard and difficult to solve approximately.[57]: 0.2422360248447205, For example topic modeling,  meta learning.[46]: 0.2298136645962733,
# The question to what is the difference between ML and AI is answered by Judea Pearl in The Book of Why.[27]: 0.22981366459627328, Similarly, investigators sometimes report the false positive rate (FPR) as well as the false negative rate (FNR).: 0.22981366459627328, TOC shows the numerators and denominators of the previously mentioned rates, thus TOC provides more information than the commonly used receiver operating characteristic (ROC) and ROC's associated area under the curve (AUC).[109]: 0.2236024844720497, Systems which are trained on datasets collected with biases may exhibit these biases upon use (algorithmic bias), thus digitizing cultural prejudices.[110]: 0.2236024844720497,
# The PCA involves changing higher dimensional data (eg. 3D) to a smaller space (eg. 2D).: 0.2111801242236025,
# Inductive logic programming is particularly useful in bioinformatics and natural language processing.: 0.2111801242236025, Positive results show that a certain class of functions can be learned in polynomial time.: 0.20496894409937888, Most of the dimensionality reduction techniques can be considered as either feature elimination or extraction.: 0.1925465838509317, The system is driven by the interaction between cognition and emotion.[48]: 0.1925465838509317, Probabilistic systems were plagued by theoretical and practical problems of data acquisition and representation.[19]:488: 0.19254658385093168, The bias–variance decomposition is one way to quantify generalization error.: 0.19254658385093168, It shifted focus away from the symbolic approaches it had inherited from AI, and toward methods and models borrowed from statistics and probability theory.[20]: 0.18633540372670807, The key idea is that a clean image patch can be sparsely represented by an image dictionary, but the noise cannot.[58]: 0.18633540372670807, Different layers may perform different kinds of transformations on their inputs.: 0.18633540372670807, The latter is often extended by regularization (mathematics) methods to mitigate overfitting and bias, as in ridge regression.: 0.18633540372670807, It is seen as a part of artificial intelligence.: 0.18012422360248448, Typically, artificial neurons are aggregated into layers.: 0.18012422360248448, Trained models derived from biased data can result in skewed or undesired predictions.: 0.18012422360248448, Others have the view that not all of ML is part of AI[23][24][25] where only an 'intelligent' subset of ML is part of AI.[26]: 0.17391304347826086, Given symptoms, the network can be used to compute the probabilities of the presence of various diseases.: 0.17391304347826086, Instead, probabilistic bounds on the performance are quite common.: 0.16149068322981364, Negative results show that certain classes cannot be learned in polynomial time.: 0.15527950310559008, By 1980, expert systems had come to dominate AI, and statistics was out of favor.[20]: 0.14906832298136644, The backpropagated value (secondary reinforcement) is the emotion toward the consequence situation.: 0.14906832298136644, This is especially true in the United States where there is a long-standing ethical dilemma of improving health care, but also increasing profits.: 0.14285714285714285, This follows Alan Turing's proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?" is replaced with the question "Can machines do what we (as thinking entities) can do?".[14]: 0.14285714285714282, The connections between artificial neurons are called "edges".: 0.13664596273291926, Similar issues with recognizing non-white people have been found in many other systems.[104]: 0.13043478260869565, Interest related to pattern recognition continued into the 1970s, as described by Duda and Hart in 1973.[11]: 0.11801242236024845, Three broad categories of anomaly detection techniques exist.[62]: 0.11801242236024845, However, over time, attention moved to performing specific tasks, leading to deviations from biology.: 0.11801242236024845, It’s inspired by people, it’s created by people, and—most importantly—it impacts people.: 0.11801242236024845, The weight increases or decreases the strength of the signal at a connection.: 0.11180124223602483, For more advanced tasks, it can be challenging for a human to manually create the needed algorithms.: 0.10559006211180125, Probabilistic reasoning was also employed, especially in automated medical diagnosis.[19]:488
# : 0.10559006211180123, Shortly after the prize was awarded, Netflix realized that viewers' ratings were not the best indicators of their viewing patterns ("everything is a recommendation") and they changed their recommendation engine accordingly.[80]: 0.10559006211180123,
# Other forms of ethical challenges, not related to personal biases, are seen in health care.: 0.10559006211180122, There are two kinds of time complexity results.: 0.09937888198757765, It has applications in ranking, recommendation systems, visual identity tracking, face verification, and speaker verification.: 0.08695652173913042, Such information can be used as the basis for decisions about marketing activities such as promotional pricing or product placements.: 0.08695652173913042,
# In 2018, a self-driving car from Uber failed to detect a pedestrian, who was killed after a collision.[93]: 0.07453416149068322, There are concerns among health care professionals that these systems might not be designed in the public's interest but as income-generating machines.[116]: 0.07453416149068322, It is intended to identify strong rules discovered in databases using some measure of "interestingness".[63]: 0.06832298136645962, An alternative is to discover such features or representations through examination, without relying on explicit algorithms.: 0.06211180124223602, In 2016, Microsoft tested a chatbot that learned from Twitter, and it quickly picked up racist and sexist language.[105]: 0.049689440993788817, These decisions rely on objectivity and logical reasoning.[113]: 0.049689440993788817, However, these rates are ratios that fail to reveal their numerators and denominators.: 0.043478260869565216, Other methods are based on estimated density and graph connectivity.: 0.037267080745341616, Their main success came in the mid-1980s with the reinvention of backpropagation.[19]:25
# : 0.031055900621118012, Anomalies are referred to as outliers, novelties, noise, deviations and exceptions.[60]: 0.012422360248447204, poorer.[37]: 0,
# : 0,
# : 0,
# : 0,
# : 0,
# : 0, ]: 0, at all.[103: 0, ]: 0}
# 293

# %%
from itertools import count, takewhile
sen_choice_spacy = 10
counter_spacy = count()
selected_sentences_spacy = list(takewhile(lambda x: next(counter_spacy) < sen_choice, (items[0] for items in sorted_sentence_tokens_spacy.items())))
for i, sentence in enumerate(selected_sentences_spacy):
    print('---> Sentence %d: %s' % (i, sentence))
# Out:
# ---> Sentence 0:
# Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.
# ---> Sentence 1: Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.
# ---> Sentence 2:
#
# Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:
# Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.[38]
# ---> Sentence 3:
# Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).
# ---> Sentence 4:
# A subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers; but not all machine learning is statistical learning.
# ---> Sentence 5: A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.[10]
# ---> Sentence 6: It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”[107]
# Classification of machine learning models can be validated by accuracy estimation techniques like the holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.
# ---> Sentence 7: Rule-based machine learning approaches include learning classifier systems, association rule learning, and artificial immune systems.
# ---> Sentence 8: Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...
# ---> Sentence 9:
# The difference between optimization and machine learning arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.
